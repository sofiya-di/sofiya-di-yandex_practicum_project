# %% [markdown]
# <h1>Анализ товарного ассортимента<span class="tocSkip"></span></h1>

# %% [markdown]
# ### Описание данных
#
# Интернет-магазин предоставил данные, которые описывают транзакции интернет-магазина товаров для дома и быта «Пока все ещё тут».
#
# - `date` — дата заказа;
# - `customer_id` — идентификатор покупателя;
# - `order_id` — идентификатор заказа;
# - `product` — наименование товара;
# - `quantity` — количество товара в заказе;
# - `price` — цена товара.

# %% [markdown]
# ## Обзор данных

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import nltk
import re 
import warnings
warnings.filterwarnings('ignore')

from datetime import date, datetime, time, timedelta
from pymystem3 import Mystem
from scipy import stats
from nltk.stem.snowball import SnowballStemmer
from sklearn.preprocessing import StandardScaler
from scipy import stats as st  
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# Ознакомимся с предоставленными данным:

# %%
try:
    df = pd.read_csv('/datasets/ecommerce_dataset.csv') #серверный путь
except:
     df = pd.read_csv('C:/Users/User/Desktop/ecommerce_dataset.csv') #локальный путь

# %% [markdown]
# ### Проверка типа данных в столбцах

# %%
display(df.head())
display(df.info())
df.describe()
# Out:
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6737 entries, 0 to 6736
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         6737 non-null   int64
#  1   customer_id  6737 non-null   object
#  2   order_id     6737 non-null   int64
#  3   product      6737 non-null   object
#  4   quantity     6737 non-null   int64
#  5   price        6737 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 315.9+ KB
# None
#                date      order_id     quantity         price
# count  6.737000e+03   6737.000000  6737.000000   6737.000000
# mean   2.018855e+09  43128.948345     2.501559    462.028499
# std    3.855185e+05  27899.414662    15.266478    871.296064
# min    2.018100e+09  12624.000000     1.000000      9.000000
# 25%    2.019020e+09  14827.000000     1.000000    101.000000
# 50%    2.019050e+09  68503.000000     1.000000    135.000000
# 75%    2.019061e+09  70504.000000     1.000000    398.000000
# max    2.019103e+09  73164.000000  1000.000000  14917.000000

# %% [markdown]
# #### Выводы:
#
# 1. В данных представлены сведения о заказах пользователей:
# * date — дата заказа;
# * customer_id — идентификатор покупателя;
# * order_id — идентификатор заказа;
# * product — наименование товара;
# * quantity — количество товара в заказе;
# * price — цена товара.
#
# 2. В таблице 6737 строчек и 6 колонок
# 3. Одна строчка соотвествует одной заказанной позиции от одного покупателя
# 4. В столбце `date`, где указана дата заказа- тип данных `int64`, вместо `datetime`
# 5. Минимальное количество товара в заказе-1, максимальное количество товара в заказаке-1000
# 6. Минимальная цена товара-9 денежных едениц, максимальная цена товара-14.917 денежных едениц

# %% [markdown]
# ### Проверка данных на пропуски

# %% [markdown]
# Проверим таблицу на наличие пропущенных значений

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6737 entries, 0 to 6736
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         6737 non-null   int64
#  1   customer_id  6737 non-null   object
#  2   order_id     6737 non-null   int64
#  3   product      6737 non-null   object
#  4   quantity     6737 non-null   int64
#  5   price        6737 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 315.9+ KB

# %% [markdown]
# #### Выводы:
#
# В таблице нет пропущенных значений

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Исправление типов данных

# %% [markdown]
# Исправим тип данных в столбце `date`, где указана дата заказа- тип данных `int64`, вместо `datetime`:

# %%
df['date_new'] = pd.to_datetime(df['date'],format='%Y%m%d%H') #изменяем тип данных
display(df.head())
df.info()
# Out:
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0
#
#     date_new
# 0 2018-10-01
# 1 2018-10-01
# 2 2018-10-01
# 3 2018-10-01
# 4 2018-10-01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6737 entries, 0 to 6736
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         6737 non-null   int64
#  1   customer_id  6737 non-null   object
#  2   order_id     6737 non-null   int64
#  3   product      6737 non-null   object
#  4   quantity     6737 non-null   int64
#  5   price        6737 non-null   float64
#  6   date_new     6737 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 368.6+ KB

# %% [markdown]
# #### Вывод:
#
# Тип данных в столбце изменен.

# %% [markdown]
# ### Выделение месяца и часов в отдельный столбец

# %% [markdown]
# Создадим столбец, в котором будет только месяц:

# %%
df['month_year'] = df['date_new'].astype('datetime64[M]') #создаем столбец только с месяцем
display(df.head())
df.info()
# Out:
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0
#
#     date_new month_year
# 0 2018-10-01 2018-10-01
# 1 2018-10-01 2018-10-01
# 2 2018-10-01 2018-10-01
# 3 2018-10-01 2018-10-01
# 4 2018-10-01 2018-10-01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6737 entries, 0 to 6736
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         6737 non-null   int64
#  1   customer_id  6737 non-null   object
#  2   order_id     6737 non-null   int64
#  3   product      6737 non-null   object
#  4   quantity     6737 non-null   int64
#  5   price        6737 non-null   float64
#  6   date_new     6737 non-null   datetime64[ns]
#  7   month_year   6737 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(3), object(2)
# memory usage: 421.2+ KB

# %% [markdown]
# Создадим столбец, в котором будут только часы:

# %%
df['hours'] = pd.to_datetime(df['date'],format='%Y%m%d%H').dt.hour #создаем столбец только с часами
df.head()
# Out:
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0
#
#     date_new month_year  hours
# 0 2018-10-01 2018-10-01      0
# 1 2018-10-01 2018-10-01      0
# 2 2018-10-01 2018-10-01      0
# 3 2018-10-01 2018-10-01      0
# 4 2018-10-01 2018-10-01      0

# %% [markdown]
# #### Вывод:
#
# Добавили отдельные столбцы с месяцем и часами.

# %% [markdown]
# ### Проверка данных на дубликаты

# %% [markdown]
# Проверим данные на дубликаты

# %%
df[df.duplicated()] #проверка на явные дубликаты
# Out:
# Empty DataFrame
# Columns: [date, customer_id, order_id, product, quantity, price, date_new, month_year, hours]
# Index: []

# %% [markdown]
# Полных дубликатов в таблице нет.
#
#
# Проверим таблицу на наличие дубликатов без столбца `date`, так как в столбце указаны данные в формате `int`, это может помешать найти существующие дубликаты

# %%
#новая таблица, без столбца с датой 
new_df = df[[ 'customer_id','order_id', 'product',  'quantity','price', 'month_year',  'hours']]
new_df
# Out:
#                                customer_id  order_id  \
# 0     ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1     ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2     ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3     ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4     ee47d746-6d2f-4d3c-9622-c31412542920     68477
# ...                                    ...       ...
# 6732  73d1cd35-5e5f-4629-8cf2-3fda829d4e58     73156
# 6733  1f0a7f35-7459-4f23-b468-5e45bf481dd1     73158
# 6734  25df96a7-c453-4708-9cea-a3dfc7c342ea     73162
# 6735  73d1cd35-5e5f-4629-8cf2-3fda829d4e58     73164
# 6736  344aa778-e436-419e-a9c6-9b8f37b7c1df     73137
#
#                                                 product  quantity   price  \
# 0       Комнатное растение в горшке Алое Вера, d12, h30         1   142.0
# 1     Комнатное растение в горшке Кофе Арабика, d12,...         1   194.0
# 2                           Радермахера d-12 см h-20 см         1   112.0
# 3                      Хризолидокарпус Лутесценс d-9 см         1   179.0
# 4                        Циперус Зумула d-12 см h-25 см         1   112.0
# ...                                                 ...       ...     ...
# 6732  Таз пластмассовый 40,0 л пищевой овальный (Иж)...         1   404.0
# 6733         Сумка-тележка 2-х колесная Gimi Argo синяя         1  1087.0
# 6734  Герань домашняя (пеларгония зональная) цветуща...         1   157.0
# 6735  Таз пластмассовый со стиральной доской (Иж), 1...         1   397.0
# 6736         Сумка-тележка 2-х колесная Gimi Argo синяя         1  1087.0
#
#      month_year  hours
# 0    2018-10-01      0
# 1    2018-10-01      0
# 2    2018-10-01      0
# 3    2018-10-01      0
# 4    2018-10-01      0
# ...         ...    ...
# 6732 2019-10-01     11
# 6733 2019-10-01     12
# 6734 2019-10-01     13
# 6735 2019-10-01     14
# 6736 2019-10-01     16
#
# [6737 rows x 7 columns]

# %%
#поиск дубликатов в таблице без столбца с датой
new_df[new_df.duplicated()]
# Out:
#                                customer_id  order_id  \
# 1130  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1133  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1138  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1143  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1206  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# ...                                    ...       ...
# 6247  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6290  254cea58-53b6-4adf-bba3-9b6074797240     72518
# 6358  eeb70bfd-1bbc-44b7-92b7-ee556c2607bb     72683
# 6647  7f76ce2d-fb60-471f-8820-53ad6197caaa     73002
# 6706  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
#
#                                                 product  quantity   price  \
# 1130  Термометр на окно уличный на липучках Т-5 h-20...         2    44.0
# 1133  Термометр на окно уличный на липучках Т-5 h-20...         2    44.0
# 1138  Термометр на окно уличный на липучках Т-5 h-20...         2    44.0
# 1143  Термометр на окно уличный на липучках Т-5 h-20...         2    44.0
# 1206  Термометр на окно уличный на липучках Т-5 h-20...         2    44.0
# ...                                                 ...       ...     ...
# 6247       Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6290  Щетка универсальная с телескопической ручкой D...         1  1612.0
# 6358  Таз пластмассовый 8,0 л пищевой (Минеральные в...         1   127.0
# 6647                     Эвкалипт Гунни d-14 см h-70 см         2   524.0
# 6706       Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
#
#      month_year  hours
# 1130 2018-12-01     20
# 1133 2018-12-01     18
# 1138 2018-12-01     14
# 1143 2018-12-01     20
# 1206 2018-12-01     18
# ...         ...    ...
# 6247 2019-09-01      9
# 6290 2019-09-01      9
# 6358 2019-09-01     10
# 6647 2019-10-01      7
# 6706 2019-10-01     10
#
# [738 rows x 7 columns]

# %% [markdown]
# По таблице видно, что некоторые заказы полностью дублируются, вплоть до времени заказа. Посмотрим на один из таких заказов.

# %%
new_df[new_df['order_id'] == 69162]
# Out:
#                                customer_id  order_id  \
# 1043  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1045  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1046  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1047  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1054  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1091  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1130  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1133  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1135  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1136  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1138  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1139  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1143  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1190  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1206  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1216  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1220  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1265  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1287  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1308  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1320  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1321  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
# 1421  8c290149-ad54-4d7a-87a7-9386b36390ee     69162
#
#                                                 product  quantity  price  \
# 1043  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1045  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1046  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1047  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1054  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1091  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1130  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1133  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1135  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1136  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1138  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1139  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1143  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1190  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1206  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1216  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1220  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1265  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1287  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1308  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1320  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1321  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
# 1421  Термометр на окно уличный на липучках Т-5 h-20...         2   44.0
#
#      month_year  hours
# 1043 2018-12-01     12
# 1045 2018-12-01     18
# 1046 2018-12-01     20
# 1047 2018-12-01     22
# 1054 2018-12-01     14
# 1091 2018-12-01     19
# 1130 2018-12-01     20
# 1133 2018-12-01     18
# 1135 2018-12-01     21
# 1136 2018-12-01     13
# 1138 2018-12-01     14
# 1139 2018-12-01     15
# 1143 2018-12-01     20
# 1190 2018-12-01      0
# 1206 2018-12-01     18
# 1216 2018-12-01     19
# 1220 2018-12-01     13
# 1265 2018-12-01     12
# 1287 2018-12-01     22
# 1308 2018-12-01     20
# 1320 2018-12-01     12
# 1321 2018-12-01     13
# 1421 2018-12-01     17

# %%
new_df[new_df['order_id'] == 70960]
# Out:
#                                customer_id  order_id  \
# 2589  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2600  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2622  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2718  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2734  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2762  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2815  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2820  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2845  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2854  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2999  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3017  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3040  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3077  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3153  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3268  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3342  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3415  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3419  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3446  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3588  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3629  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3738  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3823  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3872  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3940  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 3965  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 4091  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 4402  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 4479  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 4610  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5005  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5390  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5498  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5562  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5599  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5602  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5647  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5675  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5723  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5860  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5895  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5989  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 5997  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6047  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6140  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6183  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6194  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6235  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6247  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6284  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6317  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6335  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6354  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6419  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6581  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6670  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6673  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6705  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 6706  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
#
#                                            product  quantity   price  \
# 2589  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2600  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2622  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2718  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2734  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2762  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2815  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2820  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2845  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2854  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 2999  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3017  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3040  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3077  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3153  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3268  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3342  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3415  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3419  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3446  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3588  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3629  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3738  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3823  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3872  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3940  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 3965  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 4091  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 4402  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 4479  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 4610  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5005  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5390  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5498  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5562  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5599  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5602  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5647  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5675  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5723  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5860  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5895  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5989  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 5997  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6047  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6140  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6183  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6194  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6235  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6247  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6284  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6317  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6335  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6354  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6419  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6581  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6670  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6673  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6705  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
# 6706  Сумка-тележка 2-х колесная Gimi Argo красная         1  1087.0
#
#      month_year  hours
# 2589 2019-04-01     16
# 2600 2019-04-01     10
# 2622 2019-04-01      8
# 2718 2019-04-01     15
# 2734 2019-04-01      9
# 2762 2019-04-01     19
# 2815 2019-04-01     22
# 2820 2019-04-01     21
# 2845 2019-04-01     17
# 2854 2019-04-01     10
# 2999 2019-04-01     21
# 3017 2019-04-01     12
# 3040 2019-04-01     10
# 3077 2019-04-01     10
# 3153 2019-04-01      9
# 3268 2019-04-01     19
# 3342 2019-04-01     19
# 3415 2019-05-01      9
# 3419 2019-05-01      8
# 3446 2019-05-01      8
# 3588 2019-05-01     20
# 3629 2019-05-01     10
# 3738 2019-05-01      9
# 3823 2019-05-01     10
# 3872 2019-05-01      9
# 3940 2019-05-01     10
# 3965 2019-05-01      8
# 4091 2019-05-01      9
# 4402 2019-06-01     13
# 4479 2019-06-01     14
# 4610 2019-06-01      9
# 5005 2019-06-01      9
# 5390 2019-06-01     20
# 5498 2019-06-01     19
# 5562 2019-06-01      9
# 5599 2019-06-01     10
# 5602 2019-06-01     23
# 5647 2019-07-01      8
# 5675 2019-07-01     10
# 5723 2019-07-01      8
# 5860 2019-07-01      8
# 5895 2019-07-01      9
# 5989 2019-07-01      9
# 5997 2019-07-01     10
# 6047 2019-08-01      8
# 6140 2019-08-01     18
# 6183 2019-08-01      9
# 6194 2019-08-01     19
# 6235 2019-09-01      9
# 6247 2019-09-01      9
# 6284 2019-09-01     13
# 6317 2019-09-01     22
# 6335 2019-09-01     11
# 6354 2019-09-01     20
# 6419 2019-09-01     10
# 6581 2019-10-01     10
# 6670 2019-10-01     12
# 6673 2019-10-01      9
# 6705 2019-10-01      8
# 6706 2019-10-01     10

# %% [markdown]
# Есть несколько вариантов возникновения такого количества дубликатов:
# * покупатель оптовик (но тогда почему не оформить все товары в один заказ?)
# * на сайте возникла техническая ошибка и пользователю приходилось несколько раз оформлять заказ (но тогла почему все заказы оплачены?)
# * покупатель целенаправленно покупал термометры (напрмер, для перепродажи, для использования на разных объектах, но почему тогда не оформить все товары в одном заказе?)
# * это полные дубликаты, и для более достоверных результатов, их необходимо удалить, кроме первого вхождения

# %% [markdown]
# Расчитаем количество и долю дубликатов, кроме первого вхождения

# %%
duplicates_not_first = len(new_df[new_df.duplicated(keep= 'first')])
f'Количество дубликатов в данных, кроме первого вхождения: {duplicates_not_first}'
# Out:
# 'Количество дубликатов в данных, кроме первого вхождения: 738'

# %%
share_duplicates_not_first = (duplicates_not_first/len(df))*100
f'Доля дубликатов в данных, кроме первого вхождения: {share_duplicates_not_first} %'
# Out:
# 'Доля дубликатов в данных, кроме первого вхождения: 10.954430755529167 %'

# %% [markdown]
# Расчитаем количество и долю всех дубликатов:

# %%
duplicates = len(new_df[new_df.duplicated(keep= False)])
f'Количество всех  дубликатов в данных: {duplicates}'
# Out:
# 'Количество всех  дубликатов в данных: 1004'

# %%
share_duplicates = (duplicates/len(df))*100
f'Доля дубликатов в данных, кроме первого вхождения: {share_duplicates} %'
# Out:
# 'Доля дубликатов в данных, кроме первого вхождения: 14.902775716194153 %'

# %% [markdown]
# Удалив дубликаты, кроме первого вхождения, мы оставляем заказы, которые пользователь мог продублировать из-за того, что ему очень понравился товар.

# %%
df_without_duplicates = new_df.drop_duplicates(keep='first').reset_index(drop=True)
display(df_without_duplicates.info())
df_without_duplicates.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  5999 non-null   object
#  1   order_id     5999 non-null   int64
#  2   product      5999 non-null   object
#  3   quantity     5999 non-null   int64
#  4   price        5999 non-null   float64
#  5   month_year   5999 non-null   datetime64[ns]
#  6   hours        5999 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 328.2+ KB
# None
#                             customer_id  order_id  \
# 0  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0
#
#   month_year  hours
# 0 2018-10-01      0
# 1 2018-10-01      0
# 2 2018-10-01      0
# 3 2018-10-01      0
# 4 2018-10-01      0

# %% [markdown]
# Дубликаты удалены.

# %% [markdown]
# #### Выводы:
#
# 1. В таблице нет полных дубликатов
# 2. В таблице имеются дубликаты по `customer_id` и `по order_id`, так как один пользователь мог заказать за одно посещение интеренет магазина несколько товаров в одном заказе, а в таблице эти заказы указаны по отдельности, удалять данные дубликаты не надо.
# 3. В таблице имеются неполные дубликаты, их доля- 10% (738): один пользователь, в один и тот же день, заказала один и тот же товар, несолько раз, с одним номером заказа, одинаковое количество, но в разное время суток.
#
#
# Во многих интернет-магазинах, есть функция-"продублировать заказ": в таком случае происходит полное дублирование заказа, с тем же содержимым, но разным номером заказа. Но может быть, на в данном интернет магазине при клике на "повторить заказ", дублируется и номер заказа. Заказы отличаются только временем заказа.
#
# Однако заказ действительно может дублироваться, так как один пользователь может решиться на повторный заказ  чеерез несколько часов. Поэтому удалим дубликаты, кроме первого вхождения.
#
# Так же, следует отметить, что доля дубликатов, кроме первого вхождения-10% (доля всех дубликатов-14 %)

# %% [markdown]
# ### Работа с дубликатами

# %% [markdown]
# Ознакокимся с содержимым столбца `product`

# %%
list(df_without_duplicates['product'].unique())
# Out:
# ['Комнатное растение в горшке Алое Вера, d12, h30',
#  'Комнатное растение в горшке Кофе Арабика, d12, h25',
#  'Радермахера d-12 см h-20 см',
#  'Хризолидокарпус Лутесценс d-9 см',
#  'Циперус Зумула d-12 см h-25 см',
#  'Шеффлера Лузеана d-9 см',
#  'Юкка нитчатая d-12 см h-25-35 см',
#  'Настенная сушилка для белья Gimi Brio Super 100',
#  'Таз пластмассовый 21,0 л круглый "Водолей" С614, 1404056',
#  'Чехол для гладильной доски Colombo Persia Beige 130х50 см из хлопка 5379',
#  'Вешалка для брюк металлическая с резиновым покрытием 26 см цвет: синяя, Attribute, AHS331',
#  'Сушилка для белья потолочная Zalger Lift Basic 1520 200 см, 10 м',
#  'Чехол Eurogold Clean Basic хлопок для досок 120х38-120х42 см C42',
#  'Крючок одежный 2-х рожковый серый металлик с полимерным покрытием *Тонар*, 1110027',
#  'Корзина мягкая пластиковая 17 л, М-пластика, M2880',
#  'Мини-сковорода Marmiton "Сердце" с антипригарным покрытием 12 см, LG17085',
#  'Сковорода алюминиевая с антипригарным покрытием MARBLE ALPENKOK d = 26 см AK-0039A/26N',
#  'Стеклянная крышка для сковороды ALPENKOK 26 см AK-26GL',
#  'Сушилка для белья напольная Colombo Star 18, 3679',
#  'Доска гладильная Eurogold Professional 130х48 см металлическая сетка 35748W',
#  'Чехол для гладильной доски Festival 137x60 см из хлопка 4738',
#  'Сумка-тележка 2-х колесная Gimi Argo синяя',
#  'Многолетнее растение Тимьян-чабрец розовый объем 0,5 л',
#  'Рассада зелени для кухни Базилик Тонус, кассета по 6шт',
#  'Рассада зелени для кухни Мелиссы в горшке диам. 9 см',
#  'Муляж "Райские Яблочки Зеленые" 2 шт полиуретан, d 3 см',
#  'Муляж Банан, желтый, 21 см, полиуретан, Fancy Fair/ff XJ210',
#  'Муляж Виноград 14 см цвет в ассортименте',
#  'Муляж ГРАНАТ 9см, красный, Fancy Fair, SL90, красный',
#  'Муляж Груша мини 2 шт, желтая 4 см',
#  'Муляж Груша, желтый, 9,5 см, полиуретан, Fancy Fair/ff LI95-03',
#  'Муляж Зеленое яблоко полиуретан d-6 см',
#  'Муляж Клубника 1 шт полиуретан d-6 см',
#  'Муляж Клубника на магните',
#  'Муляж Красное яблоко мини полиуретан d-6 см',
#  'Муляж Лимон, желтый, 9 см, полиуретан, Fancy Fair/ff NM90',
#  'Муляж Мандарин, оранжевый, 8 см, полиуретан, Fancy Fair/ff JZ80',
#  'Муляж Перец, зеленый, 10 см, полиуретан, Fancy Fair/ff GP8',
#  'Муляж Перец, красный, 10 см, полиуретан, Fancy Fair/ff RP8',
#  'Муляж Персики мини полиуретан d-6 см',
#  'Муляж Томат, оранжевый, 9 см, полиуретан, Fancy Fair/ff T9',
#  'Муляж ЧЕРЕШНЯ 3см 10 шт., желтый, Fancy Fair, SCR30/10, желтый',
#  'Щетка-сметка 3-х рядная деревянная 450 мм (плоская ручка), Поиск Риф 1801095',
#  'Щетка-сметка 4-х рядная деревянная 300 мм (фигурная ручка) ворс 5,5 см 1801096',
#  'Сумка для тележки большая комбинированная 45*30*25, 1209021',
#  'Тарелка обеденная ЛИМОН ФИЦ 25см, G9547, Luminarc, Франция',
#  'Вилка столовая RIPPLE сталь 3 мм, 3 шт, Attribute, ACR013',
#  'Ложка столовая RIPPLE сталь 3 мм, 3 шт, Attribute, ACR023',
#  'Ложка чайная RIPPLE сталь 2,5 мм, 3 шт, Attribute, ACR033',
#  'Нож столовый RIPPLE 80 г 2 шт, Attribute, ACR042',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, коралловая, полумахровая',
#  'Ерш для туалета с подставкой MALIBU фарфор 47х12,5 см белый, Spirella, 1001768',
#  'Пеларгония зональная диам. 12 см малиновая с красным полумахровая',
#  'Пеларгония зональная диам. 12 см сиренево-красная простая',
#  'Пеларгония зональная диам. 12 см сиреневый полумахровый',
#  'Пеларгония зональная диам. 12 см сиреневый простая',
#  'Сушилка для белья настенная Zalger Prima 510-720 веревочная 7 линий 25 м',
#  'Котел алюминиевый 70,0 л без крышки Балезино, Хозлэнд, 1502050',
#  'Суккулент Микс d-5 см',
#  'Эхеверия Перл Фон Нюрнберг d-7 см',
#  'Набор прищепок большие пластиковые ROZENBAL ПИНОККИО 10 шт R102312',
#  'Сушилка для белья Attribute ПРИМА 11 м синяя напольная ADP410',
#  'Коврик придверный 45х75см. с рельефным рисунком "Welcome", коричневый, CR005',
#  'Коврик Bacchetta MagicStop 0,3x1,5 м бежевый для сушки посуды 2289',
#  'Корзина для глаженного белья Natural Style, 45 л, 27*38*59 см, коричневая, D 00708-213, Curver 00708-213',
#  'Корзина пластиковая для белья 60л. с крышкой бежевая 1860/2, Виолет',
#  'Сушилка для белья потолочно-настенная Gimi Lift 200',
#  'Подкладка под чехол Zalger 520140 135х50 см поролон',
#  'Набор кружек для пива ГАМБУРГ 2шт 500мл, H5072, Luminarc, Россия',
#  'Коврик интерьерный для кухни Village Street Floral из ПВХ прямоугольный 50х107 см, Apache, 4663',
#  'Дозатор для мыла Hausmann белый HM-B0194R-2',
#  'Ёрш унитазный с подставкой WC "Стандарт", Мультипласт 1712010',
#  'Нож для чистки овощей WEBBER из нержавеющей стали 12х6,8х1,5 см ВЕ-5275',
#  'Подкладка под чехол Zalger 520114 135х50 см войлок',
#  'Эвкалипт Гунни d-17 см h-60 см',
#  'Муляж Виноград, желтый, 24 см, полиуретан, Fancy Fair/G60-Y',
#  'Муляж Виноград, зеленый, 26 см, полиуретан, Fancy Fair/G85-G',
#  'Муляж Виноград, черный, 26 см, полиуретан, Fancy Fair/G85-B',
#  'Муляж Вишня, вишневый, 3 см, 10 шт, полиуретан, Fancy Fair/ff CR30/10',
#  'Муляж Груша, желтый, 9,5 см, полиуретан, Fancy Fair/ff LI95-01',
#  'Муляж Персик, оранжевый, 9 см, полиуретан, Fancy Fair/ff TZ90',
#  'Набор фужеров Luminarc ДАМПЬЕР СИЛЬВЕР для вина 260 мл 6 шт H7939',
#  'Цветок искусственный Гвоздика тканевая красная 50 см',
#  'Ёрш унитазный с деревянной ручкой , Ваир 1712012',
#  'Сумка-тележка хозяйственная Gimi Market желтая',
#  'Герань домашняя (пеларгония зональная) цветущая , D12, H25-30, красная, махровая',
#  'Мусорный контейнер в ванную комнату BOWL-SHINY полистирол 14х16 см белый, Spirella, 1014964',
#  'Сумка-тележка хозяйственная Andersen Scala Shopper Plus, Elba, черная 133-051-80',
#  'Сумка-тележка хозяйственная Rolser Jet Cuadro MH Joy серо-желтая, JET019 marengo JOY',
#  'Плед флисовый 100% полиэстер 185х240 см бежевый, Wellness, WP184-Айленд_2',
#  'Скатерть Династия 100% полиэфир прямоугольная 350х180 см сливочная, Wellness, WT355-Династия*02',
#  'Рассада зелени для кухни Лаванды в кассете по 6 шт',
#  'Рассада зелени для кухни Розмарина в кассете по 6 шт',
#  'Рассада зелени для кухни Тимьяна в кассете по 6 шт',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, лососевая, махровая',
#  'Коврик хлопковый 40х60 см цвета в ассортименте 6194',
#  'Коврик хлопковый 45х75 см цвета в ассортименте 6195',
#  'Сушилка для белья на батарею, СБ5-45, НИКА',
#  'Таз пластмассовый 24,0 л пищевой круглый (Иж), 1404006',
#  'Кувшин пластмассовый с крышкой "Кумган" 2,0 л 1408003',
#  'Муляж Перец Чили в связке, зеленый, 60 см, полиуретан, Fancy Fair/ff GP60',
#  'Адиантум Лиза d-12 см',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, белая, махровая',
#  'Ковер придверный "MULTY RUS" 120х180см., коричневый, РР214/07034',
#  'Перчатки латексные № 3 для дома утолщенные, Rozenbal, R105628',
#  'Стремянка алюминиевая Hailo 4302-301 LivingStep Comfort PLus 2 ступенчатая алюминиевая',
#  'Пеларгония зональная диам. 12 см темнорозовая полумахровая',
#  'Сумка-тележка хозяйственная Gimi Market синяя',
#  'Гладильная доска Gimi Jean Green Line 107х30 см',
#  'Лестница-стремянка Dogrular Ufuk оцинкованная 7-ми ступенчатая',
#  'Толкушка для картофеля из нержавеющей стали Proline, Leifheit, 03032',
#  'Тележка багажная DELTA ТБР-20 коричневый с оранжевым грузоподъемность 25 кг сумка и 50 кг каркас РОССИЯ',
#  'Готовая скатерть Ажурная Dia Rose круглая д.152 белая, 5173, Towa Co., LTD',
#  'Сушилка для белья напольная Gimi Modular 3 Lux Silver',
#  'Искусственный цветок Роза Маргарита пластик 58 см',
#  'Простыня на резинке односпальная Wellness RM90-Арктик 100% хлопок, 90х200 см, белая',
#  'Сумка-тележка хозяйственная Gimi Bella синяя',
#  'Чайник эмалированный "Алые маки" со свистком 2,5 л. ЕМ-25001/11',
#  'Ёрш для бутылки из натурального волокна и металла 23 см кремовый, Burstenmann, 0473/0003',
#  'Таз пластмассовый 18,0 л квадратный (ТП-18) "Пластхозторг", 1404042',
#  'Таз пластмассовый 15,0 л пищевой овальный "Ekko" 2775, 1404032',
#  'Таз пластмассовый 18,0 л пищевой (Иж), 1404047',
#  'Таз пластмассовый 20,0 л пищевой (Минеральные воды), 1404045',
#  'Набор вешалок для костюма 45см 4шт цвет: кремовый, Attribute, AHP224',
#  'Таз пластмассовый 20,0 л пищевой овальный "Ekko" 2776, 1404043',
#  'Штора текстильная для ванны и душа полиэстер, "Разноцветные пузырьки" 180х200см, розов/желт/белый, DSCN4061',
#  'Сушилка для белья потолочно-настенная Gimi Lift 220, 5030',
#  'Настенная сушилка для белья Gimi Brio Super 60',
#  'Сушилка для белья потолочная Лиана 2,2 м 1703010',
#  'Банка со стеклянной крышкой, COLOR SERIES, круглая, 10*10*12 см, 300 мл VALIANT, JP-S300',
#  'Банка со стеклянной крышкой, COLOR SERIES, круглая, 7*7,6*12,5 см, 280 мл VALIANT, JP-S280',
#  'Стяжка оконная с болтом СТ-55 цинк, 1108354',
#  'Сумка-тележка 3-х колесная Gimi Tris Floral синяя',
#  'Сушилка для белья потолочная ЛИАНА ЛЮКС 140, ЛДН-Т',
#  'Крючок одежный тройной латунь (Б-47), 1110182',
#  'Набор ковров для ванной комнаты, "Офелия", 40х50/50х80см., серый/бежевый, NTBM50804050-26-190',
#  'Сушилка для белья ВИОЛЕТ Ricko 5м Rk-5/100 настенная',
#  'Комплект для ванной и туалета Dasch 50х80 см и 55х55 см TL-2-E Лавр бежевый 5755',
#  'Тележка багажная DELTA ТБР-20 синий грузоподъемность 25 кг сумка и 50 кг каркас РОССИЯ',
#  'Сумка-тележка хозяйственная Andersen Scala Shopper, Elba, черная 112-051-80',
#  'Муляж Апельсин 8 см полиуретан',
#  'Муляж Яблоко зеленый 9 см полиуретан',
#  'Сумка-тележка хозяйственная Welfull Daisy, черная 100-002-80',
#  'Кампанула махровая двухцветная d-10 см',
#  'Пеларгония душистая d-13 см',
#  'Сушилка для белья Gimi Alablock',
#  'Тележка багажная DELTA ТБР-22 синий грузоподъемность 20 кг сумка и 50 кг каркас РОССИЯ',
#  'Пеларгония зональная диам. 12 см красная махровая',
#  'Пеларгония зональная диам. 12 см ярко красная махровая',
#  'Пеларгония зональная махровая белая',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, малиновая с красным, полумахровая',
#  'Декоративная композиция искуственных цветов Букет Роз три цветка, цвет в ассортименте 85 см',
#  'Искусственный цветок Роза бархатная с закрытым бутоном 72 см цвет в ассортименте',
#  'Сумка-тележка хозяйственная Rolser Jet C. Capri Joy синяя, JET017 azul JOY',
#  'Противень прямоугольный алюминиевый 340х240х25 см ЭКСПЕРТ, Scovo, СЭ-052, /1503028',
#  'Сушилка для белья потолочно-настенная Gimi Lift 180',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, малиновая, махровая',
#  'Калатея Микс d-12 см',
#  'Коврик придверный влаговпитывающий ребристый из полимерных материалов 90х120 см серый, Vortex, K041',
#  'Нолина в цветной керамике d-7 см',
#  'Плечики пластмассовые (Размер 48 - 54 ) "МП", 1205160',
#  'Подушка декоративная флисовая 100% полиэстер 40*40 см синяя клетка, Wellness, WP44-Атланта_34',
#  'Полотенце кухонное Мила* mix, 100% хлопок 170 г/м2, 38х63,5 см, цвета в ассортименте, Wellness, 4630005366090',
#  'Хлорофитум d-13 см',
#  'Цикламен d-13 см',
#  'Пеларгония зональная диам. 12 см розовая полумахровая',
#  'Пеларгония зональная диам. 12 см розовая с малиновым полумахровая',
#  'Пеларгония зональная диам. 12 см розово-малиновая простая',
#  'Пеларгония зональная махровая лососевая',
#  'Крепеж для пружины дверной, 1107055',
#  'Пружина дверная 240 мм оцинкованная (Д-19 мм) без крепления, 1107014',
#  'Глоксиния d-13 см',
#  'Азалия индика Биколор d-12 см',
#  'Гортензия Микс d-12 см',
#  'Хризантема Космо микс d-12 см',
#  'Сушилка для белья потолочная Лиана 1,6 м 1703005',
#  'Муляж Тыквы d-8 см',
#  'Сушилка для белья на батарею, СБ5-65, НИКА',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, розовая с малиновым, полумахровая',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, розовая, махровая',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, розово-красная, полумахровая',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, розово-малиновая, простая',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, сиренево-красная, простая',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, сиреневый, простая',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, темнорозовая, полумахровая',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, ярко красная, махровая',
#  'Коврик интерьерный для кухни Tuscan Wine из ПВХ прямоугольный 45х75 см, Apache, 4660',
#  'Петля приварная гаражная d 14х90 мм с шаром, 1103003',
#  'Сушилка для белья Gimi Lampo',
#  'Гладильная доска НИКА ВЕРОНА 1 чехол ОДРИ 122х42 см ДВ1о',
#  'Стеклянная крышка для сковороды ALPENKOK 24 см AK-24GL',
#  'Стеклянная крышка для сковороды ALPENKOK 28 см AK-28GL',
#  'Салфетка Protec Textil Lino 30х43 см серая 6226',
#  'Чехол Eurogold Clean Metallic металлизированый с поролоном для досок 110х30-114x34 см C34F3M',
#  'Вкладыши для хранения посуды 2 шт d-38 cm MARMITON, LG17056',
#  'Миксер DELTA LUX DL-5068 серо-голубой 400 Вт 4 насадки 5 скоростных режимов турборежим',
#  'Коврик влаговпитывающий Индия 50*80 см зигзаг серый 6204',
#  'Кофр для хранения медикаментов Hausmann 9 отделений 30x22x12 см 4W-107',
#  'Стиральный биопорошок BONSAI концентрированный для белого белья Россия 4607974420573',
#  'Чистящий крем для трудновыводимых пятен Mama Lemon stain remover 500 гр Индонезия 8998866106207',
#  'Сушилка для белья потолочно-настенная Gimi Lift 240, 5031',
#  'Tepмокружка AVEX Recharge 500 мл голубой AVEX0681',
#  'Чехол для гладильной доски Zalger 520135 140х50 см хлопок поролон для доски 135х45 см',
#  'Щетка для смахивания пыли 60 см разноцветная, Burstenmann, 0528/0000',
#  'Мирт d-20 см h-25 см',
#  'Цветущее комнатное растение Хризантема диаметр горшка 18 см',
#  'Сушилка для белья потолочная Лиана 1,7 м 1703006',
#  'Чайник эмалированный METALLONI со свистком и керамической ручкой "Французский шарм" 2,5 л EM-250X1/28',
#  'Чехол для гладильной доски Zalger 520138 140х50 см металлизированный с поролоном для доски 135х45 см',
#  'Штора для ванной комнаты Diamante 240х200 см бежевая, Bacchetta, 4800',
#  'Стремянки Colombo Leonardo 3 ступени G300A03W черая 3649',
#  'Таз пластмассовый со стиральной доской (Иж), 1404021',
#  'Щетка для посуды *Мила* SV3182 1807009',
#  'Щетка-утюжок с ручкой Миди, Standart, York, G1126',
#  'Светильник настольный 17 LED ламп, светодиодный сенсорный, с диммером 26-0004/W черный, PERFECTOLIGHT',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, белая, полумахровая',
#  'Муляж Лимон желтый 9 см полиуретан',
#  'Кориандр в кассете 6 шт',
#  'Рассада зелени для кухни Базилик Арарат, кассета по 6шт',
#  'Рассада зелени для кухни Петрушка Универсал, кассета по 6шт',
#  'Рассада зелени для кухни Шалфея в горшке диам. 9 см',
#  'Чехол для одежды EVA 60х95 см EVE4214',
#  'Чехол для одежды Hausmann розовый принт 60х100 см HM-EA1104',
#  'Чехол для платья из нетканного материала 60*135 см белый, Hausmann, 2B-360135',
#  'Сушилка для белья потолочная Лиана 2,4 м 1703011',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, малиново розовая, простая',
#  'Сушилка для белья Gimi Jolly 18',
#  'Жидкое мыло Vestar Хозяйственное 750 мл Россия 4620757212370',
#  'Ковёр придверный "Лапша" 60х90см коричневый',
#  'Коврик резиновый ажурный Iron Grill 45х75 см 6207',
#  'Пена для ванн Vestar хвойная Пихта 900 мл Россия 4620757212424',
#  'Тележка хозяйственная складная, ТХ0253, 50 кг, Пэмби',
#  'Таз пластмассовый 10,0 л круглый (350х170) "М- пластик" М2506, 1404091',
#  'Таз пластмассовый 13,0 л пищевой с меркой (Минеральные воды), 1404028',
#  'Таз пластмассовый 14,0 л пищевой (Иж), 1404079',
#  'Таз пластмассовый 15,0 л пищевой (Минеральные воды), 1404038',
#  'Таз пластмассовый 16,0 л круглый С12129, 1404034',
#  'Таз пластмассовый 16,0 л пищевой с ручками (С203/303) "Полимербыт", 1404039',
#  'Таз пластмассовый 40,0 л пищевой овальный (Иж), 1404094',
#  'Сумка-тележка 2-х колесная складная Gimi Flexi зеленая',
#  'Гладильная доска НИКА Haushalt M HM 122х40 см',
#  'Подрукавник складной Ника П',
#  'Штора со встроенными кольцами под штангу для ванны и душа жаккард, полиамидное покрытие, 180х200, аквамарин, HSC/ST04/aquamarin',
#  'Штора со встроенными кольцами под штангу для ванны и душа жаккард, полиамидное покрытие, 180х200, голубой, HSC/ST12/blue',
#  'Чехол для гладильной доски Zalger 520125 140х58 см хлопок войлок для доски до 135х53 см',
#  'Штора со встроенными кольцами под штангу для ванны и душа жаккард, полиамидное покрытие, 180х200, бежевый, HSC/ST05/beige',
#  'Штора со встроенными кольцами под штангу для ванны и душа жаккард, полиамидное покрытие, 180х200, белый, HSC/ST04/white',
#  'Иссоп лекарственный d-9 см',
#  'Сантолина d-9 см',
#  'Сушилка для белья Attribute МИНИ 2,5 м навесная ADM125',
#  'Аспарагус d-12 см h-30 см',
#  'Афеляндра скуарроса Дания Микс в кашпо с автополивом',
#  'Тележка багажная DELTA ТБР-15 цвет в ассортименте грузоподъемность 30 кг РОССИЯ',
#  'Набор сверел по дереву из 8 шт, 3-10 мм *888* 6867540, 0512261',
#  'Сверло-фреза, 6 мм, нитрид титана *888* 6862060, 0512262',
#  'Сверло-фреза, 8 мм, нитрид титана *888* 6862080, 0512263',
#  'Пеларгония зональная диам. 12 см лососевая махровая',
#  'Гладильная доска ДСП "БЭЛЛЬ-ЮНИОР2", 112*34,5, БЮ2, НИКА',
#  'Контейнер для овощей Полимербыт 3-х секционный лоток 9 л 4312600',
#  'Сушилка для белья ЛИАНА ЛЮКС 130 см потолочная',
#  'Стремянка алюминиевая 5 ступеней, СА5, НИКА',
#  'Чехол для гладильной доски UNIVERSAL 160х60 см, Attribute, ABU004',
#  'Гладильная доска Sarayli Orion 130x44 см',
#  'Мусорный контейнер Hailo ProfiLine SoLid 14 0514-089 14 л белый',
#  'Гладильная доска перф металл "НИКА 10+", 122*40, Н10+, НИКА',
#  'Сушилка для белья RAINBOW COLOR напольная из хромированной стали 201,5х55х93 см, Gimi',
#  'Зубная паста Zact с эффектом отбеливания кофейного и никотинового налета 150 г 8806325-603849',
#  'Зубная паста Zact Lion Smokers Toothpaste 100 г 8850002805040',
#  'Зубная паста Zact Lion Whitening Toothpaste 100 г 8850002805064',
#  'Нож для тонкой нарезки ALPENKOK из нержавеющей стали пилообразный "Comfort" 12,7 см синий AK-2082',
#  'Антуриум андрианум Блэк d-12 см',
#  'Комнатное растение в горшке Аспарагус Мейера, d12, h30',
#  'Молодило Микс d-9 см',
#  'Фиалка d-11 см',
#  'Таз пластмассовый 32,0 л с ручками "Полимербыт" С202, 1404052',
#  'Таз пластмассовый строительный круглый 65 л, 1404076',
#  'Гладильная доска-стремянка 95х33 см, 848N, DASCH',
#  'Гербера d-13 см',
#  'Душица обыкновенная d-9 см',
#  'Мелисса лекарственная d-9 см',
#  'Роза кордана Красная Мерседес d-10 см',
#  'Роза кордана красная d-10 см',
#  'Фиалка Карнавал d-12 см',
#  'Хризантема Белая Кристалл d-15 см',
#  'Хризантема Красная Тобаго d-15 см',
#  'Сушилка для белья потолочная Лиана 2,0 м 1703009',
#  'Тележка хозяйственная складная, ТХ0252, 30 кг, Пэмби',
#  'Карниз алюминиевый телескопический для штор Spirella / Спирелла Magic, хром, 125-220 см, 1050767',
#  'Штора для ванной комнаты Cannetto 240х200 см коричневая, Bacchetta, 4061',
#  'Веник сорго с деревянной ручкой с 4-мя швами, Rozenbal, R206204',
#  'Пеларгония зональная диам. 12 см малиново-красная простая',
#  'Муляж ГРАНАТ 9 см красный',
#  'Гладильная доска Sarayli New Elegant 125x45 см',
#  'Салфетка Protec Textil Polyline 30х43 см Аметист белая 6230',
#  'Лестница-стремянка Dogrular Ufuk Al алюминевая 6-ти ступенчатая',
#  'Ерш для унитаза Spirella VENISE с подставкой керамический 4007036',
#  'Контейнер для мусора FLIP BIN CURVER 25 л красный 02171-547-00',
#  'Контейнер для мусора FLIP BIN CURVER 25 л оранжевый 02171-535-00',
#  'Стремянка металлическая 4 ступени, СМ4, НИКА',
#  'Швабра многофункциональная, Rozenbal, R212522',
#  'Ящик для хранения TEXTILEBOX CURVER 5,7 л 34x20x13 см прозрачный 03003-001-00',
#  'Щетка палубная 215х80х20 мм 6-рядная без черенка угловой держатель 58 1801088',
#  'Гладильная доска перф металл "ЭЛЬЗА Премиум", 122*40, ЭЛП, НИКА',
#  'Скатерть Лувр 100% полиэфир овальная 300х150 см салатовая Wellness WTO305-Лувр*18',
#  'Подголовник для ванной комнаты из ПВХ 25х34 синий, Bacchetta, 1620',
#  'Гладильная доска фанера "СТЕЛЛА Премиум 2", 122*38, СТП2, НИКА',
#  'Пеларгония зональная диам. 12 см белая махровая',
#  'Пеларгония зональная диам. 12 см коралловая полумахровая',
#  'Пеларгония розоцветная РЕД РОЗЕБУД молодые растения',
#  'Сумка-тележка хозяйственная Rolser Jet Joy синяя, JET001 azul JOY',
#  'Банка с металлической крышкой, COLOR SERIES, круглая, 11*11*12 см, 960 мл VALIANT, JK-D960',
#  'Банка с металлической крышкой, COLOR SERIES, круглая, 11*11*17 см, 1350 мл VALIANT, JK-C1350',
#  'Ведро для мусора Hailo 0516-570 16 л, бежевый',
#  'Штора текстильная для ванны и душа полиэстер, "Бамбук" 180х200см, зелёный/белый, DSCN3579',
#  'Вешалка деревянная с расширенными плечиками и перекладиной 44,5х23 см см серый JAPANESE BLACK VALIANT JB-19708',
#  'Вешалка для блузок 41 см черный Attribute AHM791',
#  'Вешалка с закругленными плечиками без перекладины с противоскользящим покрытием Valiant 226B10 черный',
#  'Гладильная доска Sarayli Tamara 125x42 см',
#  'Коврик влаговпитывающий ребристый 50х80 см Стандарт черный 5877',
#  'Коврик влаговпитывающий ребристый 60х90 см Стандарт зеленый 5884',
#  'Коврик придверный грязеулавливающий резиновый Finger 40х60',
#  'Короб стеллажный с крышкой большой, 30*40*25 см, EXPEDITION VALIANT, EX-BOX-LM',
#  'Короб стеллажный с крышкой малый, 28*30*16 см, EXPEDITION VALIANT, EX-BOX-LS',
#  'Коробка для хранения на молнии из синтетического волокна Hausmann, 35,5х20,5х13,5 см, зеленая, BB211-3',
#  'Набор вешалок мягких тканевых с перекладиной 38х15 см 2 шт Валиант / Valiant VAL 7054sb',
#  'Наматрасник Wellness WM180, 100% хлопок, 180х200 см, стеганый белый, 4607101067749',
#  'Наматрицник-чехол Natures Стебель бамбука СБ-Н-1-1 односпальный, бамбуковый, 90х200 см, молочный',
#  'Насадка для швабры многофункциональной из микрофибры, Rozenbal, R810001',
#  'Перчатки латексные 10 шт размер S, R105816, ROZENBAL',
#  'Сушилка для белья напольная Gimi Tempo Super',
#  'Таз пластмассовый 6,0 л пищевой квадратный "Тюльпан" ПЦ2950, 1404003',
#  'Швабра многофункциональная ROZENBAL R212522-1',
#  'Швабра САЛЬСА треугольная МИНИ, Y8110',
#  'Щетка для посуды из искусственного волокна и пластмассы 20 см белая, Burstenmann, 0703/0065',
#  'Тарелка обеденная Luminarc ГРИН ФОРЕСТ 26 см H7239',
#  'Рассада зелени для кухни Лаванды в горшке диам. 9 см',
#  'Рассада зелени для кухни Розмарина в горшке диам. 9 см',
#  'Рассада зелени для кухни Тимьяна в горшке диам. 9 см',
#  'Коврик придверный, полукруглый из резины и кокоса, 40х68 см, Format Mezzaluna, Розетта, коричневый, PHP SRL, 20657',
#  'Ножеточка универсальная "Рыбка" 1519028',
#  'Вешалка-плечики без эссенции цвет тёмно-розовый FWM-002/Quartz pink',
#  'Искусственный цветок пластиковый Мак 3 бутона 48 см',
#  'Искусственный цветок Ромашка пластик 45 см',
#  'Цветок искусственный Гвоздика пластиковая одиночная в ассортименте 50 см',
#  'Цветок искусственный Мак 45 см пластик',
#  'Цветок искусственный Мак 55 см пластик',
#  'Цветок искусственный Нарцисс одиночный в ассортименте 35 см',
#  'Цветок искусственный Роза Алая бархатная раскрытый бутон 63 см',
#  'Цветок искусственный Ромашка 3 цветка 50 см пластик',
#  'Цветок искусственный Тюльпан 45 см пластик цвет в ассортименте',
#  'Цветок искусственный Тюльпан в ассортименте одиночный 63 см',
#  'Салфетка Камушки транспарент 30*40 см 5187 Dasch',
#  'Тележка багажная DELTA ТБР-22 коричневый грузоподъемность 20 кг сумка и 50 кг каркас РОССИЯ',
#  'Гладильная доска Colombo Avantgard 120х40 см',
#  'Бегония ампельная, диам. 12 см',
#  'Рассада Пеларгония (герань) зональная Блу Айз Mix смесь объем 0,5 л',
#  'Хризантема Корейская смесь окрасок объем 0,75 л',
#  'Многолетнее растение Душица-орегано розовый объем 0,5 л',
#  'Пеларгония зональная диам. 12 см белая полумахровая',
#  'Чехол для гладильной доски с дизайном Venezia 140х55 см из хлопка',
#  'Настольная гладильная доска фанера, 85*30, НД, НИКА',
#  'Кувшин пластмассовый с крышкой 2,0 л, (S-751) "Пластхозторг" 1408004',
#  'Розмарин d-12 см',
#  'Сиденье в ванну раздвижное, белый, СВ5, НИКА',
#  'Сушилка для белья Gimi Extension',
#  'Масленка КОРОВКА с крышкой 17см, 73115, Luminarc, Франция',
#  'Плечики пластмассовые Размер 52 - 54 Тула 1205158',
#  'Сушилка для белья Eurogold STABILO 18 напольная 0503 SE',
#  'Стремянка бытовая Framar Slimmy 3 ступени',
#  'Сумка-тележка 2-х колесная Gimi Argo фуксия',
#  'Подрукавник Gimi Planet для гладильной доски',
#  'Чехол для гладильной доски I LOVE GIMI L из полиэстера и хлопка 136*58 см, Gimi',
#  'Штора для ванной комнаты Quadretto 240х200 см белая, Bacchetta, 4062',
#  'Утюг электрический с керамическим покрытием DELTA LUX DL-350 зеленый, 2200 Вт , РОССИЯ',
#  'Чехол для гладильной доски Attribute METAL 140х60 см ABM106',
#  'Муляж ЯБЛОКО 9 см красное',
#  'Гладильная доска Attribute ХОМИ ТОП 124х40 см синяя ABH010',
#  'Чехол для гладильной доски METAL 135х53 см, Attribute, ABM105',
#  'Корыто оцинкованное 45 л бесшовное, 1301031',
#  'Тележка багажная DELTA ТБР-20 черный с серым грузоподъемность 25 кг сумка 50 кг каркас РОССИЯ',
#  'Штора для ванной комнаты 182х182 см ПВХ Meiwa, Krackle прозрачный 5911',
#  'Холодная сварка Mastix 55г для труб и батарей, 1205197',
#  'Холодная сварка Mastix 55г универсальная, 1205037',
#  'Гладильная доска НИКА БЭЛЛЬ 106,5х29 см Б',
#  'Муляж Вишня 3 см 10 шт полиуретан',
#  'Муляж Груша желтый 9,5 см полиуретан',
#  'Муляж Мандарин оранжевый 8 см полиуретан',
#  'Муляж Перец Чили в связке, красный, 60 см, полиуретан, Fancy Fair/ff RP60',
#  'Муляж Чеснок в связке 60 см полиуретан',
#  'Сервировочная салфетка ПВХ 26х41 см Ванда 6001',
#  'Коврик противоскользящий кружевной 88х38 см прозрачный 5528',
#  'Штора для ванной комнаты Bacchetta City текстильная 180х200 см 6023',
#  'Гладильная доска НИКА СТЕЛЛА Классик 1 122х34,5 см СТК1',
#  'Штора для ванной комнаты Bacchetta Dama текстильная 180х200 см 3655',
#  'Салатник Luminarc КУТЮР 16 см H3386',
#  'Салатник Luminarc КУТЮР 27 см H3529',
#  'Тарелка десертная КУТЮР 20,5 см J2402 Luminarc',
#  'Тарелка суповая КУТЮР 22,5 см J2397 Luminarc',
#  'Коврик придверный полипропиленовый с ПВХ STEP IN TRADITIONAL 90х150 см коричневый',
#  'Сумка-тележка хозяйственная Andersen Scala Shopper Plus, Lini, синяя 133-108-90',
#  'Гладильная доска НИКА SOPHY КОРИЦА HSK 123х46 см',
#  'Коврик противоскользящий пузырьки 70х38 см прозрачный 5523',
#  'Чехол для гладильной доски универсальный с поролоном 2, 1290 х 500, ЧП2, НИКА',
#  'Сумка-тележка хозяйственная GIMI Argo голубая',
#  'Муляж Ананас светло-коричневый 10 см полиуретан',
#  'Муляж Баклажан 18 см',
#  'Муляж Банан желтый 21 см полиуретан',
#  'Муляж Груша мини 2 шт желтая 4 см',
#  'Муляж Манго оранжевый 13 см полиуретан',
#  'Муляж Морковь 16 см',
#  'Муляж Персик 9 см полиуретан',
#  'Муляж Тыквы d-20 см',
#  'Муляж Черешня 10 штук d 2,5 см, цвет в ассортименте',
#  'Сумка-тележка хозяйственная Rolser BAB010 negro JOY-1800 черная',
#  'Чехол для гладильной доски Zalger 520133 120х40 см хлопок поролон для доски 115х35 см',
#  'Сумка-тележка 2-х колесная Gimi Galaxy черная',
#  'Сковорода Scovo Эксперт Дем СЭ-040 для блинов алюминиевая с антипригарным покрытием, 25 см, 1503020',
#  'Герань домашняя (пеларгония зональная) цветущая , D12, H25-30, лососевая, полумахровая',
#  'Коврик придверный с дизайном, из резины и кокоса Aberdeen Welcome 45x76, 4395',
#  'Коврик придверный Redstone Mix из полиэстера и переработанной резины 60х91 см серо-коричневый, Apache, 4651',
#  'Коврик придверный Stonehedge Grey из полиэстера и переработанной резины 60х91 см серый, Apache, 4652',
#  'Сумка-тележка хозяйственная Rolser IMX005 marengo Logic DOS+2 серая',
#  'Банка стеклянная STEEL TOUCH 1700 мл, Attribute, ABS017',
#  'Тарелка десертная СТОУНМАНИЯ ОРАНЖ 20,5 см H3557 Luminarc',
#  'Тарелка обеденная СТОУНМАНИЯ ОРАНЖ 25 см H3556 Luminarc',
#  'Тарелка суповая СТОУНМАНИЯ ОРАНЖ 20 см H3558 Luminarc',
#  'Скатерть из ПВХ MEIWA FPLUS-PLAIN SARASA AZ BE овальная 152х228 см бежевая 5789',
#  'Муляж Вишня на магните',
#  'Сумка-тележка 2-х колесная складная Gimi Flexi серая',
#  'Сумка-тележка 2-х колесная Gimi Ideal синяя',
#  'Шнур резиновый для тележки 110 см, 1209002',
#  'Шнур резиновый для тележки 80 см, 1209001',
#  'Рассада зелени для кухни Душицы в горшке диам. 9 см',
#  'Сумка-тележка хозяйственная Rolser MOU041 malva RD6 сиреневая',
#  'Таз пластмассовый строительный прямоугольный 80 л, 1404085',
#  'Урна уличная "Гео", Hobbyka/Хоббика, 59*37,5см, сталь',
#  'Скатерть Азалия 88% полиэфир 12% хлопок прямоугольная 350х150 см персиковая Wellness MC355-Азалия*05',
#  'Сумка-тележка хозяйственная Gimi Bella серая',
#  'Чайный набор Luminarc РЕЙНБОУ 220 мл J5978',
#  'Штора для ванной текстильная180х200 Quadretto белая, Bacchetta, 3003',
#  'Пеларгония зональная диам. 12 см малиновая махровая',
#  'Пеларгония зональная диам. 12 см розовая махровая',
#  'Пеларгония зональная розоцветная РЕД РОЗЕБАД (Red rosebud)',
#  'Набор эмалированных салатников METALLONI Ветка рябины EM-00003A/31 12,14,16 см',
#  'Мыло жидкое reffil Mama Utimate Облепиха 500 мл Россия 8809193042321',
#  'Набор вешалок мягких тканевых с перекладиной и клипсами 48х23 см 2 шт Валиант / Valiant VAL 7057gc',
#  'Стремянка 5 ступенчатая Hailo 8925-901 L9 алюминиевая',
#  'Антуриум андрианум Ванилла d-12 см',
#  'Рыбочистка металлическая, 1216396',
#  'Сиденье для унитаза Росспласт АЖУР белое РП-813',
#  'Коврик придверный Attribute NATURE кокосовый 60x40 см AMC015',
#  'Овощеварка алюминиевая Scovo МТ-045, Хозлэнд, 1502079',
#  'Сметка с совком Престиж, York, G6207',
#  'Коврик придверный, полипропилен, 40х70 см, Kokarda, Спящий кот, бежевый, PHP SRL, 20734',
#  'Муляж Баклажан мини 2 шт',
#  'Муляж Гранат мини 4 шт',
#  'Муляж Перец Чили мини 2 шт, красный 7 см',
#  'Чехол для гладильной доски BASIC 120х40 см, Attribute, ABB004',
#  'Халат вафельный Виктория_3-42 , 100% хлопок 265 g/m2, размер 52-54, салатовый, Wellness, 2000000168616',
#  'Измерительный алюминиевый угольник, 20*30 см, Truper, E-8X12/14386',
#  'Линейка, длина 30 см, Truper, RGL-30/14387',
#  'Сумка-тележка хозяйственная GIMI Ideal серая (tortora)',
#  'Набор фужеров для вина АЛЛЮР 6шт 250мл, G5747, Luminarc, Франция',
#  'Набор фужеров для вина МАСКАРАД 6шт 250мл, G5544, Luminarc, Франция',
#  'Сушилка для белья ЛИАНА ЛЮКС 190 см потолочная',
#  'Сушилка для белья Leifheit 81570 PEGASUS 150 87х157х55 см',
#  'Сумка-тележка хозяйственная Rolser BAB008 marengo JOY-1800 серая',
#  'Чехол для гладильной доски Leifheit Beach and Bubbles 130x45 см 71596',
#  'Терка WEBBER из нержавеющей стали ВЕ-048 4 грани 20 см с красной ручкой',
#  'Терка WEBBER из нержавеющей стали ВЕ-054 6 граней 21 см',
#  'Вилка столовая Better цветной горох BT-C2003E-TD1/D1',
#  'Контейнер для приготовления 2-х яиц ГЛАЗУНЬЯ Полимербыт C452',
#  'Кружка 350 мл ROSARIO Радуга керамическая коричневый Ф13-005L',
#  'Кружка для чая Ягода клубника 250 мл 1606-Д',
#  'Кружка Luminarc ЛИЛИ ФЛАУЭР 320 мл J8565-1',
#  'Ложка обувная металлическая крашенная 43 см с крючком, 1205156',
#  'Лопатка Attribute BAMBOO AGB110',
#  'Лопатка c прорезями Attribute BAMBOO AGB111',
#  'Набор фужеров для красного вина 235 мл, 6 шт., серия Касабланка, 51258B',
#  'Набор фужеров для шампанского ФРЕНЧ БРАССЕРИ 6шт 170мл, H9452, Luminarc, Франция',
#  'Полотенце махровое Гармония, 100% хлопок 335 г/м2, 32х70 см, Wellness, 4630005362832',
#  'Салфетка махровая Радуга в разноцветную полоску, 100% хлопок 312 г/м2, 31х31 см, Wellness, 4630005360012',
#  'Салфетница металлическая WEBBER с хромированным покрытием 14,7*4*9 см BE-0293',
#  'Стакан низкий Лабиринт 250 мл для напитков 05с1262',
#  'Стакан пластмассовый 300 мл, конус. (К-308) "Пластхозторг" 1535027',
#  'Столовая ложка Better цветной горох BT-C2003E-TD2/D1',
#  'Чайная ложка Better цветной горох BT-C2003E-TD3/D1',
#  'Цветок искусственный Крокус 20 см',
#  'Цветок искусственный Гербера, 45см',
#  'Ковер придверный имитация травы 60х90см , цвет серый',
#  'Тележка багажная DELTA ТБР-23 грузоподъемность 50 кг РОССИЯ',
#  'Тарелка десертная ИРИС D3700 Luminarc',
#  'Гладильная доска Attribute TEFLONIX 130х46 см ABT142',
#  'Коврик для ванной комнаты GOBI полиэстер 120х70 см темно-зеленый, Spirella, 1012778',
#  'Альбука Спиралис Фризл-Сизл d-12 см',
#  'Коврик Sochi 50х80 см коричневый 5801',
#  'Овощечистка с плавающим лезвием Comfortline из нержавеющей стали и пластика 11 см белая, Leifheit, 03151',
#  'Бальзамин новогвинейский d-13 см',
#  'Бегония клубневая d-13 см',
#  'Крассула овата d-10 см',
#  'Гладильная доска НИКА BRUNA M HBM 122х40 см',
#  'Артемизия (Полынь горькая) d-9 см',
#  'Пеларгония зональная махровая микс d-12 см',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, красно-розовая, простая',
#  'Насадка к швабре FLEXINETT пластик + микрофибра, Rozenbal, R212585',
#  'Средство для удаления известкового налета с поверхностей сантехнических приборов DECS Антикальций 500 мл Россия 4660015923266',
#  'Фиалка Микс d-9 см',
#  'Коврик ворсовый для ванной комнаты OrthoSpa River Rocks grey из микрофибры и ПВХ прямоугольный 50х85 см серо-белый, Apache, 4666',
#  'Вешалка напольная ATLANT 90х42 см VATL-1 светлая Степанов',
#  'Сумка-тележка 2-х колесная Gimi Galaxy голубая',
#  'Тележка хозяйственная РОЛЛА с крыльями, Attribute, ATT101',
#  'Бензин для зажигалок, 1205214',
#  'Скатерть прямоугольная Ажурная Imperial 140х200 см бежевая с тесненым рисунком Towa Co 5174',
#  'Паста для полировки "ГОИ" 25 гр',
#  'Цветок искусственный Гортензия, 58 см, цвет в ассортименте',
#  'Гладильная доска НИКА ДСП ЭКОНОМ 106,5х29 ЭК1',
#  'Сумка-тележка хозяйственная GIMI Argo салатовая',
#  'Сумка-тележка хозяйственная Gimi Easy Go синяя',
#  'Петля-стрела ПС-286 мм (Рыбинск), 1104019',
#  'Сушилка для белья ЛИАНА ЛЮКС 120 см потолочная',
#  'Скатерть из ПВХ MEIWA FPLUS-171 AZ WH/BE овальная 132х178 см бело-бежевая 5785',
#  'Подголовник для ванной комнаты из ПВХ 25х34 Mickey, Bacchetta, 4811',
#  'Сушилка для белья потолочная Zalger Lift Comfort 520 180 см 9 м',
#  'Лаванда d-9 см',
#  'Мята d-9 см',
#  'Сушилка для белья ВИОЛЕТ FH COLOR LUX 22 м белая ВЛ867',
#  'Муляж Виноград зеленый 26 см полиуретан',
#  'Чайник электрический пластиковый ВАСИЛИСА T7-1100 белый с голубым 1100 Вт 1 л',
#  'Вешалка-стойка № 9 Дерево ЗМИ медный антик ВНП 211 М',
#  'Стремянка металлическая 3 ступени, СМ3, НИКА',
#  'Муляж Виноград желтый 24 см полиуретан',
#  'Муляж Желудь 2 шт',
#  'Муляж Яблоко, оранжевый, 8,5 см, полиуретан',
#  'Сумка-тележка GIMI Argo синяя',
#  'Каланхое каландива белое d-7 см',
#  'Примула акаулис Микс d-10 см',
#  'Держатель для туалетной бумаги С373 "Полимербыт" 1713006',
#  'Ёрш унитазный с подставкой WC "Люкс", Мультипласт, 1712007',
#  'Пробка для ванны резиновая (Д-40 мм) 1206155',
#  'Штора для ванной с кольцами RL-0071 Мыльные пузыри 180х180 см',
#  'Чехол для гладильной доски Zalger 520116 130х46 см хлопок для доски 125х42 см',
#  'Чехол для гладильной доски Zalger 520124 140х58 см хлопок для доски до 135х53 см',
#  'Измельчитель овощей ручной ШК-4 деревянный, 3 ножа, 1516020',
#  'Сумка-тележка DELTA ТБР-20 синий грузоподъемность 25 кг сумка и 50 кг каркас РОССИЯ',
#  'Коврик придверный из резины и кокоса, 40х68 см, Format Classic, Соломка, коричневый, PHP SRL, 20135',
#  'Лоток для холодца эмалированный 1,5 л с пластмассовой крышкой с рисунком С-2508Кп/4 Стэма 1506085',
#  'Сумка-тележка GIMI Easy Go красная',
#  'Вешалка-плечики 3 шт без эссенции цвет светло-бирюзовый FWM-002/Aruba blue',
#  'Вешалки мягкие для деликатных вещей 3 шт желтые',
#  'Губка спираль металлическая EUROHOUSE 2 шт EH3599',
#  'Перчатки латексные 10 шт, р-р М, R105817, ROZENBAL',
#  'Перчатки резиновые универсальные Centi, р-р M, York, G9212',
#  'Чехол для одежды большой 137х60х10 см светло-бежевый Валиант / Valiant TR-107H',
#  'Чехол для одежды EVA 150x65 см MHE017',
#  'Ёрш унитазный пластмассовый, Ваир 1712002',
#  'Кофр для хранения Hausmann подкроватный 80х40х15 см 2B-28040',
#  'Сумка-тележка GIMI Argo красная',
#  'Салфетка Protec Textil Lino 30х43 см шоколад 6222',
#  'Корзина для белья INFINITY CURVER 59 л белая 04754-N23-00',
#  'Пробка для ванны резиновая с цепочкой 1206157',
#  'Сушилка МУЛЬТИ 10м (1002010520027), Attribute, ADM110',
#  'Чехол для гладильной доски Zalger 520111 см металлизированный с поролоном для доски 120х42 см',
#  'Салатник РОМАНТИК ГАРДЕН 17 см J7900 Luminarc',
#  'Фен дорожный DELTA DL-0904 бордовый с черным 2 режима мощности 1400 Вт Россия',
#  'Чайник электрический АКСИНЬЯ КС-1003 корпус из жаропрочного стекла черный 2200 Вт 1,8 л',
#  'Штора для ванной и душа текстильная, 180х200см, "Цветы", голубой, HSP394-B',
#  'Штора для ванной комнаты ПВХ 180х180 см Водоросли, 5919',
#  'Вешалка настенная НИКА ВН3 3 крючка медный антик',
#  'Вешалка самоклеющая на 4 крючка 1110008',
#  'Штора для ванной и душа текстильная, 180х200см."Лилии", бежевый/белый с розовыми цветами, H125',
#  'Салатник АМОРИ БРАУН 16,5 см J2113 Luminarc',
#  'Салатник КОЛОРАМА РЭД 17 см J7772 Luminarc',
#  'Салатник РАПСОДИ ОРАНЖ 16,5 см H8728 Luminarc',
#  'Салатник Luminarc АРТИ ГРИН 16,5 см J1392',
#  'Салатник Luminarc АРТИ ПИНК 16,5 см L2857',
#  'Салатник Luminarc АРТИ ПУРПЛ 16 см G9834',
#  'Салатник Luminarc АРТИ ПУРПЛ 16,5 см L2858',
#  'Салатник Luminarc AMБИАНТЭ АНИС 16 см L6415',
#  'Салатник Luminarc AMБИАНТЭ ОРАНЖ 16 см L6417',
#  'Кружка для чая Сердечки 250 мл ДСГ55029146',
#  'Дендробиум Санок Полар Файр 1 ствол d-12 см',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, красная, простая',
#  'Калоцефалус Брауни крашеный осенний микс d-10 см',
#  'Коврик придверный APACHE 45х76 см Flagstone 5415',
#  'Антижир POSH ONE MAGNUM 828 мл Россия 4580390-927058',
#  'Каллуна Гарден Герлс трехцветная d-12 см h-27 см',
#  'Капсикум Сальса оранжевый d-10 см',
#  'Кофр малый жесткий 28*30*16 см леопард Валиант / Valiant LB301',
#  'Мимоза стыдливая d-9 см',
#  'Набор кухонных полотенец 100% хлопок 200г/м2 46*71 см 2 шт, Wellness, МЕЛИСА_3',
#  'Соланум d-10 см',
#  'Универсальное средство на основе хлора ддля чистки сантехники и других поверхностей DECS Universal 750 мл Россия 4660015923228',
#  'Мантоварка алюминиевая 6,0 л 3 сетки Белая Калитва, Хозлэнд, 1502074',
#  'Гладильная доска НИКА LORA FASHION HLF 123х46 см',
#  'Пеларгония зональная простая цвет фуксии',
#  'Рассада зелени для кухни Мелиссы в кассете по 6 шт',
#  'Гладильная доска НИКА BLUES 124х46 см 5757',
#  'Ложка обувная металлическая крашенная 220, 1205155',
#  'Плечики пластмассовые Размер 48 - 54 МП 1205160',
#  'Ролик для чистки одежды *Clear Line* (20 слоев), 1205060',
#  'Сменный блок для ролика 2 шт (R160071), Rozenbal, R510100',
#  'Таз пластмассовый 4,5 л пищевой "Космея" (Ангора) 1404092',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, ярко розовая, полумахровая',
#  'Пеларгония d-13 см с топпером на День учителя в подарочной упаковке',
#  'Роза патио белая d-12 см h-30',
#  'Роза патио красная d-12 см h-30',
#  'Роза патио оранжевая d-12 см h-30',
#  'Стремянка 5 ступенчатая Hailo 8150-507 L50 алюминиевая с крючком на красной ручке',
#  'Набор бокалов ИМПЕРАТОР 3 шт 170 мл 06707 E5181 Luminarc Франция',
#  'Набор стаканов для виски 300 мл 6 шт серия Карат 52885В',
#  'Термометр на окно уличный на липучках Т-5 h-20 см 1210035',
#  'Термометр уличный оконный ТБ 202 h-20 см 1210036',
#  'Ящик почтовый металлический с ушками для навесного замка Домик 1205251',
#  'Сушилка для белья напольная Gimi Mito, алюминий',
#  'Гладильная доска НИКА ВЕРОНА 1 чехол РЕТРО 122х42 см ДВ1р',
#  'Бархатцы Веселая полянка 0,3 г 4660010777505',
#  'Космея Очаровашка 0,05 г 4660010779578',
#  'Морковь Детская сладость 2 г 4660010775921',
#  'Настурция Драгоценность вишнево-розовая 1 г 4660010773316',
#  'Огурец Засолочный 0,3 г 4660010776102',
#  'Пеларгония зональная розоцветная РЕД РОЗЕБАД',
#  'Петуния Каскад смесь махровая 10 шт 4660010772784',
#  'Сумка-тележка хозяйственная Rolser Jet Joy черная, JET010 negro JOY',
#  'Шило с пластмассовой ручкой утолщенное с крючком, 1205083',
#  'Герань домашняя (пеларгония зональная) цветущая D12, H25-30, красная, полумахровая',
#  'Тарелка обеденная МУНЛАЙТ 25 см H7253 Luminarc',
#  'Скатерть прямоугольная Ажурная Marine 132х177 см бежевая с тесненым рисунком Towa Co 4022',
#  'Сушилка для белья НИКА СБ2Б 20 м',
#  'Сушилка для белья НИКА СБ1 18 м',
#  'Вешалка деревянная с расширенными плечиками и перекладиной 44,5х23 см см белый JAPANESE WHITE VALIANT JW-19708',
#  'Вешалка для брюк Attribute CLASSIC 38 см AHN271',
#  'Набор вешалок для костюма 45 см 4 шт цвет кремовый Attribute AHP224',
#  'Набор вешалок универсальных Attribute SILUET CREAM 45 см 4 шт AHP224',
#  'Банка из стекла для сыпучих продуктов круглой с пластмассовой крышкой и цветной вкладкой 1,0л 10МР-0001',
#  'Корзина для белья KNIT 57 л темно-коричневая, Curver, 03676-X59-00',
#  'Сумка-тележка TWIN стальной каркас 56 л синяя, Gimi',
#  'Гладильная доска НИКА СТЕЛЛА Классик 2 122х34,5 см СТК2',
#  'Тарелка десертная ВОЛАРЭ БЛЭК 22,5 см G9399 Luminarc',
#  'Сушилка для белья потолочная Лиана 1,5 м 1703004',
#  'Сушилка для белья Gimi Dinamik 30',
#  'Таз пластмассовый 6,0 л пищевой М2511, 1404015',
#  'Таз пластмассовый 8,0 л пищевой (Минеральные воды), 1404009',
#  'Ковш пластмассовый Полимербыт С215, 1,5 л 1406006',
#  'Гладильная доска-стремянка DASCH 95х33 см 848N',
#  'Гладильная доска Ника Николь 9 122х40 см',
#  'Кухонные ножницы WEBBER из нержавеющей стали с орехоколом ВЕ-5208',
#  'Набор ножей Attribute CHEF 5 предметов AKF522',
#  'Нож кухонный для мяса с пластмассовой ручкой 305 х 175 мм, "Русская Линия" (НХ-36М), Метиз 1519003',
#  'Нож кухонный для овощей с деревянной ручкой 318 х 200 мм, "Гурман" (НХ-14М), Метиз 1519009',
#  'Нож кухонный универсальный с пластмассовой ручкой 285 х 150 мм, "Русская Линия" (НХ-38М) Метиз 1519022',
#  'Рыбочистка с деревянной ручкой с ножом 1518024',
#  'Тарелка десертная МОКА БРАУН 19 см H7013 Luminarc',
#  'Кисточка силиконовая для выпечки мятная 21х4 см BE-1440S WEBBER',
#  'Кисточка силиконовая для выпечки персиковая 21х4 см BE-1440S WEBBER',
#  'Скребок кондитерский WEBBER BE-0368 лавандовый',
#  'Средство для мытья полов DECS Bleach Лимон 1000 мл Россия 4660015923273',
#  'Комод Эльфпласт Виола 3-х секционный коричневый 339',
#  'Корзина для белья Виолет Ротанг 2350/2 угловая с крышкой 60 л бежевая',
#  'Сушилка для белья на ванну НИКА СБ4',
#  'Картофелемялка металлическая круглая с деревянной ручкой 1531002',
#  'Сушилка для белья потолочная Лиана 1,8 м 1703007',
#  'Салатник ВОЛАРЭ БЛЭК 16 см G9403 Luminarc',
#  'Тарелка суповая ВОЛАРЭ БЛЭК 23 см G9402 Luminarc',
#  'Ароматизированное средство дудаления известкового налета и ржавчины DECS WC Гель Лимон 750 мл Россия 4660015923235',
#  'Бальзам для мытья посуды Mama Ultimate EcoSoda 1000 мл Россия 044684',
#  'Средство для мытья пола ECOMATIC GREEN CLEANER 1000 мл Испания 126109',
#  'Стремянка бытовая Zalger 111-5 алюминиевая 5 ступенек',
#  'Банка стеклянная с крышкой Attribute FLEUR 1350 мл ABF100G',
#  'Банка стеклянная с крышкой Attribute FLEUR 650 мл ABF135W',
#  'Коврик кухонный APACHE Olive Oil Sideboard 56х86 см 5062',
#  'Штора для ванной 180х200 см, Rigone Бежевый',
#  'Алиссум (лобулярия) Снежные одежды 0,2 г 4650091480302',
#  'Гвоздика турецкая Роковая страсть 0,05 г 4660010773231',
#  'Годеция Рембранд 0,1 г 4650091480128',
#  'Календула Пинк сюрпрайз 0,5 г 4650091480203',
#  'Капуста декоративная смесь 0,1 г 4650091480234',
#  'Кореопсис Толл 0,1 г 4650091480258',
#  'Космея Клюквенный клик 0,1 г 4660010770421',
#  'Космея Кэнди страйп 0,3 г 4650091480272',
#  'Лапчатка Огненное пламя 0,02 г 4650091480616',
#  'Львиный зев Волшебный ковер 0,05 г 4660010779639',
#  'Пеларгония зональная диам. 12 см розово-красная полумахровая',
#  'Флокс друммонда смесь 0,1 г 4650091480401',
#  'Цинерария Серебряная пыль 0,1 г 4660010770797',
#  'Эшшольция Карминный король 0,5 г 4660010770193',
#  'Жестяная банка Новая паста микс П-90*90h171v140-01014',
#  'Кружка НОРДИК 380мл прозрачная H8502 Luminarc Франция',
#  'Чайник электрический АКСИНЬЯ КС-1002 корпус из жаропрочного стекла белый 2000 Вт 1,8 л',
#  'Гладильная доска Scab Stiro Lux 122х38 см',
#  'Рассекатель пламени на газовую плиту с ручкой, AN8032',
#  'Ополаскиватель для посудомоечных машин Ludwik 750 мл Польша 5900861242715',
#  'Сетка для глажения Ява РТК26 45х65 см, 1200023',
#  'Сковорода алюминиевая с антипригарным покрытием MARBLE ALPENKOK d = 22 см AK-0037A/22N',
#  'Щетка для посуды *ОЛЯ*, Мультипласт 1807010',
#  'Чайник электрический ВАСИЛИСА Т33-2000 нержавеющая сталь красный 2000 Вт 2 л',
#  'Покрывало жаккард шенилл BIRHOME VALENTIN 240х260 см наволочки 50х70 см 2 шт 9234567089661',
#  'Вешалка гардеробная Радуга 2 ЗМИ черный ВНП 299 ч',
#  'Ковер придверный EKSPO 90х150 см черный РР114/01019',
#  'Набор форм для кексов WEBBER из нержавеющей стали 6 шт 7,5*3,4 см BE-4343/6',
#  'Банка стеклянная WOODEN TOUCH 1700 мл, Attribute, ABB017',
#  'Корзина для белья пластмассовая 45 л угловая С299 1704006',
#  'Весы напольные электронные Soehnle Pino White, 63747',
#  'Лестница-стремянка Dogrular Ufuk оцинкованная 4-х ступенчатая',
#  'Диффенбахия d-12 см с топпером на День учителя в подарочной упаковке',
#  'Комплект постельного белья WELLNESS PLATINUM R185-Авеню пододеяльник 180х214 см простыня 200х214 см 2 наволочки 50х70 см',
#  'Покрывало жаккард KARNA стеганое KALVEN 260x260 см наволочки 50х70 см 2 шт 8681914002162',
#  'Вилка столовая Better цветы BT-C2003E-TD1/D3',
#  'Бальзамин новогвинейский d-13 см цвет фуксии',
#  'Чехол для гладильной доски Zalger 520132 114х37 см бязь для доски 110х32 см',
#  'Фаленопсис королевский Голубой 1 ствол d-12 см',
#  'Сумка-тележка хозяйственная Rolser RG SAQUET, синяя, SAQ002 azul CONVERT',
#  'Подставка для обуви резиновая Attribute 80x40 см AMC080',
#  'Сушилка для белья потолочная ЛИАНА ЛЮКС 160 см ЛЛП-160',
#  'Вешалка-сушилка Gimi Paco',
#  'Коврик Bacchetta противоскользящий в душевую кабину 55х55 см бежевый 4819',
#  'Штора для ванной комнаты 240х200 Fragmmento бежевая текстильная 240х200 см 6041',
#  'Штора для ванной комнаты ПВХ Sfera 240х200 см серая, Bacchetta, 4833',
#  'Миска пластмассовая круглая Пластхозторг S-706, 0,8 л 1535005',
#  'Гладильная доска НИКА БЕЛЛЬ Классик 1 122х34,5 см БК1',
#  'Кружка прозрачная 250 мл H8437 Luminarc Франция',
#  'Одеяло Silver line 195*215 100% микрофибра 100% микроволокно 17Т-0034/2',
#  'Сушилка для белья на батарею НИКА СБ6-65 двухъярусная',
#  'Подсолнечник низкорослый d-13 см',
#  'Ручка-скоба РС-100 белая *Трибатрон*, 1108035',
#  'Пуансетия d-12 см с топпером на День учителя в подарочной упаковке',
#  'Лоток для холодца эмалированный 1,5 л с пластмассовой крышкой без рисунка С-2508Кп Стэма 1506084',
#  'Гладильная доска Eurogold Professional 130х48 см 35748W',
#  'Сушилка для белья напольная COLOMBO ALPINA 40MT ST194/4CF',
#  'Пресс для чеснока Attribute WESTERN AGW050',
#  'Сушилка для белья потолочная ЛИАНА ЛЮКС 250 см ЛЛП-250',
#  'Тарелка обеденная КАШИМА ПУРПЛ 25 см G9324 Luminarc',
#  'Сумка-тележка 3-х колесная Gimi Tris красная',
#  'Коврик придверный хлопковый 60х180 см мультиколор, Helex, С05',
#  'Лестница-стремянка Примус оцинкованный металл 7 ступеней, 1,55 м , 1203048',
#  'Щетка-сметка с пластиковой ручкой ЛАУРА SV3020',
#  'Термостакан WEBBER BE-6030 КОФЕ 450 мл',
#  'Гиностемма укорененный черенок 1 шт',
#  'Сумка-тележка хозяйственная Andersen Treppensteiger Scala Shopper, Hera, черная 119-004-80',
#  'Ель канадская Коника ртк 303 горшок 9 л Нидерланды',
#  'Кипарисовик лавсона Элвуди ртк 106 горшок 9 л Нидерланды',
#  'Коврик противоскользящий камешки с ракушками овальный 69х39 см голубой 5520',
#  'Аптения d-10 см h-10 см',
#  'Сушилка для белья потолочная ЛИАНА ЛЮКС 170 см ЛЛП-170',
#  'Коврик придверный каучуковый 45х75 см черный, Helex, P01',
#  'Антуриум андрианум Фиорино d-15 см',
#  'Сушилка для белья потолочно-настенная Gimi Lift 240 5031',
#  'Банка РОНДО ЭЛИЗ 1л, G8487, Luminarc, Китай',
#  'Сушилка для белья Attribute ПРИМА 18 м синяя ADP618',
#  'Весы напольные механические Дельта D-2017 130 кг, 1205224',
#  'Таз пластмассовый 12,0 л пищевой (Минеральные воды), 1404022',
#  'Роза Палас белая d-17 см h-50 см h-20',
#  'Ковер придверный EKSPO 90х150 см коричневый РР120/1',
#  'Сушилка для белья Gimi Mito алюминий',
#  'Новогоднее дерево Ель канадская Коника ртк 343 d-9 см',
#  'Гладильная доска НИКА ЭЛЬЗА Премиум 122х40 см ЭЛП',
#  'Новогоднее дерево Ель сербская d-21 см h-60 см',
#  'Чехол для одежды малый 100х60х10 см светло-бежевый Валиант / Valiant TR-106H',
#  'Новогоднее дерево Ель канадская Коника в красном ведерке 3 л h-40 см',
#  'Мыльница пластмассовая на ванну М2221 1702010',
#  'Подголовник Bacchetta 25х34 см Quadrifoglio 4809',
#  'Сушилка для белья Gimi Modular 3 Lux Silver',
#  'Коврик Dasch для ванной комнаты 50х80 см TL-90 Листопад зеленый 5730',
#  'Сушилка для белья напольная НИКА СБ9/А цвет аквамарин/белый',
#  'Пеларгония Грандифлора махровая микс d-12 см',
#  'Муляж Мандарин мини на магните',
#  'Салфетка Protec Textil Lino 30х43 см натур 6223',
#  'Мыло ручной работы Свинюшка в грязюшке 90 г',
#  'Гладильная доска Leifheit AirBoard Compact M Plus 120х38 см малиновый 71630',
#  'Сушилка для белья на ванну Leifheit Adria 72708',
#  'Крючок одежный двойной усиленный алюминиевый (дюраль), 1110015',
#  'Гладильная доска НИКА БЭЛЛЬ-ЮНИОР1 112х34,5 см БЮ1',
#  'Чехол для одежды Hausmann со стенкой из ПВХ и ручками 60х140 см синий HM-701402NG',
#  'Набор бокалов для пива Cervoise 4 шт 320мл G3775 Luminarc Франция',
#  'Защитный экран подставка и дуршлаг WEBBER 3 в 1 цвет: зеленый d = 28,5 см из силикона BE-0341S',
#  "Многофункциональный инструмент 25 функций, PLB025L 7'/PT00234",
#  'Роза мини розовая d-7 см h-10',
#  'Коврик в ванну 36х71 см, Розовый',
#  'Стремянка-табурет алюминиевая Hailo L90 Step-ke 4442-701 2х2 ступени',
#  'Пуансеттия d-12 см красная с розовым',
#  'Коврик противоскользящий пузырьки 70х38 см бирюзовый 5526',
#  'Пуансеттия d-12 см белая',
#  'Петля рояльная оксид 545 мм, 1103066',
#  'Тележка багажная DELTA ТБР-21 черный грузоподъемность 25 кг для сумка и 50 кг для каркас РОССИЯ',
#  'Новогоднее дерево Ель сербская d-27 см h-200 см',
#  'Цветущее комнатное растение Бегония Элатиор, цвет в ассортименте',
#  'Чайная ложка 6 предметов Вена СЧВ107',
#  'Нож для мясорубки (Супер) Лепесток 1512016',
#  'Крассула d-17 см h-40 см',
#  'Тарелка суповая ИРИС 21 см J1299 Luminarc',
#  'Комплект махровых салфеток ТОП_2, 100% хлопок 266 г/м2, 28х42 см, 2 шт, цвета в ассортименте, Wellness, 4630005364393',
#  'Набор столовых приборов 24 предмета OASIS Domenik DM9634',
#  'Пуансеттия d-15 см розовая',
#  'Набор столовых приборов 24 предмета SAINT GERMAIN Domenik DM9638',
#  'Коврик ворсовый для ванной комнаты OrthoSpa River Rocks natural из микрофибры и ПВХ прямоугольный 50х85 см серо-коричневый, Apac',
#  'Кольца для штор Виолет 12 шт пластик 1212/60',
#  'Скатерть Сидней 100% полиэфир овальная 300х150 см сиреневая Wellness WTO305-Сидней*81',
#  'Кувшин Luminarc ВИКТОРИЯ 1,8 л с крышкой J8130',
#  'Пуансеттия d-15 см красная',
#  'Набор столовых приборов 24 предмета FARANDOLE Domenik DM9635',
#  'Сумка-тележка 3-х колесная Gimi Tris черная',
#  'Чехол для одежды объемный Hausmann с овальным окном ПВХ и ручками 60х140х10 см черный HM-701403AG',
#  'Коврик ворсовый ПВХ придверный Multy 60х180 см коричневый',
#  'Чайный набор СЕЛЬМА 220мл, G9434, Luminarc, Франция',
#  'Вешалка напольная TWIST складная 45*35 VRTW-1 светлая Степанов',
#  'Скатерть Towa Co Ажурная Presea прямоуголная 120х150 см сепия 5514',
#  'Вантуз черный с пластиковой ручкой малый Д-100 (МАГ), 1206002',
#  'Вешалка с закругленными плечиками перекладиной и крючками с противоскользящим покрытием Valiant 213R11 черный',
#  'Термокружка Alpenkok AK-04010A синий 400 мл',
#  'Чехол для гладильной доски универсальный с поролоном антипригарный, ЧПА, НИКА',
#  'Сушилка для белья потолочная ЛИАНА ЛЮКС 180 см ЛЛП-180',
#  'Плед флисовый 200х150 см WELLNESS WPLNY152-Зима_4 100 % полиэстер',
#  'Сумка-тележка хозяйственная Rolser BAB010 rojo JOY-1800 красная',
#  'Гладильная доска НИКА LORETA GOLF HL 123х46 см',
#  'Фоторамка Alparaisa на 7 фотографий бронзовая 43х42,5 см С31-017',
#  'Этажерка 2 для обуви узкая 4 полки, медный, ЭТ2, НИКА',
#  'Тарелка десертная БАМБУК 20 см J0276 Luminarc',
#  'Скатерть Джулия 64% хлопок 36% полиэфир прямоугольная 350х150 см золотая с голубым Wellness MT355-Джулия*16',
#  'Сервировочная салфетка ПВХ 26х41 см Капучино 6163',
#  'Гладильная доска Attribute TEFLONIX 135х46 см оранжевая ABT044',
#  'Чайник эмалированный METALLONI со свистком и керамической ручкой Французский шарм 2,5 л EM-250X1/28',
#  'Новогоднее дерево Ель канадская Коника в декоративном контейнере 1 л h-20 см',
#  'Таз пластмассовый 30,0 л пищевой овальный (Иж), 1404055',
#  'Сушилка для белья напольная COLOMBO ALPINA 30MT ST194/3CF',
#  'Шнур резиновый для тележки 200 см белый, 1209004',
#  'Термос со стеклянной колбой 1,2 л 21013',
#  'Скиммия японская Рубелла d-19 см h-40 см',
#  'Лестница-стремянка Dogrular Ufuk оцинкованная 8-ми ступенчатая',
#  'Аспарагус Спренжери d-12 см',
#  'Сумка-тележка хозяйственная Rolser Jet Claudia Joy черная, JET006 negro JOY',
#  'Доска разделочная Alparaisa стеклянная Завтрак 20х30 см RD0030-ST',
#  'Чайный набор 220 мл КАРИН РОМАШКА, G1988, Luminarc, ОАЭ',
#  'Штора для ванной комнаты Bacchetta Fragmmento бежевая текстильная 180х200 см 6034',
#  'Тарелка суповая Luminarc ОКЕАН ЭКЛИПС 20,5 см L5079',
#  'Гладильная доска НИКА Бест 122х40 см НБ',
#  'Розмарин d-9 см',
#  'Пуансеттия d-23 см белая',
#  'Набор бокалов для шампанского ЛЕДИ ДАЙМОНД 6 шт 150 мл G5208 Luminarc Франция',
#  'Коврик придверный пористый из полимерных материалов 60х90 см коричневый, Vortex, D022',
#  'Гладильная доска Dogrular Домина 125х42 см 223708',
#  'Сумка-тележка хозяйственная Rolser RG SAQUET, черная, SAQ002 negro CONVERT',
#  'Сумка хозяйственная на колесах, 1209020',
#  'Скатерть 350х180 см WELLNESS WT358-Лувр*02 100% полиэстер',
#  'Роза кордана белая d-10 см h-20',
#  'Сушилка для белья Meliconi Miss Stendy',
#  'Кружка БАМБУК 320 мл G0688 Luminarc Франция',
#  'Комод Эльфпласт № 3 Алфавит оранжевый 301о',
#  'Скатерть Арлет 50% полиэфир 50% хлопок овальная 350х175 см светло-бежевая Wellness MLO357-Арлет*17',
#  'Корыто оцинкованное 45 л бесшовное, 1303007',
#  'Сумка-тележка хозяйственная Gimi Brava',
#  'Сушилка для белья напольная COLOMBO BELLA 20 м ST387',
#  'Штора для ванной комнаты 240х200 Sintra бежевая текстильная 240х200 см 6039',
#  'Кондиционер для белья Sandokkaebi Soft Aroma Aqua Blue Свежесть океана флакон 2100 мл Корея 8801353-003494',
#  'Фарфоровая кружка ROSARIO бабочка 550 мл Ф16-013L',
#  'Термокружка Alpenkok AK-04009A красный 400 мл',
#  'Пуансеттия d-12 см красная',
#  'Сумка-тележка хозяйственная Rolser Pack Gloria Logic RG серая, PAC036 marengo LOGIC RG',
#  'Вешалка металлическая Valiant с четырьмя разъемными перекладинами противоскользящим покрытием 35*30 см 18B30',
#  'Корзина пластиковая для белья 40л. с крышкой белая 1840/06, Виолет',
#  'Стремянка бытовая Framar Slimmy 4 ступени',
#  'Вешалка настенная НИКА ВП6с с полкой 6 крючков серебро',
#  'Термос 1л SVB-1000H',
#  'Вешалка гардеробная Радуга 1 ЗМИ белое серебро ВНП 298 бс',
#  'Стремянка FRAMAR MAJOR TECH 4 алюминиевая 4-х ступенчатая 4126',
#  'Плед флисовый 150х130 см WELLNESS WPLNY135-Зима_10 100 % полиэстер',
#  'Вилка столовая 3 шт тяжелая серия Сапфир СВWeddel-2',
#  'Коврик придверный хлопковый 60х140 см мультиколор, Helex, С04',
#  'Скатерть виниловая тисненая с ажурной каймой 137х182 см водонепроницаемая ТД5-0077',
#  'Электроштопор QWERTY белый 4,5?23,4 см на батарейках 4хАА 71000',
#  'Коврик придверный полиэстер, 46х76 см, Drifted Nature, Изменчивость, Mohawk, 5007',
#  'Коврик придверный Alpine Wrought Iron из полиэстера и переработанной резины 45x76 см, Apache, 4649',
#  'Стремянка Eurogold Colour 2х ступенчатая с противоскользящим покрытием, сталь 2022R/2122R',
#  'Тарелка обеденная Luminarc ОКЕАН ЭКЛИПС 24 см L5078',
#  'Коврик для ванной комнаты, 50*80*1,4 см, мягкая основа, EXPEDITION HISTORY VALIANT, EXP-H-58',
#  'Настенная сушилка для белья Gimi Brio Super 120',
#  'Сумка-тележка хозяйственная GIMI ROLLING THERMO синяя',
#  'Чайник эмалированный со свистком 2,5л ЕМ-25001/17',
#  'Коврик противоскользящий 69х39 см овальный черепаха 5538',
#  'Комплект для мытья полов из нержавеющей стали и пластика Clean Twist Mop зеленый: швабра-моп + ведро 20 л с механизмом отжима, L',
#  'Корзина для белья ВИОЛЕТ с крышкой Ротанг 40 л латте 1840/20',
#  'Простынь вафельная 200х180 см WELLNESS RW180-01 100% хлопок',
#  'Набор вешалок деревянных 3 шт с перекладиной 44,5х23х1,2 см лиловый ROMANTIC VALIANT RM-16601s',
#  'Декоративная композиция искуственных цветов Букет Подсолнухов 115 см три бутона',
#  'Сковорода Scovo Дем Мт-029 алюминиевая без крышки с металической ручкой, 20 см',
#  'Столовый нож RIPPLE 80 г 2 шт Attribute ACR042',
#  'Вешалка Valiant для брюк и юбок металлическая 30*10.5 см 121B11',
#  'Чехол для одежды Hausmann розовый принт 60х100х104',
#  'Пеларгония зональная диам. 12 см красный махровый',
#  'Пеларгония зональная РОЗОЦВЕТНАЯ Маргарита лососевая 5-7 листов',
#  'Блюдце УТРО ЭКЛИПС, J3261, Luminarc, Франция',
#  'Скатерть Ажурная d-ia Rose круглая д.152 белая 5173 Towa Co. LTd-',
#  'Штора для ванной 180х200 см, Rigone Зеленый',
#  'Контейнер для СВЧ Полимербыт Премиум 1,2 л 4356200',
#  'Сушилка для белья напольная НИКА СБ1Г 18 м бело-голубая',
#  'Фиттония Скелетон d-9 см',
#  'Скатерть Беатрис 50% полиэфир 50% хлопок прямоугольная 300х145 см светло-коричневая Wellness ML304-Беатрис*20',
#  'Чехол Eurogold Clean Metallic металлизированый с поролоном для досок 120х38-120х42 см C42F3M',
#  'Роза кустовая Ред Лейс 60 см Кения плантация Waridi Limited 10 штук в упаковке',
#  'Чехол для одежды Hausmann со стенкой из ПВХ и ручками 60х100 см AG',
#  'Гладильная доска Dogrular Томрис 120x38 см',
#  'Гладильная доска НИКА БЭЛЛЬ-ЮНИОР2 112х34,5 см БЮ2',
#  'Полки QWERTY Лондон белый 27х27х10 см и 23х23х10 см 72000',
#  'Тимьян d-9 см',
#  'Бульонница Luminarc МИСТИГРИ 500 мл J8770',
#  'Сушилка для белья напольная НИКА СБП1/С 18 м',
#  'Нож для овощей и мяса (5024) 1518004',
#  'Алоэ Вера d-12 см h-25 см',
#  'Гладильная доска NIKA HAUSHALT Тефлон золотой 122х40 см HP1T/G',
#  'Жестяная банка Гуси 0,8 л 11х9,9 см Ц99h110v080-01339',
#  'Пеларгония зональная диам. 12 см красно-розовая простая',
#  'Комнатное растение в горшке Сциндапсус зеленый подвесной горшок, d15-16, h30',
#  'Сушилка для белья напольная НИКА СБ3Б 10 м белая',
#  'Роза одноголовая Родос 70 см Кения плантация Subati Flowers Limited 10 штук в упаковке',
#  'Сумка-тележка GIMI ITALO blue синяя',
#  'Щетка для мытья посуды КОЛИБРИ М5202 большая',
#  'Миксер ВАСИЛИСА ВА-506 белый с красным/малиновым 180 Вт 7 скоростных режимов',
#  'Сушилка для белья напольная НИКА СБ3 10 м',
#  'Ключница Картина W-12 ЗАМОК 35х30 см',
#  'Разделочная доска Attribute GRANITE 20х30 см ABX111',
#  'Штора для ванной Spirella / Спирелла TEX Porto, белый, текстиль с гидрофобной пропиткой, 180*200 см, 1033938',
#  'Тарелка обеденная СТЕЛЛА ШОКОЛАД 25 см J1762 Luminarc',
#  'Чайник электрический ВАСИЛИСА Т30-2000 нержавеющая сталь черный c красным 2000 Вт 1,8 л',
#  'Аптения d-12 см h-15 см',
#  'Мантоварка-пароварка WEBBER BE-81 нержавеющая сталь d=30 см',
#  'Складная картонная коробка для хранения 30х20х15 см с уголками белый hm-9741-3 Hausmann',
#  'Спатифиллум Шопен d-12 см',
#  'Чехол для гладильной доски Colombo Клубки Пряжи Серый/Розовый 140х55 см из хлопка 5550',
#  'Контейнер герметичный прямоугольный Виолет 092/051 500 мл дымчатый',
#  'Набор вешалок пластмассовых Rozenbal R181900',
#  'Искусственный цветок пластиковый Нарцисс 3 бутона королевский 46 см',
#  'Емкость для соуса с ложкой PASABAHCE 200 мл OTS131505-000',
#  'Фикус каучуконосный Эластика Абиджан d-12 см h-30 см',
#  'Тарелка суповая Luminarc МАРИСА ОРАНЖ 20 см J7687',
#  'Защитная соль для посудомоечных машин Ludwik 1,5 кг Польша 5900861242227',
#  'Таз пластмассовый 16,0 л пищевой круглый М2507, 1404037',
#  'Гипоаллергенный концентрированный гель для стирки белья VPK для деликатных тканей 2,5 л Корея 8809473130144',
#  'Коврик придверный с дизайном, из резины и кокоса 58,5*89 Gothic Iron Slice / Готический Узор, 4468',
#  'Муляж Ананас 21 см',
#  'Сиденье для ванны пластмассовое М1552 1714003',
#  'Скатерть 150х120 см WELLNESS WT125-Куэна 100% полиэстер',
#  'Сумка-тележка 2-х колесная Gimi Argo черная',
#  'Коврик кухонный APACHE Coffee Chef 45x75 см 5420',
#  'Вешалка-перекладина Valiant металлическая двойная с антискользящим покрытием 50320',
#  'Скатерть Муза 100% полиэфир овальная 180х150 см сливочная с цветами, Wellness, WTO185-Муза*04',
#  'Кружка мерная 11600 1 л',
#  'Штора для ванной Spirella / Спирелла TEX Rings, текстиль с гидрофобной пропиткой, серо-черный, 180*200 см, 1015184',
#  'Сушилка для белья ЛИАНА ЛЮКС 110 см потолочная',
#  'Роза Патио оранжевая d-12 см h-30',
#  'Фиалка d-9 см белая махровая',
#  'Штора для ванной Spirella / Спирелла TEX Shine текстиль с гидрофобной пропиткой, шампань, 180*200 см, 1015640',
#  'Модульная стеклянная банка 1,1л, 298264, Brabantia,',
#  'Сушилка для белья Zalger Simfony 1255-90 одноуровневая с крыльями 20 м',
#  'Контейнер для мусора пластиковый 50 л 40,7х30,6х72,7 см РОЛЛ ТОП серый, Curver, D 03977-856',
#  'Сушилка для белья настенная НИКА СН90 серебро 90 см',
#  'Сушилка для белья потолочная ЛИАНА ЛЮКС 200 см ЛЛП-200',
#  'Перчатки Fabrikators для чистки овощей детские оранжевый KO2PU',
#  'Термостакан WEBBER ВЕ-6031 ЧАЙ 450 мл',
#  'Сумка-тележка хозяйственная Rolser IMX001 negro Convert RG черная',
#  'Столовая ложка Attribute FORTRESS 2 шт ACF622',
#  'Сушилка для белья Hausmann Hermes De Luxe 20 м 03-010C-1',
#  'Подставка для ножей ALPENKOK круглая из пластика 11*22 см красная AK-202ST',
#  'Лестница стремянка ЗМИ Конёк медный антик ТС 277',
#  'Чайный набор Luminarc ЛИЛИ ФЛАУЭР 6 шт 320 мл J8565',
#  'Весы напольные Edition Feet механические',
#  'Петля рояльная цинк 960 мм, 1103055',
#  'Банка стеклянная с металлической крышкой и краником Attribute GRAPE 3,8 л ABS038',
#  'Карниз для ванной комнаты Виолет раздвижной 210 см с кольцами белый 2110/6',
#  'Чехол для гладильной доски I LOVE GIMI M из полиэстера и хлопка 132*48 см, Gimi',
#  'Азалия Индика фиолетовая d-10 см h-20',
#  'Пеларгония зональная махровая белая взрослое растение',
#  'Пеларгония розебудная Emma укорененный черенок',
#  'Пеларгония розебудная Mary укорененный черенок',
#  'Пеларгония розебудная Prins Nikolai укорененный черенок',
#  'Полки QWERTY Берлин чёрный 44х24х10 см 40х20х10 см 36х16х10 см 72008',
#  'Штора для ванной комнаты ПВХ 180х180 см Ракушки бежевая, 5923',
#  'Крючок проволочный 75 мм латунь, 1110136',
#  'Цветок искусственный Тюльпан 40 см пластик цвет в ассортименте',
#  'Просеиватель для муки D27см., RSB',
#  'Мусорный контейнер Hailo BigBin Swing 45 0845-010 45 л хром',
#  'Пеларгония Toscana Angeleyes Amarillo Burgundy укорененный черенок',
#  'Пеларгония Toscana Angeleyes Amarillo Rosato укорененный черенок',
#  'Пеларгония розебудная Queen Ingrid укорененный черенок',
#  'Пеларгония розебудная Red Pandora укорененный черенок',
#  'Пеларгония Toscana Angeleyes Bicolor укорененный черенок',
#  'Скатерть Meiwa FPLUS-PLAIN SARASA AZ BE прямоугольная152х228 см бежевая 5140 Meiwa',
#  'Кастрюля чугунная 24 см, красная, 3.6 л, PYREX, SC5AC24/5141',
#  'Сиденье для гладильной доски Leifheit Niveau, 71325',
#  'Штора для ванной 180х200 см, Rigone Розовый',
#  'Весы настольные электронные DELTA КСЕ-01 белый 5кг',
#  'Крючок проволочный 125 мм медь, 1110132',
#  'Гладильная доска НИКА ВЕРОНА 1 чехол МУЖЧИНА С РОЗОЙ 122х42 см ДВ1м',
#  'Средство для мытья посуды Vestar Гранат 1000 мл Россия 4620757211700',
#  'Декоративная коробка Stockholm XL Classico 30*25*40 см D 04711-D41 Curver 04711-D41',
#  'Толкушка деревянная ( Бук ) 1530018',
#  'Махровое полотенце 70х35 см WELLNESS EXCLUSIVE 1ДСЖ1_ЙОТА_1-67 100% хлопок',
#  'Вешалка НИКА Комфорт 6 напольная серебро ВК6с',
#  'Швабра для пола с отжимом и фиксатором микрофибра, R212608, ROZENBAL',
#  'Искусственная лиана Плющ 2,4 м',
#  'Кодонанта укорененный черенок 1 шт',
#  'Коврик придверный PHP SRL 40х68 см Format Tour 21717 Добро пожаловать 6008',
#  'Гладильная доска Белль-Юниор1 34,5х112см ДСП 1200006',
#  ...]

# %%
prod = len(df_without_duplicates['product'].unique())
f'Количество товаров в ассортименте: {prod}'
# Out:
# 'Количество товаров в ассортименте: 2343'

# %% [markdown]
# Количество товаров в ассортименте - 2343. Но по списку видно, что в данном столбце представлены неявные дубликаты.
#
# Для дальнейшей работой со столбцом `product` и проведения категоризации - необходимо предобработать его, а именно:
#
# * Изменение регистра(приведение к нижнему регистру)
# * Замена ё на е
# * Удаление пробелов
# * Удаление цифр
# * Удаление не буквенных символов
#
# Все это необходимо сделать для того, что бы сделать схожие позиции в ассортименте более "однородными".

# %%
df_without_duplicates['product'] = df_without_duplicates['product'].str.lower() #приведение к нижнему регистру
df.head(5)
# Out:
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price  \
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# 3                   Хризолидокарпус Лутесценс d-9 см         1  179.0
# 4                     Циперус Зумула d-12 см h-25 см         1  112.0
#
#     date_new month_year  hours
# 0 2018-10-01 2018-10-01      0
# 1 2018-10-01 2018-10-01      0
# 2 2018-10-01 2018-10-01      0
# 3 2018-10-01 2018-10-01      0
# 4 2018-10-01 2018-10-01      0

# %% [markdown]
# Товары в таблице приведены к нижнему регистру. Заменим букву ё на букву е.

# %%
df_without_duplicates['product'] = df_without_duplicates['product'].replace('ё', 'е')

# %% [markdown]
# Замена произведена, далее напишем регулярное выражение, что бы получить только символы из названия товаров (без цифр, без знаков).

# %%
#используем регулярное выражение, что бы получить навзания товаров
df_without_duplicates['new_product'] = df_without_duplicates['product'].str.extract(r'([a-я]+)', expand=True) 
df_without_duplicates.head(15)
# Out:
#                              customer_id  order_id  \
# 0   ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1   ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2   ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3   ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4   ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5   ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6   ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7   375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8   6644e5b4-9934-4863-9778-aaa125207701     68478
# 9   c971fb21-d54c-4134-938f-16b62ee86d3b     68480
# 10  161e1b98-45ba-4b4e-8236-e6e3e70f6f7c     68483
# 11  86432d8d-b706-463b-bd5d-6a9e170daee3     68484
# 12  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68485
# 13  0948b0c2-990b-4a11-b835-69ac4714b21d     68486
# 14  a576fa59-7b28-4a4c-a496-92f128754a94     68487
#
#                                               product  quantity  price  \
# 0     комнатное растение в горшке алое вера, d12, h30         1  142.0
# 1   комнатное растение в горшке кофе арабика, d12,...         1  194.0
# 2                         радермахера d-12 см h-20 см         1  112.0
# 3                    хризолидокарпус лутесценс d-9 см         1  179.0
# 4                      циперус зумула d-12 см h-25 см         1  112.0
# 5                             шеффлера лузеана d-9 см         1  164.0
# 6                    юкка нитчатая d-12 см h-25-35 см         1  134.0
# 7     настенная сушилка для белья gimi brio super 100         1  824.0
# 8   таз пластмассовый 21,0 л круглый "водолей" с61...         1  269.0
# 9   чехол для гладильной доски colombo persia beig...         1  674.0
# 10  вешалка для брюк металлическая с резиновым пок...        10   82.0
# 11  сушилка для белья потолочная zalger lift basic...         1  614.0
# 12  чехол eurogold clean basic хлопок для досок 12...         1  187.0
# 13  крючок одежный 2-х рожковый серый металлик с п...        96   38.0
# 14  корзина мягкая пластиковая 17 л, м-пластика, m...         1  188.0
#
#    month_year  hours      new_product
# 0  2018-10-01      0        комнатное
# 1  2018-10-01      0        комнатное
# 2  2018-10-01      0      радермахера
# 3  2018-10-01      0  хризолидокарпус
# 4  2018-10-01      0          циперус
# 5  2018-10-01      0         шеффлера
# 6  2018-10-01      0             юкка
# 7  2018-10-01      8        настенная
# 8  2018-10-01      8              таз
# 9  2018-10-01      9            чехол
# 10 2018-10-01     11          вешалка
# 11 2018-10-01     12          сушилка
# 12 2018-10-01     13            чехол
# 13 2018-10-01     15           крючок
# 14 2018-10-01     16          корзина

# %%
list(df_without_duplicates['product'].unique())
# Out:
# ['комнатное растение в горшке алое вера, d12, h30',
#  'комнатное растение в горшке кофе арабика, d12, h25',
#  'радермахера d-12 см h-20 см',
#  'хризолидокарпус лутесценс d-9 см',
#  'циперус зумула d-12 см h-25 см',
#  'шеффлера лузеана d-9 см',
#  'юкка нитчатая d-12 см h-25-35 см',
#  'настенная сушилка для белья gimi brio super 100',
#  'таз пластмассовый 21,0 л круглый "водолей" с614, 1404056',
#  'чехол для гладильной доски colombo persia beige 130х50 см из хлопка 5379',
#  'вешалка для брюк металлическая с резиновым покрытием 26 см цвет: синяя, attribute, ahs331',
#  'сушилка для белья потолочная zalger lift basic 1520 200 см, 10 м',
#  'чехол eurogold clean basic хлопок для досок 120х38-120х42 см c42',
#  'крючок одежный 2-х рожковый серый металлик с полимерным покрытием *тонар*, 1110027',
#  'корзина мягкая пластиковая 17 л, м-пластика, m2880',
#  'мини-сковорода marmiton "сердце" с антипригарным покрытием 12 см, lg17085',
#  'сковорода алюминиевая с антипригарным покрытием marble alpenkok d = 26 см ak-0039a/26n',
#  'стеклянная крышка для сковороды alpenkok 26 см ak-26gl',
#  'сушилка для белья напольная colombo star 18, 3679',
#  'доска гладильная eurogold professional 130х48 см металлическая сетка 35748w',
#  'чехол для гладильной доски festival 137x60 см из хлопка 4738',
#  'сумка-тележка 2-х колесная gimi argo синяя',
#  'многолетнее растение тимьян-чабрец розовый объем 0,5 л',
#  'рассада зелени для кухни базилик тонус, кассета по 6шт',
#  'рассада зелени для кухни мелиссы в горшке диам. 9 см',
#  'муляж "райские яблочки зеленые" 2 шт полиуретан, d 3 см',
#  'муляж банан, желтый, 21 см, полиуретан, fancy fair/ff xj210',
#  'муляж виноград 14 см цвет в ассортименте',
#  'муляж гранат 9см, красный, fancy fair, sl90, красный',
#  'муляж груша мини 2 шт, желтая 4 см',
#  'муляж груша, желтый, 9,5 см, полиуретан, fancy fair/ff li95-03',
#  'муляж зеленое яблоко полиуретан d-6 см',
#  'муляж клубника 1 шт полиуретан d-6 см',
#  'муляж клубника на магните',
#  'муляж красное яблоко мини полиуретан d-6 см',
#  'муляж лимон, желтый, 9 см, полиуретан, fancy fair/ff nm90',
#  'муляж мандарин, оранжевый, 8 см, полиуретан, fancy fair/ff jz80',
#  'муляж перец, зеленый, 10 см, полиуретан, fancy fair/ff gp8',
#  'муляж перец, красный, 10 см, полиуретан, fancy fair/ff rp8',
#  'муляж персики мини полиуретан d-6 см',
#  'муляж томат, оранжевый, 9 см, полиуретан, fancy fair/ff t9',
#  'муляж черешня 3см 10 шт., желтый, fancy fair, scr30/10, желтый',
#  'щетка-сметка 3-х рядная деревянная 450 мм (плоская ручка), поиск риф 1801095',
#  'щетка-сметка 4-х рядная деревянная 300 мм (фигурная ручка) ворс 5,5 см 1801096',
#  'сумка для тележки большая комбинированная 45*30*25, 1209021',
#  'тарелка обеденная лимон фиц 25см, g9547, luminarc, франция',
#  'вилка столовая ripple сталь 3 мм, 3 шт, attribute, acr013',
#  'ложка столовая ripple сталь 3 мм, 3 шт, attribute, acr023',
#  'ложка чайная ripple сталь 2,5 мм, 3 шт, attribute, acr033',
#  'нож столовый ripple 80 г 2 шт, attribute, acr042',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, коралловая, полумахровая',
#  'ерш для туалета с подставкой malibu фарфор 47х12,5 см белый, spirella, 1001768',
#  'пеларгония зональная диам. 12 см малиновая с красным полумахровая',
#  'пеларгония зональная диам. 12 см сиренево-красная простая',
#  'пеларгония зональная диам. 12 см сиреневый полумахровый',
#  'пеларгония зональная диам. 12 см сиреневый простая',
#  'сушилка для белья настенная zalger prima 510-720 веревочная 7 линий 25 м',
#  'котел алюминиевый 70,0 л без крышки балезино, хозлэнд, 1502050',
#  'суккулент микс d-5 см',
#  'эхеверия перл фон нюрнберг d-7 см',
#  'набор прищепок большие пластиковые rozenbal пиноккио 10 шт r102312',
#  'сушилка для белья attribute прима 11 м синяя напольная adp410',
#  'коврик придверный 45х75см. с рельефным рисунком "welcome", коричневый, cr005',
#  'коврик bacchetta magicstop 0,3x1,5 м бежевый для сушки посуды 2289',
#  'корзина для глаженного белья natural style, 45 л, 27*38*59 см, коричневая, d 00708-213, curver 00708-213',
#  'корзина пластиковая для белья 60л. с крышкой бежевая 1860/2, виолет',
#  'сушилка для белья потолочно-настенная gimi lift 200',
#  'подкладка под чехол zalger 520140 135х50 см поролон',
#  'набор кружек для пива гамбург 2шт 500мл, h5072, luminarc, россия',
#  'коврик интерьерный для кухни village street floral из пвх прямоугольный 50х107 см, apache, 4663',
#  'дозатор для мыла hausmann белый hm-b0194r-2',
#  'ёрш унитазный с подставкой wc "стандарт", мультипласт 1712010',
#  'нож для чистки овощей webber из нержавеющей стали 12х6,8х1,5 см ве-5275',
#  'подкладка под чехол zalger 520114 135х50 см войлок',
#  'эвкалипт гунни d-17 см h-60 см',
#  'муляж виноград, желтый, 24 см, полиуретан, fancy fair/g60-y',
#  'муляж виноград, зеленый, 26 см, полиуретан, fancy fair/g85-g',
#  'муляж виноград, черный, 26 см, полиуретан, fancy fair/g85-b',
#  'муляж вишня, вишневый, 3 см, 10 шт, полиуретан, fancy fair/ff cr30/10',
#  'муляж груша, желтый, 9,5 см, полиуретан, fancy fair/ff li95-01',
#  'муляж персик, оранжевый, 9 см, полиуретан, fancy fair/ff tz90',
#  'набор фужеров luminarc дампьер сильвер для вина 260 мл 6 шт h7939',
#  'цветок искусственный гвоздика тканевая красная 50 см',
#  'ёрш унитазный с деревянной ручкой , ваир 1712012',
#  'сумка-тележка хозяйственная gimi market желтая',
#  'герань домашняя (пеларгония зональная) цветущая , d12, h25-30, красная, махровая',
#  'мусорный контейнер в ванную комнату bowl-shiny полистирол 14х16 см белый, spirella, 1014964',
#  'сумка-тележка хозяйственная andersen scala shopper plus, elba, черная 133-051-80',
#  'сумка-тележка хозяйственная rolser jet cuadro mh joy серо-желтая, jet019 marengo joy',
#  'плед флисовый 100% полиэстер 185х240 см бежевый, wellness, wp184-айленд_2',
#  'скатерть династия 100% полиэфир прямоугольная 350х180 см сливочная, wellness, wt355-династия*02',
#  'рассада зелени для кухни лаванды в кассете по 6 шт',
#  'рассада зелени для кухни розмарина в кассете по 6 шт',
#  'рассада зелени для кухни тимьяна в кассете по 6 шт',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, лососевая, махровая',
#  'коврик хлопковый 40х60 см цвета в ассортименте 6194',
#  'коврик хлопковый 45х75 см цвета в ассортименте 6195',
#  'сушилка для белья на батарею, сб5-45, ника',
#  'таз пластмассовый 24,0 л пищевой круглый (иж), 1404006',
#  'кувшин пластмассовый с крышкой "кумган" 2,0 л 1408003',
#  'муляж перец чили в связке, зеленый, 60 см, полиуретан, fancy fair/ff gp60',
#  'адиантум лиза d-12 см',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, белая, махровая',
#  'ковер придверный "multy rus" 120х180см., коричневый, рр214/07034',
#  'перчатки латексные № 3 для дома утолщенные, rozenbal, r105628',
#  'стремянка алюминиевая hailo 4302-301 livingstep comfort plus 2 ступенчатая алюминиевая',
#  'пеларгония зональная диам. 12 см темнорозовая полумахровая',
#  'сумка-тележка хозяйственная gimi market синяя',
#  'гладильная доска gimi jean green line 107х30 см',
#  'лестница-стремянка dogrular ufuk оцинкованная 7-ми ступенчатая',
#  'толкушка для картофеля из нержавеющей стали proline, leifheit, 03032',
#  'тележка багажная delta тбр-20 коричневый с оранжевым грузоподъемность 25 кг сумка и 50 кг каркас россия',
#  'готовая скатерть ажурная dia rose круглая д.152 белая, 5173, towa co., ltd',
#  'сушилка для белья напольная gimi modular 3 lux silver',
#  'искусственный цветок роза маргарита пластик 58 см',
#  'простыня на резинке односпальная wellness rm90-арктик 100% хлопок, 90х200 см, белая',
#  'сумка-тележка хозяйственная gimi bella синяя',
#  'чайник эмалированный "алые маки" со свистком 2,5 л. ем-25001/11',
#  'ёрш для бутылки из натурального волокна и металла 23 см кремовый, burstenmann, 0473/0003',
#  'таз пластмассовый 18,0 л квадратный (тп-18) "пластхозторг", 1404042',
#  'таз пластмассовый 15,0 л пищевой овальный "ekko" 2775, 1404032',
#  'таз пластмассовый 18,0 л пищевой (иж), 1404047',
#  'таз пластмассовый 20,0 л пищевой (минеральные воды), 1404045',
#  'набор вешалок для костюма 45см 4шт цвет: кремовый, attribute, ahp224',
#  'таз пластмассовый 20,0 л пищевой овальный "ekko" 2776, 1404043',
#  'штора текстильная для ванны и душа полиэстер, "разноцветные пузырьки" 180х200см, розов/желт/белый, dscn4061',
#  'сушилка для белья потолочно-настенная gimi lift 220, 5030',
#  'настенная сушилка для белья gimi brio super 60',
#  'сушилка для белья потолочная лиана 2,2 м 1703010',
#  'банка со стеклянной крышкой, color series, круглая, 10*10*12 см, 300 мл valiant, jp-s300',
#  'банка со стеклянной крышкой, color series, круглая, 7*7,6*12,5 см, 280 мл valiant, jp-s280',
#  'стяжка оконная с болтом ст-55 цинк, 1108354',
#  'сумка-тележка 3-х колесная gimi tris floral синяя',
#  'сушилка для белья потолочная лиана люкс 140, лдн-т',
#  'крючок одежный тройной латунь (б-47), 1110182',
#  'набор ковров для ванной комнаты, "офелия", 40х50/50х80см., серый/бежевый, ntbm50804050-26-190',
#  'сушилка для белья виолет ricko 5м rk-5/100 настенная',
#  'комплект для ванной и туалета dasch 50х80 см и 55х55 см tl-2-e лавр бежевый 5755',
#  'тележка багажная delta тбр-20 синий грузоподъемность 25 кг сумка и 50 кг каркас россия',
#  'сумка-тележка хозяйственная andersen scala shopper, elba, черная 112-051-80',
#  'муляж апельсин 8 см полиуретан',
#  'муляж яблоко зеленый 9 см полиуретан',
#  'сумка-тележка хозяйственная welfull daisy, черная 100-002-80',
#  'кампанула махровая двухцветная d-10 см',
#  'пеларгония душистая d-13 см',
#  'сушилка для белья gimi alablock',
#  'тележка багажная delta тбр-22 синий грузоподъемность 20 кг сумка и 50 кг каркас россия',
#  'пеларгония зональная диам. 12 см красная махровая',
#  'пеларгония зональная диам. 12 см ярко красная махровая',
#  'пеларгония зональная махровая белая',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, малиновая с красным, полумахровая',
#  'декоративная композиция искуственных цветов букет роз три цветка, цвет в ассортименте 85 см',
#  'искусственный цветок роза бархатная с закрытым бутоном 72 см цвет в ассортименте',
#  'сумка-тележка хозяйственная rolser jet c. capri joy синяя, jet017 azul joy',
#  'противень прямоугольный алюминиевый 340х240х25 см эксперт, scovo, сэ-052, /1503028',
#  'сушилка для белья потолочно-настенная gimi lift 180',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, малиновая, махровая',
#  'калатея микс d-12 см',
#  'коврик придверный влаговпитывающий ребристый из полимерных материалов 90х120 см серый, vortex, k041',
#  'нолина в цветной керамике d-7 см',
#  'плечики пластмассовые (размер 48 - 54 ) "мп", 1205160',
#  'подушка декоративная флисовая 100% полиэстер 40*40 см синяя клетка, wellness, wp44-атланта_34',
#  'полотенце кухонное мила* mix, 100% хлопок 170 г/м2, 38х63,5 см, цвета в ассортименте, wellness, 4630005366090',
#  'хлорофитум d-13 см',
#  'цикламен d-13 см',
#  'пеларгония зональная диам. 12 см розовая полумахровая',
#  'пеларгония зональная диам. 12 см розовая с малиновым полумахровая',
#  'пеларгония зональная диам. 12 см розово-малиновая простая',
#  'пеларгония зональная махровая лососевая',
#  'крепеж для пружины дверной, 1107055',
#  'пружина дверная 240 мм оцинкованная (д-19 мм) без крепления, 1107014',
#  'глоксиния d-13 см',
#  'азалия индика биколор d-12 см',
#  'гортензия микс d-12 см',
#  'хризантема космо микс d-12 см',
#  'сушилка для белья потолочная лиана 1,6 м 1703005',
#  'муляж тыквы d-8 см',
#  'сушилка для белья на батарею, сб5-65, ника',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, розовая с малиновым, полумахровая',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, розовая, махровая',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, розово-красная, полумахровая',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, розово-малиновая, простая',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, сиренево-красная, простая',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, сиреневый, простая',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, темнорозовая, полумахровая',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, ярко красная, махровая',
#  'коврик интерьерный для кухни tuscan wine из пвх прямоугольный 45х75 см, apache, 4660',
#  'петля приварная гаражная d 14х90 мм с шаром, 1103003',
#  'сушилка для белья gimi lampo',
#  'гладильная доска ника верона 1 чехол одри 122х42 см дв1о',
#  'стеклянная крышка для сковороды alpenkok 24 см ak-24gl',
#  'стеклянная крышка для сковороды alpenkok 28 см ak-28gl',
#  'салфетка protec textil lino 30х43 см серая 6226',
#  'чехол eurogold clean metallic металлизированый с поролоном для досок 110х30-114x34 см c34f3m',
#  'вкладыши для хранения посуды 2 шт d-38 cm marmiton, lg17056',
#  'миксер delta lux dl-5068 серо-голубой 400 вт 4 насадки 5 скоростных режимов турборежим',
#  'коврик влаговпитывающий индия 50*80 см зигзаг серый 6204',
#  'кофр для хранения медикаментов hausmann 9 отделений 30x22x12 см 4w-107',
#  'стиральный биопорошок bonsai концентрированный для белого белья россия 4607974420573',
#  'чистящий крем для трудновыводимых пятен mama lemon stain remover 500 гр индонезия 8998866106207',
#  'сушилка для белья потолочно-настенная gimi lift 240, 5031',
#  'tepмокружка avex recharge 500 мл голубой avex0681',
#  'чехол для гладильной доски zalger 520135 140х50 см хлопок поролон для доски 135х45 см',
#  'щетка для смахивания пыли 60 см разноцветная, burstenmann, 0528/0000',
#  'мирт d-20 см h-25 см',
#  'цветущее комнатное растение хризантема диаметр горшка 18 см',
#  'сушилка для белья потолочная лиана 1,7 м 1703006',
#  'чайник эмалированный metalloni со свистком и керамической ручкой "французский шарм" 2,5 л em-250x1/28',
#  'чехол для гладильной доски zalger 520138 140х50 см металлизированный с поролоном для доски 135х45 см',
#  'штора для ванной комнаты diamante 240х200 см бежевая, bacchetta, 4800',
#  'стремянки colombo leonardo 3 ступени g300a03w черая 3649',
#  'таз пластмассовый со стиральной доской (иж), 1404021',
#  'щетка для посуды *мила* sv3182 1807009',
#  'щетка-утюжок с ручкой миди, standart, york, g1126',
#  'светильник настольный 17 led ламп, светодиодный сенсорный, с диммером 26-0004/w черный, perfectolight',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, белая, полумахровая',
#  'муляж лимон желтый 9 см полиуретан',
#  'кориандр в кассете 6 шт',
#  'рассада зелени для кухни базилик арарат, кассета по 6шт',
#  'рассада зелени для кухни петрушка универсал, кассета по 6шт',
#  'рассада зелени для кухни шалфея в горшке диам. 9 см',
#  'чехол для одежды eva 60х95 см eve4214',
#  'чехол для одежды hausmann розовый принт 60х100 см hm-ea1104',
#  'чехол для платья из нетканного материала 60*135 см белый, hausmann, 2b-360135',
#  'сушилка для белья потолочная лиана 2,4 м 1703011',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, малиново розовая, простая',
#  'сушилка для белья gimi jolly 18',
#  'жидкое мыло vestar хозяйственное 750 мл россия 4620757212370',
#  'ковёр придверный "лапша" 60х90см коричневый',
#  'коврик резиновый ажурный iron grill 45х75 см 6207',
#  'пена для ванн vestar хвойная пихта 900 мл россия 4620757212424',
#  'тележка хозяйственная складная, тх0253, 50 кг, пэмби',
#  'таз пластмассовый 10,0 л круглый (350х170) "м- пластик" м2506, 1404091',
#  'таз пластмассовый 13,0 л пищевой с меркой (минеральные воды), 1404028',
#  'таз пластмассовый 14,0 л пищевой (иж), 1404079',
#  'таз пластмассовый 15,0 л пищевой (минеральные воды), 1404038',
#  'таз пластмассовый 16,0 л круглый с12129, 1404034',
#  'таз пластмассовый 16,0 л пищевой с ручками (с203/303) "полимербыт", 1404039',
#  'таз пластмассовый 40,0 л пищевой овальный (иж), 1404094',
#  'сумка-тележка 2-х колесная складная gimi flexi зеленая',
#  'гладильная доска ника haushalt m hm 122х40 см',
#  'подрукавник складной ника п',
#  'штора со встроенными кольцами под штангу для ванны и душа жаккард, полиамидное покрытие, 180х200, аквамарин, hsc/st04/aquamarin',
#  'штора со встроенными кольцами под штангу для ванны и душа жаккард, полиамидное покрытие, 180х200, голубой, hsc/st12/blue',
#  'чехол для гладильной доски zalger 520125 140х58 см хлопок войлок для доски до 135х53 см',
#  'штора со встроенными кольцами под штангу для ванны и душа жаккард, полиамидное покрытие, 180х200, бежевый, hsc/st05/beige',
#  'штора со встроенными кольцами под штангу для ванны и душа жаккард, полиамидное покрытие, 180х200, белый, hsc/st04/white',
#  'иссоп лекарственный d-9 см',
#  'сантолина d-9 см',
#  'сушилка для белья attribute мини 2,5 м навесная adm125',
#  'аспарагус d-12 см h-30 см',
#  'афеляндра скуарроса дания микс в кашпо с автополивом',
#  'тележка багажная delta тбр-15 цвет в ассортименте грузоподъемность 30 кг россия',
#  'набор сверел по дереву из 8 шт, 3-10 мм *888* 6867540, 0512261',
#  'сверло-фреза, 6 мм, нитрид титана *888* 6862060, 0512262',
#  'сверло-фреза, 8 мм, нитрид титана *888* 6862080, 0512263',
#  'пеларгония зональная диам. 12 см лососевая махровая',
#  'гладильная доска дсп "бэлль-юниор2", 112*34,5, бю2, ника',
#  'контейнер для овощей полимербыт 3-х секционный лоток 9 л 4312600',
#  'сушилка для белья лиана люкс 130 см потолочная',
#  'стремянка алюминиевая 5 ступеней, са5, ника',
#  'чехол для гладильной доски universal 160х60 см, attribute, abu004',
#  'гладильная доска sarayli orion 130x44 см',
#  'мусорный контейнер hailo profiline solid 14 0514-089 14 л белый',
#  'гладильная доска перф металл "ника 10+", 122*40, н10+, ника',
#  'сушилка для белья rainbow color напольная из хромированной стали 201,5х55х93 см, gimi',
#  'зубная паста zact с эффектом отбеливания кофейного и никотинового налета 150 г 8806325-603849',
#  'зубная паста zact lion smokers toothpaste 100 г 8850002805040',
#  'зубная паста zact lion whitening toothpaste 100 г 8850002805064',
#  'нож для тонкой нарезки alpenkok из нержавеющей стали пилообразный "comfort" 12,7 см синий ak-2082',
#  'антуриум андрианум блэк d-12 см',
#  'комнатное растение в горшке аспарагус мейера, d12, h30',
#  'молодило микс d-9 см',
#  'фиалка d-11 см',
#  'таз пластмассовый 32,0 л с ручками "полимербыт" с202, 1404052',
#  'таз пластмассовый строительный круглый 65 л, 1404076',
#  'гладильная доска-стремянка 95х33 см, 848n, dasch',
#  'гербера d-13 см',
#  'душица обыкновенная d-9 см',
#  'мелисса лекарственная d-9 см',
#  'роза кордана красная мерседес d-10 см',
#  'роза кордана красная d-10 см',
#  'фиалка карнавал d-12 см',
#  'хризантема белая кристалл d-15 см',
#  'хризантема красная тобаго d-15 см',
#  'сушилка для белья потолочная лиана 2,0 м 1703009',
#  'тележка хозяйственная складная, тх0252, 30 кг, пэмби',
#  'карниз алюминиевый телескопический для штор spirella / спирелла magic, хром, 125-220 см, 1050767',
#  'штора для ванной комнаты cannetto 240х200 см коричневая, bacchetta, 4061',
#  'веник сорго с деревянной ручкой с 4-мя швами, rozenbal, r206204',
#  'пеларгония зональная диам. 12 см малиново-красная простая',
#  'муляж гранат 9 см красный',
#  'гладильная доска sarayli new elegant 125x45 см',
#  'салфетка protec textil polyline 30х43 см аметист белая 6230',
#  'лестница-стремянка dogrular ufuk al алюминевая 6-ти ступенчатая',
#  'ерш для унитаза spirella venise с подставкой керамический 4007036',
#  'контейнер для мусора flip bin curver 25 л красный 02171-547-00',
#  'контейнер для мусора flip bin curver 25 л оранжевый 02171-535-00',
#  'стремянка металлическая 4 ступени, см4, ника',
#  'швабра многофункциональная, rozenbal, r212522',
#  'ящик для хранения textilebox curver 5,7 л 34x20x13 см прозрачный 03003-001-00',
#  'щетка палубная 215х80х20 мм 6-рядная без черенка угловой держатель 58 1801088',
#  'гладильная доска перф металл "эльза премиум", 122*40, элп, ника',
#  'скатерть лувр 100% полиэфир овальная 300х150 см салатовая wellness wto305-лувр*18',
#  'подголовник для ванной комнаты из пвх 25х34 синий, bacchetta, 1620',
#  'гладильная доска фанера "стелла премиум 2", 122*38, стп2, ника',
#  'пеларгония зональная диам. 12 см белая махровая',
#  'пеларгония зональная диам. 12 см коралловая полумахровая',
#  'пеларгония розоцветная ред розебуд молодые растения',
#  'сумка-тележка хозяйственная rolser jet joy синяя, jet001 azul joy',
#  'банка с металлической крышкой, color series, круглая, 11*11*12 см, 960 мл valiant, jk-d960',
#  'банка с металлической крышкой, color series, круглая, 11*11*17 см, 1350 мл valiant, jk-c1350',
#  'ведро для мусора hailo 0516-570 16 л, бежевый',
#  'штора текстильная для ванны и душа полиэстер, "бамбук" 180х200см, зелёный/белый, dscn3579',
#  'вешалка деревянная с расширенными плечиками и перекладиной 44,5х23 см см серый japanese black valiant jb-19708',
#  'вешалка для блузок 41 см черный attribute ahm791',
#  'вешалка с закругленными плечиками без перекладины с противоскользящим покрытием valiant 226b10 черный',
#  'гладильная доска sarayli tamara 125x42 см',
#  'коврик влаговпитывающий ребристый 50х80 см стандарт черный 5877',
#  'коврик влаговпитывающий ребристый 60х90 см стандарт зеленый 5884',
#  'коврик придверный грязеулавливающий резиновый finger 40х60',
#  'короб стеллажный с крышкой большой, 30*40*25 см, expedition valiant, ex-box-lm',
#  'короб стеллажный с крышкой малый, 28*30*16 см, expedition valiant, ex-box-ls',
#  'коробка для хранения на молнии из синтетического волокна hausmann, 35,5х20,5х13,5 см, зеленая, bb211-3',
#  'набор вешалок мягких тканевых с перекладиной 38х15 см 2 шт валиант / valiant val 7054sb',
#  'наматрасник wellness wm180, 100% хлопок, 180х200 см, стеганый белый, 4607101067749',
#  'наматрицник-чехол natures стебель бамбука сб-н-1-1 односпальный, бамбуковый, 90х200 см, молочный',
#  'насадка для швабры многофункциональной из микрофибры, rozenbal, r810001',
#  'перчатки латексные 10 шт размер s, r105816, rozenbal',
#  'сушилка для белья напольная gimi tempo super',
#  'таз пластмассовый 6,0 л пищевой квадратный "тюльпан" пц2950, 1404003',
#  'швабра многофункциональная rozenbal r212522-1',
#  'швабра сальса треугольная мини, y8110',
#  'щетка для посуды из искусственного волокна и пластмассы 20 см белая, burstenmann, 0703/0065',
#  'тарелка обеденная luminarc грин форест 26 см h7239',
#  'рассада зелени для кухни лаванды в горшке диам. 9 см',
#  'рассада зелени для кухни розмарина в горшке диам. 9 см',
#  'рассада зелени для кухни тимьяна в горшке диам. 9 см',
#  'коврик придверный, полукруглый из резины и кокоса, 40х68 см, format mezzaluna, розетта, коричневый, php srl, 20657',
#  'ножеточка универсальная "рыбка" 1519028',
#  'вешалка-плечики без эссенции цвет тёмно-розовый fwm-002/quartz pink',
#  'искусственный цветок пластиковый мак 3 бутона 48 см',
#  'искусственный цветок ромашка пластик 45 см',
#  'цветок искусственный гвоздика пластиковая одиночная в ассортименте 50 см',
#  'цветок искусственный мак 45 см пластик',
#  'цветок искусственный мак 55 см пластик',
#  'цветок искусственный нарцисс одиночный в ассортименте 35 см',
#  'цветок искусственный роза алая бархатная раскрытый бутон 63 см',
#  'цветок искусственный ромашка 3 цветка 50 см пластик',
#  'цветок искусственный тюльпан 45 см пластик цвет в ассортименте',
#  'цветок искусственный тюльпан в ассортименте одиночный 63 см',
#  'салфетка камушки транспарент 30*40 см 5187 dasch',
#  'тележка багажная delta тбр-22 коричневый грузоподъемность 20 кг сумка и 50 кг каркас россия',
#  'гладильная доска colombo avantgard 120х40 см',
#  'бегония ампельная, диам. 12 см',
#  'рассада пеларгония (герань) зональная блу айз mix смесь объем 0,5 л',
#  'хризантема корейская смесь окрасок объем 0,75 л',
#  'многолетнее растение душица-орегано розовый объем 0,5 л',
#  'пеларгония зональная диам. 12 см белая полумахровая',
#  'чехол для гладильной доски с дизайном venezia 140х55 см из хлопка',
#  'настольная гладильная доска фанера, 85*30, нд, ника',
#  'кувшин пластмассовый с крышкой 2,0 л, (s-751) "пластхозторг" 1408004',
#  'розмарин d-12 см',
#  'сиденье в ванну раздвижное, белый, св5, ника',
#  'сушилка для белья gimi extension',
#  'масленка коровка с крышкой 17см, 73115, luminarc, франция',
#  'плечики пластмассовые размер 52 - 54 тула 1205158',
#  'сушилка для белья eurogold stabilo 18 напольная 0503 se',
#  'стремянка бытовая framar slimmy 3 ступени',
#  'сумка-тележка 2-х колесная gimi argo фуксия',
#  'подрукавник gimi planet для гладильной доски',
#  'чехол для гладильной доски i love gimi l из полиэстера и хлопка 136*58 см, gimi',
#  'штора для ванной комнаты quadretto 240х200 см белая, bacchetta, 4062',
#  'утюг электрический с керамическим покрытием delta lux dl-350 зеленый, 2200 вт , россия',
#  'чехол для гладильной доски attribute metal 140х60 см abm106',
#  'муляж яблоко 9 см красное',
#  'гладильная доска attribute хоми топ 124х40 см синяя abh010',
#  'чехол для гладильной доски metal 135х53 см, attribute, abm105',
#  'корыто оцинкованное 45 л бесшовное, 1301031',
#  'тележка багажная delta тбр-20 черный с серым грузоподъемность 25 кг сумка 50 кг каркас россия',
#  'штора для ванной комнаты 182х182 см пвх meiwa, krackle прозрачный 5911',
#  'холодная сварка mastix 55г для труб и батарей, 1205197',
#  'холодная сварка mastix 55г универсальная, 1205037',
#  'гладильная доска ника бэлль 106,5х29 см б',
#  'муляж вишня 3 см 10 шт полиуретан',
#  'муляж груша желтый 9,5 см полиуретан',
#  'муляж мандарин оранжевый 8 см полиуретан',
#  'муляж перец чили в связке, красный, 60 см, полиуретан, fancy fair/ff rp60',
#  'муляж чеснок в связке 60 см полиуретан',
#  'сервировочная салфетка пвх 26х41 см ванда 6001',
#  'коврик противоскользящий кружевной 88х38 см прозрачный 5528',
#  'штора для ванной комнаты bacchetta city текстильная 180х200 см 6023',
#  'гладильная доска ника стелла классик 1 122х34,5 см стк1',
#  'штора для ванной комнаты bacchetta dama текстильная 180х200 см 3655',
#  'салатник luminarc кутюр 16 см h3386',
#  'салатник luminarc кутюр 27 см h3529',
#  'тарелка десертная кутюр 20,5 см j2402 luminarc',
#  'тарелка суповая кутюр 22,5 см j2397 luminarc',
#  'коврик придверный полипропиленовый с пвх step in traditional 90х150 см коричневый',
#  'сумка-тележка хозяйственная andersen scala shopper plus, lini, синяя 133-108-90',
#  'гладильная доска ника sophy корица hsk 123х46 см',
#  'коврик противоскользящий пузырьки 70х38 см прозрачный 5523',
#  'чехол для гладильной доски универсальный с поролоном 2, 1290 х 500, чп2, ника',
#  'сумка-тележка хозяйственная gimi argo голубая',
#  'муляж ананас светло-коричневый 10 см полиуретан',
#  'муляж баклажан 18 см',
#  'муляж банан желтый 21 см полиуретан',
#  'муляж груша мини 2 шт желтая 4 см',
#  'муляж манго оранжевый 13 см полиуретан',
#  'муляж морковь 16 см',
#  'муляж персик 9 см полиуретан',
#  'муляж тыквы d-20 см',
#  'муляж черешня 10 штук d 2,5 см, цвет в ассортименте',
#  'сумка-тележка хозяйственная rolser bab010 negro joy-1800 черная',
#  'чехол для гладильной доски zalger 520133 120х40 см хлопок поролон для доски 115х35 см',
#  'сумка-тележка 2-х колесная gimi galaxy черная',
#  'сковорода scovo эксперт дем сэ-040 для блинов алюминиевая с антипригарным покрытием, 25 см, 1503020',
#  'герань домашняя (пеларгония зональная) цветущая , d12, h25-30, лососевая, полумахровая',
#  'коврик придверный с дизайном, из резины и кокоса aberdeen welcome 45x76, 4395',
#  'коврик придверный redstone mix из полиэстера и переработанной резины 60х91 см серо-коричневый, apache, 4651',
#  'коврик придверный stonehedge grey из полиэстера и переработанной резины 60х91 см серый, apache, 4652',
#  'сумка-тележка хозяйственная rolser imx005 marengo logic dos+2 серая',
#  'банка стеклянная steel touch 1700 мл, attribute, abs017',
#  'тарелка десертная стоунмания оранж 20,5 см h3557 luminarc',
#  'тарелка обеденная стоунмания оранж 25 см h3556 luminarc',
#  'тарелка суповая стоунмания оранж 20 см h3558 luminarc',
#  'скатерть из пвх meiwa fplus-plain sarasa az be овальная 152х228 см бежевая 5789',
#  'муляж вишня на магните',
#  'сумка-тележка 2-х колесная складная gimi flexi серая',
#  'сумка-тележка 2-х колесная gimi ideal синяя',
#  'шнур резиновый для тележки 110 см, 1209002',
#  'шнур резиновый для тележки 80 см, 1209001',
#  'рассада зелени для кухни душицы в горшке диам. 9 см',
#  'сумка-тележка хозяйственная rolser mou041 malva rd6 сиреневая',
#  'таз пластмассовый строительный прямоугольный 80 л, 1404085',
#  'урна уличная "гео", hobbyka/хоббика, 59*37,5см, сталь',
#  'скатерть азалия 88% полиэфир 12% хлопок прямоугольная 350х150 см персиковая wellness mc355-азалия*05',
#  'сумка-тележка хозяйственная gimi bella серая',
#  'чайный набор luminarc рейнбоу 220 мл j5978',
#  'штора для ванной текстильная180х200 quadretto белая, bacchetta, 3003',
#  'пеларгония зональная диам. 12 см малиновая махровая',
#  'пеларгония зональная диам. 12 см розовая махровая',
#  'пеларгония зональная розоцветная ред розебад (red rosebud)',
#  'набор эмалированных салатников metalloni ветка рябины em-00003a/31 12,14,16 см',
#  'мыло жидкое reffil mama utimate облепиха 500 мл россия 8809193042321',
#  'набор вешалок мягких тканевых с перекладиной и клипсами 48х23 см 2 шт валиант / valiant val 7057gc',
#  'стремянка 5 ступенчатая hailo 8925-901 l9 алюминиевая',
#  'антуриум андрианум ванилла d-12 см',
#  'рыбочистка металлическая, 1216396',
#  'сиденье для унитаза росспласт ажур белое рп-813',
#  'коврик придверный attribute nature кокосовый 60x40 см amc015',
#  'овощеварка алюминиевая scovo мт-045, хозлэнд, 1502079',
#  'сметка с совком престиж, york, g6207',
#  'коврик придверный, полипропилен, 40х70 см, kokarda, спящий кот, бежевый, php srl, 20734',
#  'муляж баклажан мини 2 шт',
#  'муляж гранат мини 4 шт',
#  'муляж перец чили мини 2 шт, красный 7 см',
#  'чехол для гладильной доски basic 120х40 см, attribute, abb004',
#  'халат вафельный виктория_3-42 , 100% хлопок 265 g/m2, размер 52-54, салатовый, wellness, 2000000168616',
#  'измерительный алюминиевый угольник, 20*30 см, truper, e-8x12/14386',
#  'линейка, длина 30 см, truper, rgl-30/14387',
#  'сумка-тележка хозяйственная gimi ideal серая (tortora)',
#  'набор фужеров для вина аллюр 6шт 250мл, g5747, luminarc, франция',
#  'набор фужеров для вина маскарад 6шт 250мл, g5544, luminarc, франция',
#  'сушилка для белья лиана люкс 190 см потолочная',
#  'сушилка для белья leifheit 81570 pegasus 150 87х157х55 см',
#  'сумка-тележка хозяйственная rolser bab008 marengo joy-1800 серая',
#  'чехол для гладильной доски leifheit beach and bubbles 130x45 см 71596',
#  'терка webber из нержавеющей стали ве-048 4 грани 20 см с красной ручкой',
#  'терка webber из нержавеющей стали ве-054 6 граней 21 см',
#  'вилка столовая better цветной горох bt-c2003e-td1/d1',
#  'контейнер для приготовления 2-х яиц глазунья полимербыт c452',
#  'кружка 350 мл rosario радуга керамическая коричневый ф13-005l',
#  'кружка для чая ягода клубника 250 мл 1606-д',
#  'кружка luminarc лили флауэр 320 мл j8565-1',
#  'ложка обувная металлическая крашенная 43 см с крючком, 1205156',
#  'лопатка attribute bamboo agb110',
#  'лопатка c прорезями attribute bamboo agb111',
#  'набор фужеров для красного вина 235 мл, 6 шт., серия касабланка, 51258b',
#  'набор фужеров для шампанского френч брассери 6шт 170мл, h9452, luminarc, франция',
#  'полотенце махровое гармония, 100% хлопок 335 г/м2, 32х70 см, wellness, 4630005362832',
#  'салфетка махровая радуга в разноцветную полоску, 100% хлопок 312 г/м2, 31х31 см, wellness, 4630005360012',
#  'салфетница металлическая webber с хромированным покрытием 14,7*4*9 см be-0293',
#  'стакан низкий лабиринт 250 мл для напитков 05с1262',
#  'стакан пластмассовый 300 мл, конус. (к-308) "пластхозторг" 1535027',
#  'столовая ложка better цветной горох bt-c2003e-td2/d1',
#  'чайная ложка better цветной горох bt-c2003e-td3/d1',
#  'цветок искусственный крокус 20 см',
#  'цветок искусственный гербера, 45см',
#  'ковер придверный имитация травы 60х90см , цвет серый',
#  'тележка багажная delta тбр-23 грузоподъемность 50 кг россия',
#  'тарелка десертная ирис d3700 luminarc',
#  'гладильная доска attribute teflonix 130х46 см abt142',
#  'коврик для ванной комнаты gobi полиэстер 120х70 см темно-зеленый, spirella, 1012778',
#  'альбука спиралис фризл-сизл d-12 см',
#  'коврик sochi 50х80 см коричневый 5801',
#  'овощечистка с плавающим лезвием comfortline из нержавеющей стали и пластика 11 см белая, leifheit, 03151',
#  'бальзамин новогвинейский d-13 см',
#  'бегония клубневая d-13 см',
#  'крассула овата d-10 см',
#  'гладильная доска ника bruna m hbm 122х40 см',
#  'артемизия (полынь горькая) d-9 см',
#  'пеларгония зональная махровая микс d-12 см',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, красно-розовая, простая',
#  'насадка к швабре flexinett пластик + микрофибра, rozenbal, r212585',
#  'средство для удаления известкового налета с поверхностей сантехнических приборов decs антикальций 500 мл россия 4660015923266',
#  'фиалка микс d-9 см',
#  'коврик ворсовый для ванной комнаты orthospa river rocks grey из микрофибры и пвх прямоугольный 50х85 см серо-белый, apache, 4666',
#  'вешалка напольная atlant 90х42 см vatl-1 светлая степанов',
#  'сумка-тележка 2-х колесная gimi galaxy голубая',
#  'тележка хозяйственная ролла с крыльями, attribute, att101',
#  'бензин для зажигалок, 1205214',
#  'скатерть прямоугольная ажурная imperial 140х200 см бежевая с тесненым рисунком towa co 5174',
#  'паста для полировки "гои" 25 гр',
#  'цветок искусственный гортензия, 58 см, цвет в ассортименте',
#  'гладильная доска ника дсп эконом 106,5х29 эк1',
#  'сумка-тележка хозяйственная gimi argo салатовая',
#  'сумка-тележка хозяйственная gimi easy go синяя',
#  'петля-стрела пс-286 мм (рыбинск), 1104019',
#  'сушилка для белья лиана люкс 120 см потолочная',
#  'скатерть из пвх meiwa fplus-171 az wh/be овальная 132х178 см бело-бежевая 5785',
#  'подголовник для ванной комнаты из пвх 25х34 mickey, bacchetta, 4811',
#  'сушилка для белья потолочная zalger lift comfort 520 180 см 9 м',
#  'лаванда d-9 см',
#  'мята d-9 см',
#  'сушилка для белья виолет fh color lux 22 м белая вл867',
#  'муляж виноград зеленый 26 см полиуретан',
#  'чайник электрический пластиковый василиса t7-1100 белый с голубым 1100 вт 1 л',
#  'вешалка-стойка № 9 дерево зми медный антик внп 211 м',
#  'стремянка металлическая 3 ступени, см3, ника',
#  'муляж виноград желтый 24 см полиуретан',
#  'муляж желудь 2 шт',
#  'муляж яблоко, оранжевый, 8,5 см, полиуретан',
#  'сумка-тележка gimi argo синяя',
#  'каланхое каландива белое d-7 см',
#  'примула акаулис микс d-10 см',
#  'держатель для туалетной бумаги с373 "полимербыт" 1713006',
#  'ёрш унитазный с подставкой wc "люкс", мультипласт, 1712007',
#  'пробка для ванны резиновая (д-40 мм) 1206155',
#  'штора для ванной с кольцами rl-0071 мыльные пузыри 180х180 см',
#  'чехол для гладильной доски zalger 520116 130х46 см хлопок для доски 125х42 см',
#  'чехол для гладильной доски zalger 520124 140х58 см хлопок для доски до 135х53 см',
#  'измельчитель овощей ручной шк-4 деревянный, 3 ножа, 1516020',
#  'сумка-тележка delta тбр-20 синий грузоподъемность 25 кг сумка и 50 кг каркас россия',
#  'коврик придверный из резины и кокоса, 40х68 см, format classic, соломка, коричневый, php srl, 20135',
#  'лоток для холодца эмалированный 1,5 л с пластмассовой крышкой с рисунком с-2508кп/4 стэма 1506085',
#  'сумка-тележка gimi easy go красная',
#  'вешалка-плечики 3 шт без эссенции цвет светло-бирюзовый fwm-002/aruba blue',
#  'вешалки мягкие для деликатных вещей 3 шт желтые',
#  'губка спираль металлическая eurohouse 2 шт eh3599',
#  'перчатки латексные 10 шт, р-р м, r105817, rozenbal',
#  'перчатки резиновые универсальные centi, р-р m, york, g9212',
#  'чехол для одежды большой 137х60х10 см светло-бежевый валиант / valiant tr-107h',
#  'чехол для одежды eva 150x65 см mhe017',
#  'ёрш унитазный пластмассовый, ваир 1712002',
#  'кофр для хранения hausmann подкроватный 80х40х15 см 2b-28040',
#  'сумка-тележка gimi argo красная',
#  'салфетка protec textil lino 30х43 см шоколад 6222',
#  'корзина для белья infinity curver 59 л белая 04754-n23-00',
#  'пробка для ванны резиновая с цепочкой 1206157',
#  'сушилка мульти 10м (1002010520027), attribute, adm110',
#  'чехол для гладильной доски zalger 520111 см металлизированный с поролоном для доски 120х42 см',
#  'салатник романтик гарден 17 см j7900 luminarc',
#  'фен дорожный delta dl-0904 бордовый с черным 2 режима мощности 1400 вт россия',
#  'чайник электрический аксинья кс-1003 корпус из жаропрочного стекла черный 2200 вт 1,8 л',
#  'штора для ванной и душа текстильная, 180х200см, "цветы", голубой, hsp394-b',
#  'штора для ванной комнаты пвх 180х180 см водоросли, 5919',
#  'вешалка настенная ника вн3 3 крючка медный антик',
#  'вешалка самоклеющая на 4 крючка 1110008',
#  'штора для ванной и душа текстильная, 180х200см."лилии", бежевый/белый с розовыми цветами, h125',
#  'салатник амори браун 16,5 см j2113 luminarc',
#  'салатник колорама рэд 17 см j7772 luminarc',
#  'салатник рапсоди оранж 16,5 см h8728 luminarc',
#  'салатник luminarc арти грин 16,5 см j1392',
#  'салатник luminarc арти пинк 16,5 см l2857',
#  'салатник luminarc арти пурпл 16 см g9834',
#  'салатник luminarc арти пурпл 16,5 см l2858',
#  'салатник luminarc amбиантэ анис 16 см l6415',
#  'салатник luminarc amбиантэ оранж 16 см l6417',
#  'кружка для чая сердечки 250 мл дсг55029146',
#  'дендробиум санок полар файр 1 ствол d-12 см',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, красная, простая',
#  'калоцефалус брауни крашеный осенний микс d-10 см',
#  'коврик придверный apache 45х76 см flagstone 5415',
#  'антижир posh one magnum 828 мл россия 4580390-927058',
#  'каллуна гарден герлс трехцветная d-12 см h-27 см',
#  'капсикум сальса оранжевый d-10 см',
#  'кофр малый жесткий 28*30*16 см леопард валиант / valiant lb301',
#  'мимоза стыдливая d-9 см',
#  'набор кухонных полотенец 100% хлопок 200г/м2 46*71 см 2 шт, wellness, мелиса_3',
#  'соланум d-10 см',
#  'универсальное средство на основе хлора ддля чистки сантехники и других поверхностей decs universal 750 мл россия 4660015923228',
#  'мантоварка алюминиевая 6,0 л 3 сетки белая калитва, хозлэнд, 1502074',
#  'гладильная доска ника lora fashion hlf 123х46 см',
#  'пеларгония зональная простая цвет фуксии',
#  'рассада зелени для кухни мелиссы в кассете по 6 шт',
#  'гладильная доска ника blues 124х46 см 5757',
#  'ложка обувная металлическая крашенная 220, 1205155',
#  'плечики пластмассовые размер 48 - 54 мп 1205160',
#  'ролик для чистки одежды *clear line* (20 слоев), 1205060',
#  'сменный блок для ролика 2 шт (r160071), rozenbal, r510100',
#  'таз пластмассовый 4,5 л пищевой "космея" (ангора) 1404092',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, ярко розовая, полумахровая',
#  'пеларгония d-13 см с топпером на день учителя в подарочной упаковке',
#  'роза патио белая d-12 см h-30',
#  'роза патио красная d-12 см h-30',
#  'роза патио оранжевая d-12 см h-30',
#  'стремянка 5 ступенчатая hailo 8150-507 l50 алюминиевая с крючком на красной ручке',
#  'набор бокалов император 3 шт 170 мл 06707 e5181 luminarc франция',
#  'набор стаканов для виски 300 мл 6 шт серия карат 52885в',
#  'термометр на окно уличный на липучках т-5 h-20 см 1210035',
#  'термометр уличный оконный тб 202 h-20 см 1210036',
#  'ящик почтовый металлический с ушками для навесного замка домик 1205251',
#  'сушилка для белья напольная gimi mito, алюминий',
#  'гладильная доска ника верона 1 чехол ретро 122х42 см дв1р',
#  'бархатцы веселая полянка 0,3 г 4660010777505',
#  'космея очаровашка 0,05 г 4660010779578',
#  'морковь детская сладость 2 г 4660010775921',
#  'настурция драгоценность вишнево-розовая 1 г 4660010773316',
#  'огурец засолочный 0,3 г 4660010776102',
#  'пеларгония зональная розоцветная ред розебад',
#  'петуния каскад смесь махровая 10 шт 4660010772784',
#  'сумка-тележка хозяйственная rolser jet joy черная, jet010 negro joy',
#  'шило с пластмассовой ручкой утолщенное с крючком, 1205083',
#  'герань домашняя (пеларгония зональная) цветущая d12, h25-30, красная, полумахровая',
#  'тарелка обеденная мунлайт 25 см h7253 luminarc',
#  'скатерть прямоугольная ажурная marine 132х177 см бежевая с тесненым рисунком towa co 4022',
#  'сушилка для белья ника сб2б 20 м',
#  'сушилка для белья ника сб1 18 м',
#  'вешалка деревянная с расширенными плечиками и перекладиной 44,5х23 см см белый japanese white valiant jw-19708',
#  'вешалка для брюк attribute classic 38 см ahn271',
#  'набор вешалок для костюма 45 см 4 шт цвет кремовый attribute ahp224',
#  'набор вешалок универсальных attribute siluet cream 45 см 4 шт ahp224',
#  'банка из стекла для сыпучих продуктов круглой с пластмассовой крышкой и цветной вкладкой 1,0л 10мр-0001',
#  'корзина для белья knit 57 л темно-коричневая, curver, 03676-x59-00',
#  'сумка-тележка twin стальной каркас 56 л синяя, gimi',
#  'гладильная доска ника стелла классик 2 122х34,5 см стк2',
#  'тарелка десертная воларэ блэк 22,5 см g9399 luminarc',
#  'сушилка для белья потолочная лиана 1,5 м 1703004',
#  'сушилка для белья gimi dinamik 30',
#  'таз пластмассовый 6,0 л пищевой м2511, 1404015',
#  'таз пластмассовый 8,0 л пищевой (минеральные воды), 1404009',
#  'ковш пластмассовый полимербыт с215, 1,5 л 1406006',
#  'гладильная доска-стремянка dasch 95х33 см 848n',
#  'гладильная доска ника николь 9 122х40 см',
#  'кухонные ножницы webber из нержавеющей стали с орехоколом ве-5208',
#  'набор ножей attribute chef 5 предметов akf522',
#  'нож кухонный для мяса с пластмассовой ручкой 305 х 175 мм, "русская линия" (нх-36м), метиз 1519003',
#  'нож кухонный для овощей с деревянной ручкой 318 х 200 мм, "гурман" (нх-14м), метиз 1519009',
#  'нож кухонный универсальный с пластмассовой ручкой 285 х 150 мм, "русская линия" (нх-38м) метиз 1519022',
#  'рыбочистка с деревянной ручкой с ножом 1518024',
#  'тарелка десертная мока браун 19 см h7013 luminarc',
#  'кисточка силиконовая для выпечки мятная 21х4 см be-1440s webber',
#  'кисточка силиконовая для выпечки персиковая 21х4 см be-1440s webber',
#  'скребок кондитерский webber be-0368 лавандовый',
#  'средство для мытья полов decs bleach лимон 1000 мл россия 4660015923273',
#  'комод эльфпласт виола 3-х секционный коричневый 339',
#  'корзина для белья виолет ротанг 2350/2 угловая с крышкой 60 л бежевая',
#  'сушилка для белья на ванну ника сб4',
#  'картофелемялка металлическая круглая с деревянной ручкой 1531002',
#  'сушилка для белья потолочная лиана 1,8 м 1703007',
#  'салатник воларэ блэк 16 см g9403 luminarc',
#  'тарелка суповая воларэ блэк 23 см g9402 luminarc',
#  'ароматизированное средство дудаления известкового налета и ржавчины decs wc гель лимон 750 мл россия 4660015923235',
#  'бальзам для мытья посуды mama ultimate ecosoda 1000 мл россия 044684',
#  'средство для мытья пола ecomatic green cleaner 1000 мл испания 126109',
#  'стремянка бытовая zalger 111-5 алюминиевая 5 ступенек',
#  'банка стеклянная с крышкой attribute fleur 1350 мл abf100g',
#  'банка стеклянная с крышкой attribute fleur 650 мл abf135w',
#  'коврик кухонный apache olive oil sideboard 56х86 см 5062',
#  'штора для ванной 180х200 см, rigone бежевый',
#  'алиссум (лобулярия) снежные одежды 0,2 г 4650091480302',
#  'гвоздика турецкая роковая страсть 0,05 г 4660010773231',
#  'годеция рембранд 0,1 г 4650091480128',
#  'календула пинк сюрпрайз 0,5 г 4650091480203',
#  'капуста декоративная смесь 0,1 г 4650091480234',
#  'кореопсис толл 0,1 г 4650091480258',
#  'космея клюквенный клик 0,1 г 4660010770421',
#  'космея кэнди страйп 0,3 г 4650091480272',
#  'лапчатка огненное пламя 0,02 г 4650091480616',
#  'львиный зев волшебный ковер 0,05 г 4660010779639',
#  'пеларгония зональная диам. 12 см розово-красная полумахровая',
#  'флокс друммонда смесь 0,1 г 4650091480401',
#  'цинерария серебряная пыль 0,1 г 4660010770797',
#  'эшшольция карминный король 0,5 г 4660010770193',
#  'жестяная банка новая паста микс п-90*90h171v140-01014',
#  'кружка нордик 380мл прозрачная h8502 luminarc франция',
#  'чайник электрический аксинья кс-1002 корпус из жаропрочного стекла белый 2000 вт 1,8 л',
#  'гладильная доска scab stiro lux 122х38 см',
#  'рассекатель пламени на газовую плиту с ручкой, an8032',
#  'ополаскиватель для посудомоечных машин ludwik 750 мл польша 5900861242715',
#  'сетка для глажения ява ртк26 45х65 см, 1200023',
#  'сковорода алюминиевая с антипригарным покрытием marble alpenkok d = 22 см ak-0037a/22n',
#  'щетка для посуды *оля*, мультипласт 1807010',
#  'чайник электрический василиса т33-2000 нержавеющая сталь красный 2000 вт 2 л',
#  'покрывало жаккард шенилл birhome valentin 240х260 см наволочки 50х70 см 2 шт 9234567089661',
#  'вешалка гардеробная радуга 2 зми черный внп 299 ч',
#  'ковер придверный ekspo 90х150 см черный рр114/01019',
#  'набор форм для кексов webber из нержавеющей стали 6 шт 7,5*3,4 см be-4343/6',
#  'банка стеклянная wooden touch 1700 мл, attribute, abb017',
#  'корзина для белья пластмассовая 45 л угловая с299 1704006',
#  'весы напольные электронные soehnle pino white, 63747',
#  'лестница-стремянка dogrular ufuk оцинкованная 4-х ступенчатая',
#  'диффенбахия d-12 см с топпером на день учителя в подарочной упаковке',
#  'комплект постельного белья wellness platinum r185-авеню пододеяльник 180х214 см простыня 200х214 см 2 наволочки 50х70 см',
#  'покрывало жаккард karna стеганое kalven 260x260 см наволочки 50х70 см 2 шт 8681914002162',
#  'вилка столовая better цветы bt-c2003e-td1/d3',
#  'бальзамин новогвинейский d-13 см цвет фуксии',
#  'чехол для гладильной доски zalger 520132 114х37 см бязь для доски 110х32 см',
#  'фаленопсис королевский голубой 1 ствол d-12 см',
#  'сумка-тележка хозяйственная rolser rg saquet, синяя, saq002 azul convert',
#  'подставка для обуви резиновая attribute 80x40 см amc080',
#  'сушилка для белья потолочная лиана люкс 160 см ллп-160',
#  'вешалка-сушилка gimi paco',
#  'коврик bacchetta противоскользящий в душевую кабину 55х55 см бежевый 4819',
#  'штора для ванной комнаты 240х200 fragmmento бежевая текстильная 240х200 см 6041',
#  'штора для ванной комнаты пвх sfera 240х200 см серая, bacchetta, 4833',
#  'миска пластмассовая круглая пластхозторг s-706, 0,8 л 1535005',
#  'гладильная доска ника белль классик 1 122х34,5 см бк1',
#  'кружка прозрачная 250 мл h8437 luminarc франция',
#  'одеяло silver line 195*215 100% микрофибра 100% микроволокно 17т-0034/2',
#  'сушилка для белья на батарею ника сб6-65 двухъярусная',
#  'подсолнечник низкорослый d-13 см',
#  'ручка-скоба рс-100 белая *трибатрон*, 1108035',
#  'пуансетия d-12 см с топпером на день учителя в подарочной упаковке',
#  'лоток для холодца эмалированный 1,5 л с пластмассовой крышкой без рисунка с-2508кп стэма 1506084',
#  'гладильная доска eurogold professional 130х48 см 35748w',
#  'сушилка для белья напольная colombo alpina 40mt st194/4cf',
#  'пресс для чеснока attribute western agw050',
#  'сушилка для белья потолочная лиана люкс 250 см ллп-250',
#  'тарелка обеденная кашима пурпл 25 см g9324 luminarc',
#  'сумка-тележка 3-х колесная gimi tris красная',
#  'коврик придверный хлопковый 60х180 см мультиколор, helex, с05',
#  'лестница-стремянка примус оцинкованный металл 7 ступеней, 1,55 м , 1203048',
#  'щетка-сметка с пластиковой ручкой лаура sv3020',
#  'термостакан webber be-6030 кофе 450 мл',
#  'гиностемма укорененный черенок 1 шт',
#  'сумка-тележка хозяйственная andersen treppensteiger scala shopper, hera, черная 119-004-80',
#  'ель канадская коника ртк 303 горшок 9 л нидерланды',
#  'кипарисовик лавсона элвуди ртк 106 горшок 9 л нидерланды',
#  'коврик противоскользящий камешки с ракушками овальный 69х39 см голубой 5520',
#  'аптения d-10 см h-10 см',
#  'сушилка для белья потолочная лиана люкс 170 см ллп-170',
#  'коврик придверный каучуковый 45х75 см черный, helex, p01',
#  'антуриум андрианум фиорино d-15 см',
#  'сушилка для белья потолочно-настенная gimi lift 240 5031',
#  'банка рондо элиз 1л, g8487, luminarc, китай',
#  'сушилка для белья attribute прима 18 м синяя adp618',
#  'весы напольные механические дельта d-2017 130 кг, 1205224',
#  'таз пластмассовый 12,0 л пищевой (минеральные воды), 1404022',
#  'роза палас белая d-17 см h-50 см h-20',
#  'ковер придверный ekspo 90х150 см коричневый рр120/1',
#  'сушилка для белья gimi mito алюминий',
#  'новогоднее дерево ель канадская коника ртк 343 d-9 см',
#  'гладильная доска ника эльза премиум 122х40 см элп',
#  'новогоднее дерево ель сербская d-21 см h-60 см',
#  'чехол для одежды малый 100х60х10 см светло-бежевый валиант / valiant tr-106h',
#  'новогоднее дерево ель канадская коника в красном ведерке 3 л h-40 см',
#  'мыльница пластмассовая на ванну м2221 1702010',
#  'подголовник bacchetta 25х34 см quadrifoglio 4809',
#  'сушилка для белья gimi modular 3 lux silver',
#  'коврик dasch для ванной комнаты 50х80 см tl-90 листопад зеленый 5730',
#  'сушилка для белья напольная ника сб9/а цвет аквамарин/белый',
#  'пеларгония грандифлора махровая микс d-12 см',
#  'муляж мандарин мини на магните',
#  'салфетка protec textil lino 30х43 см натур 6223',
#  'мыло ручной работы свинюшка в грязюшке 90 г',
#  'гладильная доска leifheit airboard compact m plus 120х38 см малиновый 71630',
#  'сушилка для белья на ванну leifheit adria 72708',
#  'крючок одежный двойной усиленный алюминиевый (дюраль), 1110015',
#  'гладильная доска ника бэлль-юниор1 112х34,5 см бю1',
#  'чехол для одежды hausmann со стенкой из пвх и ручками 60х140 см синий hm-701402ng',
#  'набор бокалов для пива cervoise 4 шт 320мл g3775 luminarc франция',
#  'защитный экран подставка и дуршлаг webber 3 в 1 цвет: зеленый d = 28,5 см из силикона be-0341s',
#  "многофункциональный инструмент 25 функций, plb025l 7'/pt00234",
#  'роза мини розовая d-7 см h-10',
#  'коврик в ванну 36х71 см, розовый',
#  'стремянка-табурет алюминиевая hailo l90 step-ke 4442-701 2х2 ступени',
#  'пуансеттия d-12 см красная с розовым',
#  'коврик противоскользящий пузырьки 70х38 см бирюзовый 5526',
#  'пуансеттия d-12 см белая',
#  'петля рояльная оксид 545 мм, 1103066',
#  'тележка багажная delta тбр-21 черный грузоподъемность 25 кг для сумка и 50 кг для каркас россия',
#  'новогоднее дерево ель сербская d-27 см h-200 см',
#  'цветущее комнатное растение бегония элатиор, цвет в ассортименте',
#  'чайная ложка 6 предметов вена счв107',
#  'нож для мясорубки (супер) лепесток 1512016',
#  'крассула d-17 см h-40 см',
#  'тарелка суповая ирис 21 см j1299 luminarc',
#  'комплект махровых салфеток топ_2, 100% хлопок 266 г/м2, 28х42 см, 2 шт, цвета в ассортименте, wellness, 4630005364393',
#  'набор столовых приборов 24 предмета oasis domenik dm9634',
#  'пуансеттия d-15 см розовая',
#  'набор столовых приборов 24 предмета saint germain domenik dm9638',
#  'коврик ворсовый для ванной комнаты orthospa river rocks natural из микрофибры и пвх прямоугольный 50х85 см серо-коричневый, apac',
#  'кольца для штор виолет 12 шт пластик 1212/60',
#  'скатерть сидней 100% полиэфир овальная 300х150 см сиреневая wellness wto305-сидней*81',
#  'кувшин luminarc виктория 1,8 л с крышкой j8130',
#  'пуансеттия d-15 см красная',
#  'набор столовых приборов 24 предмета farandole domenik dm9635',
#  'сумка-тележка 3-х колесная gimi tris черная',
#  'чехол для одежды объемный hausmann с овальным окном пвх и ручками 60х140х10 см черный hm-701403ag',
#  'коврик ворсовый пвх придверный multy 60х180 см коричневый',
#  'чайный набор сельма 220мл, g9434, luminarc, франция',
#  'вешалка напольная twist складная 45*35 vrtw-1 светлая степанов',
#  'скатерть towa co ажурная presea прямоуголная 120х150 см сепия 5514',
#  'вантуз черный с пластиковой ручкой малый д-100 (маг), 1206002',
#  'вешалка с закругленными плечиками перекладиной и крючками с противоскользящим покрытием valiant 213r11 черный',
#  'термокружка alpenkok ak-04010a синий 400 мл',
#  'чехол для гладильной доски универсальный с поролоном антипригарный, чпа, ника',
#  'сушилка для белья потолочная лиана люкс 180 см ллп-180',
#  'плед флисовый 200х150 см wellness wplny152-зима_4 100 % полиэстер',
#  'сумка-тележка хозяйственная rolser bab010 rojo joy-1800 красная',
#  'гладильная доска ника loreta golf hl 123х46 см',
#  'фоторамка alparaisa на 7 фотографий бронзовая 43х42,5 см с31-017',
#  'этажерка 2 для обуви узкая 4 полки, медный, эт2, ника',
#  'тарелка десертная бамбук 20 см j0276 luminarc',
#  'скатерть джулия 64% хлопок 36% полиэфир прямоугольная 350х150 см золотая с голубым wellness mt355-джулия*16',
#  'сервировочная салфетка пвх 26х41 см капучино 6163',
#  'гладильная доска attribute teflonix 135х46 см оранжевая abt044',
#  'чайник эмалированный metalloni со свистком и керамической ручкой французский шарм 2,5 л em-250x1/28',
#  'новогоднее дерево ель канадская коника в декоративном контейнере 1 л h-20 см',
#  'таз пластмассовый 30,0 л пищевой овальный (иж), 1404055',
#  'сушилка для белья напольная colombo alpina 30mt st194/3cf',
#  'шнур резиновый для тележки 200 см белый, 1209004',
#  'термос со стеклянной колбой 1,2 л 21013',
#  'скиммия японская рубелла d-19 см h-40 см',
#  'лестница-стремянка dogrular ufuk оцинкованная 8-ми ступенчатая',
#  'аспарагус спренжери d-12 см',
#  'сумка-тележка хозяйственная rolser jet claudia joy черная, jet006 negro joy',
#  'доска разделочная alparaisa стеклянная завтрак 20х30 см rd0030-st',
#  'чайный набор 220 мл карин ромашка, g1988, luminarc, оаэ',
#  'штора для ванной комнаты bacchetta fragmmento бежевая текстильная 180х200 см 6034',
#  'тарелка суповая luminarc океан эклипс 20,5 см l5079',
#  'гладильная доска ника бест 122х40 см нб',
#  'розмарин d-9 см',
#  'пуансеттия d-23 см белая',
#  'набор бокалов для шампанского леди даймонд 6 шт 150 мл g5208 luminarc франция',
#  'коврик придверный пористый из полимерных материалов 60х90 см коричневый, vortex, d022',
#  'гладильная доска dogrular домина 125х42 см 223708',
#  'сумка-тележка хозяйственная rolser rg saquet, черная, saq002 negro convert',
#  'сумка хозяйственная на колесах, 1209020',
#  'скатерть 350х180 см wellness wt358-лувр*02 100% полиэстер',
#  'роза кордана белая d-10 см h-20',
#  'сушилка для белья meliconi miss stendy',
#  'кружка бамбук 320 мл g0688 luminarc франция',
#  'комод эльфпласт № 3 алфавит оранжевый 301о',
#  'скатерть арлет 50% полиэфир 50% хлопок овальная 350х175 см светло-бежевая wellness mlo357-арлет*17',
#  'корыто оцинкованное 45 л бесшовное, 1303007',
#  'сумка-тележка хозяйственная gimi brava',
#  'сушилка для белья напольная colombo bella 20 м st387',
#  'штора для ванной комнаты 240х200 sintra бежевая текстильная 240х200 см 6039',
#  'кондиционер для белья sandokkaebi soft aroma aqua blue свежесть океана флакон 2100 мл корея 8801353-003494',
#  'фарфоровая кружка rosario бабочка 550 мл ф16-013l',
#  'термокружка alpenkok ak-04009a красный 400 мл',
#  'пуансеттия d-12 см красная',
#  'сумка-тележка хозяйственная rolser pack gloria logic rg серая, pac036 marengo logic rg',
#  'вешалка металлическая valiant с четырьмя разъемными перекладинами противоскользящим покрытием 35*30 см 18b30',
#  'корзина пластиковая для белья 40л. с крышкой белая 1840/06, виолет',
#  'стремянка бытовая framar slimmy 4 ступени',
#  'вешалка настенная ника вп6с с полкой 6 крючков серебро',
#  'термос 1л svb-1000h',
#  'вешалка гардеробная радуга 1 зми белое серебро внп 298 бс',
#  'стремянка framar major tech 4 алюминиевая 4-х ступенчатая 4126',
#  'плед флисовый 150х130 см wellness wplny135-зима_10 100 % полиэстер',
#  'вилка столовая 3 шт тяжелая серия сапфир свweddel-2',
#  'коврик придверный хлопковый 60х140 см мультиколор, helex, с04',
#  'скатерть виниловая тисненая с ажурной каймой 137х182 см водонепроницаемая тд5-0077',
#  'электроштопор qwerty белый 4,5?23,4 см на батарейках 4хаа 71000',
#  'коврик придверный полиэстер, 46х76 см, drifted nature, изменчивость, mohawk, 5007',
#  'коврик придверный alpine wrought iron из полиэстера и переработанной резины 45x76 см, apache, 4649',
#  'стремянка eurogold colour 2х ступенчатая с противоскользящим покрытием, сталь 2022r/2122r',
#  'тарелка обеденная luminarc океан эклипс 24 см l5078',
#  'коврик для ванной комнаты, 50*80*1,4 см, мягкая основа, expedition history valiant, exp-h-58',
#  'настенная сушилка для белья gimi brio super 120',
#  'сумка-тележка хозяйственная gimi rolling thermo синяя',
#  'чайник эмалированный со свистком 2,5л ем-25001/17',
#  'коврик противоскользящий 69х39 см овальный черепаха 5538',
#  'комплект для мытья полов из нержавеющей стали и пластика clean twist mop зеленый: швабра-моп + ведро 20 л с механизмом отжима, l',
#  'корзина для белья виолет с крышкой ротанг 40 л латте 1840/20',
#  'простынь вафельная 200х180 см wellness rw180-01 100% хлопок',
#  'набор вешалок деревянных 3 шт с перекладиной 44,5х23х1,2 см лиловый romantic valiant rm-16601s',
#  'декоративная композиция искуственных цветов букет подсолнухов 115 см три бутона',
#  'сковорода scovo дем мт-029 алюминиевая без крышки с металической ручкой, 20 см',
#  'столовый нож ripple 80 г 2 шт attribute acr042',
#  'вешалка valiant для брюк и юбок металлическая 30*10.5 см 121b11',
#  'чехол для одежды hausmann розовый принт 60х100х104',
#  'пеларгония зональная диам. 12 см красный махровый',
#  'пеларгония зональная розоцветная маргарита лососевая 5-7 листов',
#  'блюдце утро эклипс, j3261, luminarc, франция',
#  'скатерть ажурная d-ia rose круглая д.152 белая 5173 towa co. ltd-',
#  'штора для ванной 180х200 см, rigone зеленый',
#  'контейнер для свч полимербыт премиум 1,2 л 4356200',
#  'сушилка для белья напольная ника сб1г 18 м бело-голубая',
#  'фиттония скелетон d-9 см',
#  'скатерть беатрис 50% полиэфир 50% хлопок прямоугольная 300х145 см светло-коричневая wellness ml304-беатрис*20',
#  'чехол eurogold clean metallic металлизированый с поролоном для досок 120х38-120х42 см c42f3m',
#  'роза кустовая ред лейс 60 см кения плантация waridi limited 10 штук в упаковке',
#  'чехол для одежды hausmann со стенкой из пвх и ручками 60х100 см ag',
#  'гладильная доска dogrular томрис 120x38 см',
#  'гладильная доска ника бэлль-юниор2 112х34,5 см бю2',
#  'полки qwerty лондон белый 27х27х10 см и 23х23х10 см 72000',
#  'тимьян d-9 см',
#  'бульонница luminarc мистигри 500 мл j8770',
#  'сушилка для белья напольная ника сбп1/с 18 м',
#  'нож для овощей и мяса (5024) 1518004',
#  'алоэ вера d-12 см h-25 см',
#  'гладильная доска nika haushalt тефлон золотой 122х40 см hp1t/g',
#  'жестяная банка гуси 0,8 л 11х9,9 см ц99h110v080-01339',
#  'пеларгония зональная диам. 12 см красно-розовая простая',
#  'комнатное растение в горшке сциндапсус зеленый подвесной горшок, d15-16, h30',
#  'сушилка для белья напольная ника сб3б 10 м белая',
#  'роза одноголовая родос 70 см кения плантация subati flowers limited 10 штук в упаковке',
#  'сумка-тележка gimi italo blue синяя',
#  'щетка для мытья посуды колибри м5202 большая',
#  'миксер василиса ва-506 белый с красным/малиновым 180 вт 7 скоростных режимов',
#  'сушилка для белья напольная ника сб3 10 м',
#  'ключница картина w-12 замок 35х30 см',
#  'разделочная доска attribute granite 20х30 см abx111',
#  'штора для ванной spirella / спирелла tex porto, белый, текстиль с гидрофобной пропиткой, 180*200 см, 1033938',
#  'тарелка обеденная стелла шоколад 25 см j1762 luminarc',
#  'чайник электрический василиса т30-2000 нержавеющая сталь черный c красным 2000 вт 1,8 л',
#  'аптения d-12 см h-15 см',
#  'мантоварка-пароварка webber be-81 нержавеющая сталь d=30 см',
#  'складная картонная коробка для хранения 30х20х15 см с уголками белый hm-9741-3 hausmann',
#  'спатифиллум шопен d-12 см',
#  'чехол для гладильной доски colombo клубки пряжи серый/розовый 140х55 см из хлопка 5550',
#  'контейнер герметичный прямоугольный виолет 092/051 500 мл дымчатый',
#  'набор вешалок пластмассовых rozenbal r181900',
#  'искусственный цветок пластиковый нарцисс 3 бутона королевский 46 см',
#  'емкость для соуса с ложкой pasabahce 200 мл ots131505-000',
#  'фикус каучуконосный эластика абиджан d-12 см h-30 см',
#  'тарелка суповая luminarc мариса оранж 20 см j7687',
#  'защитная соль для посудомоечных машин ludwik 1,5 кг польша 5900861242227',
#  'таз пластмассовый 16,0 л пищевой круглый м2507, 1404037',
#  'гипоаллергенный концентрированный гель для стирки белья vpk для деликатных тканей 2,5 л корея 8809473130144',
#  'коврик придверный с дизайном, из резины и кокоса 58,5*89 gothic iron slice / готический узор, 4468',
#  'муляж ананас 21 см',
#  'сиденье для ванны пластмассовое м1552 1714003',
#  'скатерть 150х120 см wellness wt125-куэна 100% полиэстер',
#  'сумка-тележка 2-х колесная gimi argo черная',
#  'коврик кухонный apache coffee chef 45x75 см 5420',
#  'вешалка-перекладина valiant металлическая двойная с антискользящим покрытием 50320',
#  'скатерть муза 100% полиэфир овальная 180х150 см сливочная с цветами, wellness, wto185-муза*04',
#  'кружка мерная 11600 1 л',
#  'штора для ванной spirella / спирелла tex rings, текстиль с гидрофобной пропиткой, серо-черный, 180*200 см, 1015184',
#  'сушилка для белья лиана люкс 110 см потолочная',
#  'фиалка d-9 см белая махровая',
#  'штора для ванной spirella / спирелла tex shine текстиль с гидрофобной пропиткой, шампань, 180*200 см, 1015640',
#  'модульная стеклянная банка 1,1л, 298264, brabantia,',
#  'сушилка для белья zalger simfony 1255-90 одноуровневая с крыльями 20 м',
#  'контейнер для мусора пластиковый 50 л 40,7х30,6х72,7 см ролл топ серый, curver, d 03977-856',
#  'сушилка для белья настенная ника сн90 серебро 90 см',
#  'сушилка для белья потолочная лиана люкс 200 см ллп-200',
#  'перчатки fabrikators для чистки овощей детские оранжевый ko2pu',
#  'термостакан webber ве-6031 чай 450 мл',
#  'сумка-тележка хозяйственная rolser imx001 negro convert rg черная',
#  'столовая ложка attribute fortress 2 шт acf622',
#  'сушилка для белья hausmann hermes de luxe 20 м 03-010c-1',
#  'подставка для ножей alpenkok круглая из пластика 11*22 см красная ak-202st',
#  'лестница стремянка зми конёк медный антик тс 277',
#  'чайный набор luminarc лили флауэр 6 шт 320 мл j8565',
#  'весы напольные edition feet механические',
#  'петля рояльная цинк 960 мм, 1103055',
#  'банка стеклянная с металлической крышкой и краником attribute grape 3,8 л abs038',
#  'карниз для ванной комнаты виолет раздвижной 210 см с кольцами белый 2110/6',
#  'чехол для гладильной доски i love gimi m из полиэстера и хлопка 132*48 см, gimi',
#  'азалия индика фиолетовая d-10 см h-20',
#  'пеларгония зональная махровая белая взрослое растение',
#  'пеларгония розебудная emma укорененный черенок',
#  'пеларгония розебудная mary укорененный черенок',
#  'пеларгония розебудная prins nikolai укорененный черенок',
#  'полки qwerty берлин чёрный 44х24х10 см 40х20х10 см 36х16х10 см 72008',
#  'штора для ванной комнаты пвх 180х180 см ракушки бежевая, 5923',
#  'крючок проволочный 75 мм латунь, 1110136',
#  'цветок искусственный тюльпан 40 см пластик цвет в ассортименте',
#  'просеиватель для муки d27см., rsb',
#  'мусорный контейнер hailo bigbin swing 45 0845-010 45 л хром',
#  'пеларгония toscana angeleyes amarillo burgundy укорененный черенок',
#  'пеларгония toscana angeleyes amarillo rosato укорененный черенок',
#  'пеларгония розебудная queen ingrid укорененный черенок',
#  'пеларгония розебудная red pandora укорененный черенок',
#  'пеларгония toscana angeleyes bicolor укорененный черенок',
#  'скатерть meiwa fplus-plain sarasa az be прямоугольная152х228 см бежевая 5140 meiwa',
#  'кастрюля чугунная 24 см, красная, 3.6 л, pyrex, sc5ac24/5141',
#  'сиденье для гладильной доски leifheit niveau, 71325',
#  'штора для ванной 180х200 см, rigone розовый',
#  'весы настольные электронные delta ксе-01 белый 5кг',
#  'крючок проволочный 125 мм медь, 1110132',
#  'гладильная доска ника верона 1 чехол мужчина с розой 122х42 см дв1м',
#  'средство для мытья посуды vestar гранат 1000 мл россия 4620757211700',
#  'декоративная коробка stockholm xl classico 30*25*40 см d 04711-d41 curver 04711-d41',
#  'толкушка деревянная ( бук ) 1530018',
#  'махровое полотенце 70х35 см wellness exclusive 1дсж1_йота_1-67 100% хлопок',
#  'вешалка ника комфорт 6 напольная серебро вк6с',
#  'швабра для пола с отжимом и фиксатором микрофибра, r212608, rozenbal',
#  'искусственная лиана плющ 2,4 м',
#  'кодонанта укорененный черенок 1 шт',
#  'коврик придверный php srl 40х68 см format tour 21717 добро пожаловать 6008',
#  'гладильная доска белль-юниор1 34,5х112см дсп 1200006',
#  'кофр для хранения hausmann средний 36х36х30 2 шт. 4c-202',
#  ...]

# %%
prod_new = len(df_without_duplicates['product'].unique())
f'Количество товаров в ассортименте после обработки неявынх дубликатов: {prod_new}'
# Out:
# 'Количество товаров в ассортименте после обработки неявынх дубликатов: 2341'

# %% [markdown]
# #### Вывод:

# %% [markdown]
# Таким образом, после обработки дубликатов, нам удалось сделать ассортимент более "однородным" (из 2343 наименований до 443 ) , что в дальнейшем  поможет нам провести категоризацию товаров.

# %% [markdown]
# ### Кластаризация

# %%
for_claster = df_without_duplicates[['order_id', 'quantity', 'hours', 'price']].astype(float)
for_claster
# Out:
#       order_id  quantity  hours   price
# 0      68477.0       1.0    0.0   142.0
# 1      68477.0       1.0    0.0   194.0
# 2      68477.0       1.0    0.0   112.0
# 3      68477.0       1.0    0.0   179.0
# 4      68477.0       1.0    0.0   112.0
# ...        ...       ...    ...     ...
# 5994   73156.0       1.0   11.0   404.0
# 5995   73158.0       1.0   12.0  1087.0
# 5996   73162.0       1.0   13.0   157.0
# 5997   73164.0       1.0   14.0   397.0
# 5998   73137.0       1.0   16.0  1087.0
#
# [5999 rows x 4 columns]

# %%
#выделяем данные
X = for_claster

# %%
#стандартизируем данные
scaler = StandardScaler()
X_sc = scaler.fit_transform(X)

# %%
#построим матрицу расстояний функцией на стандартизованной матрице признаков
linked = linkage(X_sc, method = 'ward') 
linked
# Out:
# array([[1.17000000e+02, 1.18000000e+02, 0.00000000e+00, 2.00000000e+00],
#        [2.00000000e+00, 4.00000000e+00, 0.00000000e+00, 2.00000000e+00],
#        [2.83000000e+02, 2.84000000e+02, 0.00000000e+00, 2.00000000e+00],
#        ...,
#        [1.19880000e+04, 1.19930000e+04, 7.89743155e+01, 3.36100000e+03],
#        [4.78500000e+03, 1.19940000e+04, 8.71790952e+01, 3.36200000e+03],
#        [1.19920000e+04, 1.19950000e+04, 1.16941876e+02, 5.99900000e+03]])

# %%
#строим дендограмму
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Дендограмма кластеров')
plt.show()

# %% [markdown]
# #### Вывод:
#
# По дендограмме видно, что кластеров должно быть около 7. Распределим все товары по 7 категориям

# %% [markdown]
# ### Категоризация столбца `product`

# %% [markdown]
# Для дальнейшего анализа, распределим товары из ассортимента по категориям.

# %%
list(df_without_duplicates['new_product'].unique())
# Out:
# ['комнатное',
#  'радермахера',
#  'хризолидокарпус',
#  'циперус',
#  'шеффлера',
#  'юкка',
#  'настенная',
#  'таз',
#  'чехол',
#  'вешалка',
#  'сушилка',
#  'крючок',
#  'корзина',
#  'мини',
#  'сковорода',
#  'стеклянная',
#  'доска',
#  'сумка',
#  'многолетнее',
#  'рассада',
#  'муляж',
#  'щетка',
#  'тарелка',
#  'вилка',
#  'ложка',
#  'нож',
#  'герань',
#  'ерш',
#  'пеларгония',
#  'котел',
#  'суккулент',
#  'эхеверия',
#  'набор',
#  'коврик',
#  'подкладка',
#  'дозатор',
#  'рш',
#  'эвкалипт',
#  'цветок',
#  'мусорный',
#  'плед',
#  'скатерть',
#  'кувшин',
#  'адиантум',
#  'ковер',
#  'перчатки',
#  'стремянка',
#  'гладильная',
#  'лестница',
#  'толкушка',
#  'тележка',
#  'готовая',
#  'искусственный',
#  'простыня',
#  'чайник',
#  'штора',
#  'банка',
#  'стяжка',
#  'комплект',
#  'кампанула',
#  'декоративная',
#  'противень',
#  'калатея',
#  'нолина',
#  'плечики',
#  'подушка',
#  'полотенце',
#  'хлорофитум',
#  'цикламен',
#  'крепеж',
#  'пружина',
#  'глоксиния',
#  'азалия',
#  'гортензия',
#  'хризантема',
#  'петля',
#  'салфетка',
#  'вкладыши',
#  'миксер',
#  'кофр',
#  'стиральный',
#  'чистящий',
#  'tepмокружка',
#  'мирт',
#  'цветущее',
#  'стремянки',
#  'светильник',
#  'кориандр',
#  'жидкое',
#  'ков',
#  'пена',
#  'подрукавник',
#  'иссоп',
#  'сантолина',
#  'аспарагус',
#  'афеляндра',
#  'сверло',
#  'контейнер',
#  'зубная',
#  'антуриум',
#  'молодило',
#  'фиалка',
#  'гербера',
#  'душица',
#  'мелисса',
#  'роза',
#  'карниз',
#  'веник',
#  'швабра',
#  'ящик',
#  'подголовник',
#  'ведро',
#  'короб',
#  'коробка',
#  'наматрасник',
#  'наматрицник',
#  'насадка',
#  'ножеточка',
#  'бегония',
#  'настольная',
#  'розмарин',
#  'сиденье',
#  'масленка',
#  'утюг',
#  'корыто',
#  'холодная',
#  'сервировочная',
#  'салатник',
#  'шнур',
#  'урна',
#  'чайный',
#  'мыло',
#  'рыбочистка',
#  'овощеварка',
#  'сметка',
#  'халат',
#  'измерительный',
#  'линейка',
#  'терка',
#  'кружка',
#  'лопатка',
#  'салфетница',
#  'стакан',
#  'столовая',
#  'чайная',
#  'альбука',
#  'овощечистка',
#  'бальзамин',
#  'крассула',
#  'артемизия',
#  'средство',
#  'бензин',
#  'паста',
#  'лаванда',
#  'мята',
#  'каланхое',
#  'примула',
#  'держатель',
#  'пробка',
#  'измельчитель',
#  'лоток',
#  'вешалки',
#  'губка',
#  'фен',
#  'дендробиум',
#  'калоцефалус',
#  'антижир',
#  'каллуна',
#  'капсикум',
#  'мимоза',
#  'соланум',
#  'универсальное',
#  'мантоварка',
#  'ролик',
#  'сменный',
#  'термометр',
#  'бархатцы',
#  'космея',
#  'морковь',
#  'настурция',
#  'огурец',
#  'петуния',
#  'шило',
#  'ковш',
#  'кухонные',
#  'кисточка',
#  'скребок',
#  'комод',
#  'картофелемялка',
#  'ароматизированное',
#  'бальзам',
#  'алиссум',
#  'гвоздика',
#  'годеция',
#  'календула',
#  'капуста',
#  'кореопсис',
#  'лапчатка',
#  'львиный',
#  'флокс',
#  'цинерария',
#  'эшшольция',
#  'жестяная',
#  'рассекатель',
#  'ополаскиватель',
#  'сетка',
#  'покрывало',
#  'весы',
#  'диффенбахия',
#  'фаленопсис',
#  'подставка',
#  'миска',
#  'одеяло',
#  'подсолнечник',
#  'ручка',
#  'пуансетия',
#  'пресс',
#  'термостакан',
#  'гиностемма',
#  'ель',
#  'кипарисовик',
#  'аптения',
#  'новогоднее',
#  'мыльница',
#  'защитный',
#  'многофункциональный',
#  'пуансеттия',
#  'кольца',
#  'вантуз',
#  'термокружка',
#  'фоторамка',
#  'этажерка',
#  'термос',
#  'скиммия',
#  'кондиционер',
#  'фарфоровая',
#  'электроштопор',
#  'простынь',
#  'столовый',
#  'блюдце',
#  'фиттония',
#  'полки',
#  'тимьян',
#  'бульонница',
#  'алоэ',
#  'ключница',
#  'разделочная',
#  'складная',
#  'спатифиллум',
#  'емкость',
#  'фикус',
#  'защитная',
#  'гипоаллергенный',
#  'модульная',
#  'просеиватель',
#  'кастрюля',
#  'махровое',
#  'искусственная',
#  'кодонанта',
#  'совок',
#  'хлебница',
#  'гимнокалициум',
#  'нетканые',
#  'пылесос',
#  'кофе',
#  'эхинокактус',
#  'фал',
#  'форма',
#  'орехоколка',
#  'штанга',
#  'увлажняющая',
#  'крокусы',
#  'кухонное',
#  'гипсофила',
#  'подарочный',
#  'калибрахоа',
#  'эпипремнум',
#  'махровый',
#  'аквилегия',
#  'базилик',
#  'горох',
#  'земляника',
#  'незабудка',
#  'седум',
#  'томат',
#  'укроп',
#  'нефролепис',
#  'калла',
#  'декабрист',
#  'тюльпан',
#  'штангенциркуль',
#  'гиацинт',
#  'вербена',
#  'однолетнее',
#  'скалка',
#  'рукав',
#  'чабер',
#  'бакопа',
#  'ранункулус',
#  'венчик',
#  'сито',
#  'бак',
#  'газания',
#  'овсянница',
#  'концентрат',
#  'тортница',
#  'георгина',
#  'смолевка',
#  'цинния',
#  'лавр',
#  'вербейник',
#  'виола',
#  'колокольчик',
#  'котовник',
#  'эхинацея',
#  'ясколка',
#  'блюдо',
#  'полка',
#  'окномойка',
#  'лилейник',
#  'папоротник',
#  'платикодон',
#  'энотера',
#  'сменная',
#  'ткань',
#  'фуксия',
#  'цитрофортунелла',
#  'пеперомия',
#  'дыня',
#  'циния',
#  'синнингия',
#  'гардения',
#  'томата',
#  'лобелия',
#  'подвесное',
#  'табак',
#  'наматрацник',
#  'автоматическая',
#  'тряпкодержатель',
#  'девичий',
#  'бельевые',
#  'фиксатор',
#  'мускари',
#  'пиретрум',
#  'агератум',
#  'колеус',
#  'тагетис',
#  'цинерания',
#  'муррайя',
#  'портулак',
#  'астра',
#  'аргирантерум',
#  'левкой',
#  'вероника',
#  'целозия',
#  'арбуз',
#  'баклажан',
#  'клубника',
#  'патиссон',
#  'маттиола',
#  'сальвия',
#  'лук',
#  'джункус',
#  'драцена',
#  'фатсия',
#  'хоста',
#  'наволочка',
#  'гайлардия',
#  'монарда',
#  'нивянник',
#  'рудбекия',
#  'обувница',
#  'барвинок',
#  'пододеяльник',
#  'осина',
#  'отжим',
#  'сциндапсус',
#  'пряные',
#  'бузульник',
#  'камнеломка',
#  'солидаго',
#  'физостегия',
#  'бадан',
#  'лен',
#  'антинакипин',
#  'шпагат',
#  'сотейник',
#  'стеллаж',
#  'бидон',
#  'лантана',
#  'складной',
#  'лаватера',
#  'ванна',
#  'анемона',
#  'буддлея',
#  'валериана',
#  'змееголовник',
#  'любисток',
#  'петрушка',
#  'сельдерей',
#  'шалфей',
#  'корзинка',
#  'ваза',
#  'вигна',
#  'кабачок',
#  'тыква',
#  'хамедорея',
#  'зверобой',
#  'прищепки',
#  'мединилла',
#  'отделитель',
#  'шприц',
#  'крышка',
#  'импатиенс',
#  'покрытие',
#  'клен',
#  'веревка',
#  'мешок',
#  'замиокулькас',
#  'отбеливатель',
#  'сахарница',
#  'завертка',
#  'амариллис',
#  'соковарка',
#  'пьезозажигалка',
#  'соковыжималка',
#  'решетка',
#  'запасная',
#  'щ',
#  'универсальный',
#  'уголок',
#  'салат',
#  'вакуумный',
#  'тряпка',
#  'половник',
#  'двуспальное',
#  'кипятильник',
#  'пахира',
#  'основание',
#  'мерный',
#  'стяжки',
#  'шпингалет',
#  'литопс']

# %% [markdown]
# Разделим весь ассортимент на 7 категорий:
# * кухня
# * сад
# * ванная
# * гардероб
# * дом
# * текстиль
# * бытовая химия

# %% [markdown]
# Составим для кажой категории список, где укажем название товаров, относящихся к этой категории:

# %%
kitchens = ['мини', 'сковорода', 'стеклянная','тарелка', 'вилка', 'ложка', 'нож', 'котел','подкладка',  'набор', 
             'соковарка', 'пьезозажигалка с', 'соковыжималка', 'стакан', 'сахарница', 'противень', 'банка',  
               'хлебница', 'миска',  'шприц', 'отделитель', 'ваза', 'кастрюля',  'сотейник',  'бидон',
            'скребок', 'сотейник', 'блюдо',  'тортница',  'венчик', 'сито', 'скалка', 'форма', 'орехоколка', 'нетканые',
            'просеиватель', 'модульная', 'емкость', 'разделочная','бульонница', 'блюдце','столовый', 'фарфоровая',
            'термокружка', 'термос', 'защитный', 'пресс',  'термостакан', 'рассекатель', 'жестяная', 'мерный',
            'салатник', 'рш', 'кипятильник',  'половник',  'кружка',  'универсальный',  'терка', 'тка',
            'картофелемялка', 'кисточка',  'ковш', 'кухонные', 'измельчитель', 'мантоварка', 'губка', 'лоток', 'чайная',
            'овощечистка', 'столовая', 'рыбочистка', 'лопатка', 'салфетница', 'чайный', 'сервировочная', 'чайник', 
            'масленка', 'ножеточка', 'салфетка', 'вкладыши','кувшин', 'толкушка','щетка', 'tepмокружка', 
           'контейнер', 'ящик', 'мусорный',  'крышка', 'электроштопор',   'овощеварка', 'миксер']

gardens = ['комнатное', 'радермахера', 'хризолидокарпус', 'циперус', 'шеффлера','юкка', 'многолетнее', 
          'герань', 'пеларгония', 'суккулент', 'эхеверия', 'эвкалипт', 'литопс', 'лавр', 'рассада','фуксия',
          'пахира','хризантема',  'эхеверия', 'петрушка', 'салат',  'диффенбахия', 'роза', 'розмарин', 
          'амариллис', 'замиокулькас', 'спатифиллум', 'фиалка', 'импатиенс', 'клен', 'хамедорея',  'зверобой',
          'цикламен', 'вигна',  'кабачок', 'огурец', 'тыква', 'мединилла',  'анемона',  'буддлея', 
          'валериана', 'змееголовник', 'капуста', 'любисток', 'монарда',  'сельдерей', 'пряные', 'аквилегия', 
          'алиссум', 'астра', 'бузульник', 'камнеломка', 'солидаго', 'физостегия', 'патиссон', 'бадан', 'камнеломка', 
          'колокольчик', 'лен', 'табак', 'шалфей', 'лантана','папоротник', 'платикодон', 'энотера' 
           'искусственный',  'лаватера',  'фатсия',  'лапчатка', 'седум', 'барвинок', 'осина', 'молодило', 
          'сциндапсус', 'пеларгония', 'гайлардия', 'монарда', 'нивянник',  'клубника', 'рудбекия','маттиола',  
          'кориандр стимул', 'сальвия', 'лук', 'джункус', 'драцена', 'арбуз', 'фатсия', 'хоста', 
          'томат', 'аргирантерум', 'левкой', 'петуния', 'вероника', 'целозия',  'примула', 'баклажан', 'дыня', 
          'кореопсис', 'портулак', 'эвкалипт', 'мускари', 'пиретрум', 'флокс', 'агератум',
          'колеус', 'тагетис','цинерания', 'лобелия рассада', 'муррайя', 'вербена',  'пеларгония', 'цитрофортунелла', 
           'пеперомия', 'гортензия', 'синнингия', 'гардения', 'томата', 
          'бальзамин', 'земляника', 'календула', 'цинния', 'базилик', 'настурция', 'гвоздика', 'девичий',
          'бегония', 'лаванда', 'виола', 'лилейник', 'папоротник', 'подвесное', 'циния', 'ясколка', 'георгина',
           'смолевка', 'вербейник', 'котовник', 'эхинацея','овсянница', 'газания',  'чабер', 'бакопа', 'ранункулус',
           'однолетнее', 'калибрахоа', 'эпипремнум', 'горох', 'незабудка', 'укроп', 'нефролепис', 'калла', 'декабрист',
          'тюльпан', 'штангенциркуль', 'гиацинт', 'подарочный',  'крокусы', 'гипсофила', 'новогоднее',
           'гиностемма', 'ель', 'кипарисовик', 'аптения', 'пуансеттия', 'скиммия', 'фиттония','тимьян', 'алоэ', 
           'фикус', 'искусственная', 'кодонанта', 'гимнокалициум', 'кофе', 'эхинокактус',  'подсолнечник', 'фаленопсис',
           'пуансетия', 'годеция','львиный','цинерария','эшшольция','бархатцы', 'космея', 'морковь',
           'дендробиум', 'калоцефалус', 'каллуна', 'капсикум', 'мимоза', 'соланум', 'альбука',  'крассула', 
           'артемизия', 'мята', 'каланхое', 'антуриум', 'гербера', 'душица', 'мелисса',
           'иссоп',  'сантолина',  'аспарагус',  'афеляндра', 'цветущее', 'мирт','пружина',  'глоксиния',  'азалия',
           'хлорофитум', 'калатея',  'нолина', 'цветок', 'адиантум', 'перчатки',  'кампанула', 'декоративная', 'муляж', 
          'искусственный', 'кориандр', 'лобелия', 'энотера','фен', 'весы',  'пылесос' ]

bathroom = ['настенная',  'таз','сушилка', 'ерш', 'коврик', 'корзина','дозатор', 'рш', 'ведро', 'швабра',
            'корзина',  'тряпка',  'совок',   'прищепки', 'вантуз', 'ванна', 'отжим', 'щ', 'тряпкодержатель', 
            'автоматическая', 'сменная', 'окномойка', 'бак', 'махровый', 'штанга', 'мыльница', 'сетка', 
            'пробка', 'держатель', 'сметка',  'корыто', 'сиденье', 'насадка', 'подголовник', 'бельевые']

wardrobe = ['чехол',  'вешалка', 'крючок', 'доска',  'сумка','щетка', 'набор', 'коврик',  'вакуумный', 'стеллаж',
            'обувница', 'полка', 'рукав', 'складная', 'ключница', 'этажерка',  'комод', 'сменный', 'ролик',
            'настольная', 'вешалки',  'веник','подрукавник',  'плечики','гладильная', 'кофр','короб', 
            'коробка',  'подставка', 'мешок', 'утюг', ]

house = ['основание', 'стяжки', 'шпингалет',  'уголок',  'решетка', 'запасная',
        'завертка',  'ручка',  'веревка',  'покрытие', 'сушилка', 'измерительный', 'шнур' , 'корзинка', 'фал', 'полки',
         'термометр', 'коврик',  'складной', 'фоторамка', 'кольца', 'ручка', 'карниз', 'светильник', 'урна',
         'набор инструментов',  'шпагат', 'многофункциональный', 'шило', 'линейка', 'холодная',  'сверло','стремянки',
         'петля','крепеж','стремянка', 'лестница', 'тележка',  'стяжка', 'бензин', 'пьезозажигалка', 'фиксатор']

textile = ['двуспальное', 'простыня', 'подушка', 'скатерть', 'покрывало', 'ткань', 'полотенце',
           'пододеяльник',  'наволочка', 'наматрацник', 'кухонное', 'махровое', 'простынь','одеяло', 'халат',
          'наматрасник','наматрицник', 'ковер',  'ков','плед', 'штора', 'готовая','комплект']    
           

household_chemicals = ['отбеливатель', 'паста',  'антинакипин', 'концентрат', 'увлажняющая', 'гипоаллергенный',
                       'защитная', 'кондиционер','ополаскиватель', 'бальзам', 'ароматизированное', 
                       'универсальное', 'антижир', 'паста', 'средство',  'мыло', 'зубная', 'жидкое','стиральный', 
                       'чистящий', 'пена']

# %% [markdown]
# Напишем функцию для категорзации товаров:

# %%
#напишем функцию для категоризации
def category(row):
    if row in kitchens:
        return 'кухня'
    if row in gardens:
        return 'сад'
    if  row in bathroom:
        return 'ванная комната'
    if  row in wardrobe:
        return 'гардероб'
    if  row in house:
        return 'для дома'
    if  row in textile:
        return 'текстиль'
    if  row in household_chemicals:
        return 'бытовая химия'
    else:
        return 'неизвестно'

# %% [markdown]
# Проверим работу функции:

# %%
display(category('сковорода'))
display(category('тыква'))
display(category('тряпка'))
display(category('вешалка'))
display(category('стяжки'))
display(category('простыня'))
display(category('шпагат'))
display(category('паста'))
display(category('пылесос'))
display(category('мусорный'))
# Out:
# 'кухня'
# 'сад'
# 'ванная комната'
# 'гардероб'
# 'для дома'
# 'текстиль'
# 'для дома'
# 'бытовая химия'
# 'сад'
# 'кухня'

# %% [markdown]
# Функция работает исправно. Применим функцию к предобработанному столбцу с названиями товаров:

# %%
df_without_duplicates['category'] = df_without_duplicates['new_product'].apply(category)
df_without_duplicates.head()
# Out:
#                             customer_id  order_id  \
# 0  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price  \
# 0    комнатное растение в горшке алое вера, d12, h30         1  142.0
# 1  комнатное растение в горшке кофе арабика, d12,...         1  194.0
# 2                        радермахера d-12 см h-20 см         1  112.0
# 3                   хризолидокарпус лутесценс d-9 см         1  179.0
# 4                     циперус зумула d-12 см h-25 см         1  112.0
#
#   month_year  hours      new_product category
# 0 2018-10-01      0        комнатное      сад
# 1 2018-10-01      0        комнатное      сад
# 2 2018-10-01      0      радермахера      сад
# 3 2018-10-01      0  хризолидокарпус      сад
# 4 2018-10-01      0          циперус      сад

# %% [markdown]
# Проверим наличие товаров с категорией "неизвестно"

# %%
df_without_duplicates[df_without_duplicates['new_product']=='неизвестно']
# Out:
# Empty DataFrame
# Columns: [customer_id, order_id, product, quantity, price, month_year, hours, new_product, category]
# Index: []

# %% [markdown]
# ####  Вывод:
#
# 1. Проведена категоризация товаров
# 2. Всем товарам присвоена категория, товаров категории "неизвестно" нет.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Опеределение периода анализа данных

# %% [markdown]
# Тип данных в столбце изменен. Теперь, мы можем выяснить данными за какой период мы владеем. Найдем минимальную и максимальную даты:

# %%
display(f"Минимальная дата:{df_without_duplicates['month_year'].min()}")
f"Максимальная дата:{df_without_duplicates['month_year'].max()}"
# Out:
# 'Минимальная дата:2018-10-01 00:00:00'
# 'Максимальная дата:2019-10-01 00:00:00'

# %% [markdown]
# #### Вывод:
#
# Таким образом, мы узнали, что владеем данными за период с 2018-10-01 по 2019-10-31.

# %% [markdown]
# ### Работа с аномалиями

# %% [markdown]
# Ранее мы знакомились с описанием данных через метод describe, вспомним:

# %%
df_without_duplicates.describe() #описание данных
# Out:
#            order_id     quantity         price        hours
# count   5999.000000  5999.000000   5999.000000  5999.000000
# mean   45985.836139     2.673279    494.797466    13.947491
# std    27710.847435    16.165654    909.528559     4.900280
# min    12624.000000     1.000000      9.000000     0.000000
# 25%    14784.000000     1.000000     90.000000    10.000000
# 50%    68735.000000     1.000000    149.000000    14.000000
# 75%    70726.000000     1.000000    464.000000    18.000000
# max    73164.000000  1000.000000  14917.000000    23.000000

# %% [markdown]
# Из таблицы видно, что:
# * минимальное количество товаров-1, максимальное количество товаров-1000
# * минимальная стоимость заказа-9 денежных едениц, максимальная стоимость заказа-14917 денежных едениц; средняя сумма заказов-494, а медиана-149.
# * минимальное время-0 часов, максимальное время-23 часа
#
# Построим графики распределения по столбцам `quantity`и  `price`, а так же построим диаграмму размаха, что бы выявить аномалии

# %%
plt.figure(figsize=(12,10))

ax1 = sns.boxplot(y='price', data=df_without_duplicates )
ax1.set(title='Распределение стоимости заказа')

ax1.set_ylim(-5,20000)
ax1.set_xlabel('')
ax1.set_ylabel('');

# %% [markdown]
# Построим еще одну диаграмму размаза, что бы более четко определить медиану.

# %%
plt.figure(figsize=(12,10))

ax1 = sns.boxplot(y='price', data=df_without_duplicates )
ax1.set(title='Распределение стоимости заказа')

ax1.set_ylim(-5,2000)
ax1.set_xlabel('')
ax1.set_ylabel('');

# %% [markdown]
# По графику видно, что в основном, все заказы были менее 10.000 денежных единиц, кроме одного. Так же по графику видно, что заказы стоимость больше 1000 денежных едениц-выбросы.
#
# Построим диаграмму размаха по количеству товаров:

# %%
plt.figure(figsize=(12,10))

ax1 = sns.boxplot(y='quantity', data=df_without_duplicates )
ax1.set(title='Распределение количества товаров в заказе')

ax1.set_ylim(-5,1500)
ax1.set_xlabel('')
ax1.set_ylabel('');

# %% [markdown]
# Построим еще одну диаграмму размаха, в другом масштабе, для визуализации медианы:

# %%
plt.figure(figsize=(12,10))

ax1 = sns.boxplot(y='quantity', data=df_without_duplicates )
ax1.set(title='Распределение количества товаров в заказе')

ax1.set_ylim(-5,5)
ax1.set_xlabel('')
ax1.set_ylabel('');

# %% [markdown]
# По графику видно, что в основном количество товаров в заказе было менее 400, кроме одного заказа с количеством заказов около 1000.
#
# Такие выбросы искажают среднее. Ознакомимся с заказами, где количество товаров 1000, и с заказами, где стоимость заказа 14917 денежных единиц

# %%
df_without_duplicates[df_without_duplicates['price'] == 14917]
# Out:
#                                customer_id  order_id  \
# 5264  0d87f4ae-465a-4fac-81e6-5d629761783e     72139
#
#                                                 product  quantity    price  \
# 5264  сушилка уличная leifheit 85210 linomatic v 400...         1  14917.0
#
#      month_year  hours new_product        category
# 5264 2019-07-01     17     сушилка  ванная комната

# %%
df_without_duplicates[df_without_duplicates['quantity'] == 1000.0]
# Out:
#                                customer_id  order_id  \
# 4785  312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6     71743
#
#                                                 product  quantity  price  \
# 4785  вантуз с деревянной ручкой d14 см красный, bur...      1000  675.0
#
#      month_year  hours new_product        category
# 4785 2019-06-01     15      вантуз  ванная комната

# %% [markdown]
# Товар, со стомостью 14917 денежных единиц-сушилка уличная, в количестве 1 штука, а товар, купленный в количестве 1000 экземпляров-вантуз.
#
# Ознакомимся с товарами "сушилка".

# %%
df_without_duplicates[df_without_duplicates['new_product'] == 'сушилка'].head(15)
# Out:
#                               customer_id  order_id  \
# 11   86432d8d-b706-463b-bd5d-6a9e170daee3     68484
# 18   17213b88-1514-47a4-b8aa-ce51378ab34e     68476
# 56   5f75c73a-1305-4079-b040-2bcb42085002     68509
# 65   c971fb21-d54c-4134-938f-16b62ee86d3b     68514
# 70   4d93d3f6-8b24-403b-a74b-f5173e40d7db     68516
# 108  b463177a-cc14-44f6-a225-0e03170f5d41     68536
# 132  c971fb21-d54c-4134-938f-16b62ee86d3b     68563
# 133  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68564
# 151  cfa03448-10b8-4538-94c9-82d53e869582     68577
# 157  3bc760df-7192-4ebc-9403-21ad69060f00     68578
# 162  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68583
# 166  3d64da20-86d3-493c-bb8f-2c7c5471c167     68589
# 178  39334cc6-4608-4e62-9211-4413d56398be     68602
# 191  f0c70c63-e6bc-4a9e-84fb-ba6827b580ea     68609
# 218  2cb89eef-49db-4241-8063-c8aff48a1ed4     68618
#
#                                                product  quantity   price  \
# 11   сушилка для белья потолочная zalger lift basic...         1   614.0
# 18   сушилка для белья напольная colombo star 18, 3679         1  1049.0
# 56   сушилка для белья настенная zalger prima 510-7...         1   299.0
# 65   сушилка для белья attribute прима 11 м синяя н...         1   749.0
# 70   сушилка для белья потолочно-настенная gimi lif...         1  1649.0
# 108         сушилка для белья на батарею, сб5-45, ника         1   134.0
# 132  сушилка для белья потолочная zalger lift basic...         1   614.0
# 133  сушилка для белья напольная gimi modular 3 lux...         1  1724.0
# 151  сушилка для белья потолочно-настенная gimi lif...         1  1949.0
# 157   сушилка для белья потолочная лиана 2,2 м 1703010         2   697.0
# 162  сушилка для белья потолочная лиана люкс 140, л...         1   449.0
# 166  сушилка для белья виолет ricko 5м rk-5/100 нас...         2   637.0
# 178                    сушилка для белья gimi alablock         1  1012.0
# 191  сушилка для белья потолочно-настенная gimi lif...         1  1574.0
# 218   сушилка для белья потолочная лиана 1,6 м 1703005         1   539.0
#
#     month_year  hours new_product        category
# 11  2018-10-01     12     сушилка  ванная комната
# 18  2018-10-01     18     сушилка  ванная комната
# 56  2018-10-01     18     сушилка  ванная комната
# 65  2018-10-01     10     сушилка  ванная комната
# 70  2018-10-01     11     сушилка  ванная комната
# 108 2018-10-01     12     сушилка  ванная комната
# 132 2018-10-01      9     сушилка  ванная комната
# 133 2018-10-01     10     сушилка  ванная комната
# 151 2018-10-01     20     сушилка  ванная комната
# 157 2018-10-01      7     сушилка  ванная комната
# 162 2018-10-01     10     сушилка  ванная комната
# 166 2018-10-01     15     сушилка  ванная комната
# 178 2018-10-01     19     сушилка  ванная комната
# 191 2018-10-01     11     сушилка  ванная комната
# 218 2018-10-01     10     сушилка  ванная комната

# %% [markdown]
# Посмотрим максимальную стоимость товара "сушилка":

# %%
max_price = df_without_duplicates[df_without_duplicates['new_product'] == 'сушилка']['price'].max()
f'Максимальная стоимость сушилки: {max_price}'
# Out:
# 'Максимальная стоимость сушилки: 14917.0'

# %% [markdown]
# Посмотрим максимальное количество товара "сушилка" в одном заказе:

# %%
max_count = df_without_duplicates[df_without_duplicates['new_product'] == 'сушилка']['quantity'].max()
f'Максимальная стоимость сушилки: {max_count}'
# Out:
# 'Максимальная стоимость сушилки: 10'

# %% [markdown]
# Посмотрим на товары "сушилка" с количеством товара 10:

# %%
df_without_duplicates.query('new_product == "сушилка" and quantity ==10')
# Out:
#                                customer_id  order_id  \
# 5804  363f8d24-6d16-428f-8c89-a0fab51a5436     72892
# 5836  363f8d24-6d16-428f-8c89-a0fab51a5436     72892
#
#                                                product  quantity  price  \
# 5804  сушилка для белья напольная ника сб3б 10 м белая        10  542.0
# 5836  сушилка для белья напольная ника сб3б 10 м белая        10  542.0
#
#      month_year  hours new_product        category
# 5804 2019-10-01      9     сушилка  ванная комната
# 5836 2019-10-01     16     сушилка  ванная комната

# %% [markdown]
# Стоимость этих товаров "сушилка для" с количеством -10 едениц товара - не превышает 600 денежных едениц.
#
#
# Посмотрим на товар "сушилка для" и стоимость товара 7004 денежные единицы.

# %%
df_without_duplicates.query('new_product == "сушилка" and price ==7004')
# Out:
#                                customer_id  order_id  \
# 4680  85716494-dd51-4d1d-ab28-8c74b87f14dc     71674
#
#                                                 product  quantity   price  \
# 4680  сушилка для белья leifheit pegasus 200 deluxe ...         1  7004.0
#
#      month_year  hours new_product        category
# 4680 2019-06-01     10     сушилка  ванная комната

# %% [markdown]
# Ценовой сегмент среди схожих товаров не превышает 7100 днежных едениц.
#
#
# Вероятнее всего, в данные при выгрузке возникла ошибка, поэтому удалим данные о товаре "сушилка" со стоимостью 14917 денежных единиц.
#
#
# Так же, ранее мы выявили оптовый закуп товаров "вантуз" в количестве 1000 единицы. Учитывая, что анализ товара проводится в рамках розничного ассортимента, исключим данную покупку из таблицы и посмотрим на данные, если исключить данные аномальные заказы из таблицы:

# %%
data = df_without_duplicates.query('price !=14917 and quantity!=1000.0')
data.describe()
# Out:
#            order_id     quantity        price        hours
# count   5997.000000  5997.000000  5997.000000  5997.000000
# mean   45977.180090     2.507254   492.362515    13.946807
# std    27711.412908     9.772418   890.402720     4.900920
# min    12624.000000     1.000000     9.000000     0.000000
# 25%    14784.000000     1.000000    90.000000    10.000000
# 50%    68735.000000     1.000000   149.000000    14.000000
# 75%    70725.000000     1.000000   464.000000    18.000000
# max    73164.000000   334.000000  8737.000000    23.000000

# %% [markdown]
# #### Выводы:
#
# 1. В ходе исследования, было выявлено аномальное значение в столбце `price`  и в столбце `quantity`:
# * товар со стомостью 14917 денежных единиц-сушилка уличная, в количестве 1 штука
# * товар, купленный в количестве 1000 экземпляров-вантуз
# 2. Далее, после рассмотрения аналогичных товаров,было решено, что вероятнее всего, в данных ошибка, поэтому решено было удалить данные о товаре "сушилка" со стоимостью 14917 денежных единиц.
# 3. Так же, в ходе анализа данных выявили оптовый закуп товаров "вантуз" в количестве 1000 единицы. Учитывая, что анализ товара проводится в рамках розничного ассортимента, мы исключили данную покупку из таблицы
# 4. Из таблицы после исключения аномалий видно, что:
# * минимальное количество товаров-1, максимальное количество товаров-334 единиц(вместо 1000)
# * минимальная стоимость заказа-9 денежных едениц, максимальная стоимость заказа-8737(вместо 14917 денежных едениц); средняя сумма заказов-492(вместо 494) , а медиана-149.

# %% [markdown]
# ### Изучение асортимента

# %% [markdown]
# Изучим:
#
# * распределение заказов по категориям и месяцам (в каких месяцах-какие категории наиболее популярны)
# * категории, приносящие наибольшую выручку в каждом сезоне(что бы заранее "запастись" данными товарами перед пиком)
# * в каком сезоне средний чек наибольший
# * в каком сезоне средний чек наименьший(можно запустить акцию, для увеличения среднего чека)

# %% [markdown]
# #### Распределение заказов по категориям и месяцам

# %% [markdown]
# Создадим таблицу, с количеством заказов в каждом месяце по каждой категории. Для этого сначала изменим тип данных в столбце `data` на строковой тип данных

# %%
data['month_year'] = data['month_year'].astype('str') #изменяем тип данных
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5997 entries, 0 to 5998
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  5997 non-null   object
#  1   order_id     5997 non-null   int64
#  2   product      5997 non-null   object
#  3   quantity     5997 non-null   int64
#  4   price        5997 non-null   float64
#  5   month_year   5997 non-null   object
#  6   hours        5997 non-null   int64
#  7   new_product  5997 non-null   object
#  8   category     5997 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 468.5+ KB

# %% [markdown]
# Тип данных в столбце изменен. Создадим таблицу:

# %%
category_month = data.pivot_table(index='category',
                                  columns='month_year',
                                 values='order_id',
                                 aggfunc='count')
category_month = category_month.T #транспонируем таблицу
category_month = category_month.fillna(0) #заменим пропуски на 0
category_month
# Out:
# category    бытовая химия  ванная комната  гардероб  для дома  кухня    сад  \
# month_year
# 2018-10-01            7.0           117.0      85.0      26.0   80.0  224.0
# 2018-11-01            7.0            56.0      70.0      27.0   82.0  212.0
# 2018-12-01            7.0            57.0      89.0      35.0   67.0   89.0
# 2019-01-01            3.0            35.0      44.0      15.0   36.0   73.0
# 2019-02-01            4.0            68.0      63.0      17.0   45.0  214.0
# 2019-03-01            4.0            40.0      51.0      15.0   43.0  330.0
# 2019-04-01            1.0            43.0      56.0      25.0   22.0  595.0
# 2019-05-01            1.0            22.0      43.0      22.0   21.0  739.0
# 2019-06-01            2.0            44.0      44.0      16.0   10.0  599.0
# 2019-07-01            0.0            58.0      40.0      15.0   26.0  242.0
# 2019-08-01            3.0            32.0      47.0      28.0   21.0   79.0
# 2019-09-01            0.0            43.0      41.0      26.0   26.0  101.0
# 2019-10-01            0.0            47.0      44.0      29.0   18.0  106.0
#
# category    текстиль
# month_year
# 2018-10-01      28.0
# 2018-11-01      20.0
# 2018-12-01      22.0
# 2019-01-01      15.0
# 2019-02-01      14.0
# 2019-03-01      13.0
# 2019-04-01      17.0
# 2019-05-01       3.0
# 2019-06-01      10.0
# 2019-07-01      10.0
# 2019-08-01       9.0
# 2019-09-01      11.0
# 2019-10-01      11.0

# %% [markdown]
# Построим графики, что бы оценить количество заказов в каждом месяце по каждой категории

# %%
#напишем цикл для отрисовки графиков по количеству заказов в категории в каждом месяце 
fig, ax = plt.subplots(figsize = (15,45))

for i,col in enumerate(category_month.columns):
    ax=fig.add_subplot(7,1, i+1)
    
    sns.barplot(data=category_month,
    x = category_month.index,
    y = category_month[col].values)
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.set_title('Ежемесячное количество заказов в категории ' + col)
    plt.tight_layout();

# %% [markdown]
# ##### Выводы:
#
# По графику видно, что наибольшее количество заказов в категории:
# * бытовая химия - в октябре,ноябре и декабре 2018 года
# * ванная комната - в октябре 2018 года
# * гардероб - в октябре,ноябре и декабре 2018 года
# * для дома - в декабре 2018 года, августе, октябре 2018 и 2019 года
# * кухня - в октябре,ноябре и декабре 2018 года
# * сад - в апреле, мае и июне 2019 года
# * текстиль - в октябре,ноябре и декабре 2018 года

# %% [markdown]
# #### Прибыль по категориям

# %% [markdown]
# Посмотрим, какая категория приносит наибольшую прибыль в целом:

# %%
total_month = data.pivot_table(index='category',
                                  columns='month_year',
                                 values='price',
                                 aggfunc='sum')
total_month = total_month.T #транспонируем таблицу
total_month = total_month.fillna(0) #заменим пропуски на 0
total_month
# Out:
# category    бытовая химия  ванная комната  гардероб  для дома    кухня  \
# month_year
# 2018-10-01         1089.0         81819.0  108745.0   26049.0  30580.0
# 2018-11-01          671.0         44055.0  109374.0   20448.0  18423.0
# 2018-12-01         1432.0         46622.0  143388.0   21829.0  24178.0
# 2019-01-01          987.0         28180.0   61204.0   25194.0  14649.0
# 2019-02-01          822.0         61521.0  101291.0   22323.0  23875.0
# 2019-03-01          501.0         54176.0   98621.0   17037.0  21928.0
# 2019-04-01          269.0         35964.0   90229.0   36862.0   9619.0
# 2019-05-01          142.0         15509.0   79810.0   22519.0   6962.0
# 2019-06-01          328.0         34901.0   64001.0   27399.0   3300.0
# 2019-07-01            0.0         46801.0   73038.0   15797.0  11781.0
# 2019-08-01         1835.0         26848.0   75060.0   32773.0  12900.0
# 2019-09-01            0.0         45098.0   47183.0   26208.0  19170.0
# 2019-10-01            0.0         40796.0   63724.0   48029.0   7226.0
#
# category        сад  текстиль
# month_year
# 2018-10-01  38698.0   35593.0
# 2018-11-01  29181.0   16846.0
# 2018-12-01  31899.0   34493.0
# 2019-01-01  12246.0   29591.0
# 2019-02-01  33536.0    7478.0
# 2019-03-01  44562.0   16052.0
# 2019-04-01  79324.0   17856.0
# 2019-05-01  83812.0    1782.0
# 2019-06-01  77488.0    6942.0
# 2019-07-01  30855.0   13321.0
# 2019-08-01  14379.0    5195.0
# 2019-09-01  19053.0    8738.0
# 2019-10-01  17735.0   12951.0

# %%
#напишем цикл для отрисовки графиков по количеству заказов в категории в каждом месяце 
fig, ax = plt.subplots(figsize = (15,45))

for i,col in enumerate(total_month.columns):
    ax=fig.add_subplot(7,1, i+1)
    
    sns.barplot(data=total_month,
    x = total_month.index,
    y = total_month[col].values)
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.set_title('Ежемесячная прибыль в категории ' + col)
    plt.tight_layout();

# %% [markdown]
# ##### Выводы:
#
# По графику видно, что наибольшая прибыль в категории:
# * бытовая химия - в декабре 2018 года и августе 2019 года
# * ванная комната - в октябре 2018 года, феврале и марте 2019 года
# * гардероб - в октябре,ноябре,декабре 2018 года, феврале 2019 года
# * для дома - в октябре 2019 года и апереле 2018 года
# * инстурменты - в октябре, декабре 2018 года, январе,июне и октябре 2019 года
# * кухня - в октябре, декабре 2018 года, феврале 2019 года
# * сад - в апреле, мае и июне 2019 года
# * текстиль - в октябре, декабре 2018 года и январе 2019 года

# %% [markdown]
# #### Наиболее прибыльные категории

# %% [markdown]
# Составим таблицу, где подсчитаем прибыль в каждой категории, что бы выяснить -какая категория наиболее прибыльная

# %%
category_best = data.pivot_table(index='category',
                                 values='price',
                                 aggfunc='sum').reset_index().sort_values(by='price', ascending=False)
category_best
# Out:
#          category      price
# 2        гардероб  1115668.0
# 1  ванная комната   562290.0
# 5             сад   512768.0
# 3        для дома   342467.0
# 6        текстиль   206838.0
# 4           кухня   204591.0
# 0   бытовая химия     8076.0

# %%
plt.figure(figsize=(10,8))

ax1 = sns.barplot(data=category_best,
                  x=category_best['category'], 
                  y=category_best['price'], palette='pastel') #изменяем палитру
ax1.set_xlabel('')
ax1.set_ylabel('')
ax1.figure.autofmt_xdate(rotation=45) #настроили поворот надписей по оси х

ax1.set_title('Прибыль по категориям');

# %% [markdown]
# ##### Выводы:
#
# По графику видно, что:
# * наиболее прибыльная категория товаров-категория гардероб
# * наименее прибыльная категория товаров-категория бытовая химия

# %% [markdown]
# ### Количество уникальных пользователей

# %% [markdown]
# Для каждого магазина важный показатель-возвращаемость покупателей. Выясним долю повторных покупок.

# %% [markdown]
# Сначала, выясним, сколько всего уникальных пользователей в представленных данных:

# %%
f"Всего уникальных пользователей: {len(data['customer_id'].unique())}"
# Out:
# 'Всего уникальных пользователей: 2449'

# %% [markdown]
# ####  Вывод:
#
# В данных представленные данные о 2449 уникальных пользователях.

# %% [markdown]
# ### Общее количество заказов каждого пользователя и среднее количество заказов на одного пользователя

# %% [markdown]
# Составим таблицу, с общим количеством заказов каждого пользователя:

# %%
group_df = data.pivot_table(index='customer_id', values='order_id', aggfunc='count').reset_index()
group_df.head()
# Out:
#                             customer_id  order_id
# 0  000d6849-084e-4d9f-ac03-37174eaf60c4         4
# 1  001cee7f-0b29-4716-b202-0042213ab038         1
# 2  00299f34-5385-4d13-9aea-c80b81658e1b         1
# 3  002d4d3a-4a59-406b-86ec-c3314357e498         1
# 4  003bbd39-0000-41ff-b7f9-2ddaec152037         1

# %% [markdown]
# Выясним, количество и долю повторных покупок среди пользователей

# %%
repeat_purchase_count = len(group_df[group_df['order_id'] > 1])
repeat_purchase_share = (repeat_purchase_count*100) / len(group_df)

display(f'Количество повторных покупок: {repeat_purchase_count}')
f'Доля повторных покупок: {repeat_purchase_share} %'
# Out:
# 'Количество повторных покупок: 664'
# 'Доля повторных покупок: 27.113107390771745 %'

# %% [markdown]
# Выясним, сколько в среднем заказов приходится на пользователя:

# %%
f"Среднее количество заказов на пользователя: {group_df['order_id'].mean()}"
# Out:
# 'Среднее количество заказов на пользователя: 2.448754593711719'

# %% [markdown]
# #### Выводы:
#
# 1. Количество повторных покупок-664
# 2. Доля повторных покупок: 27.1 %. Что бы увеличить данный показатель, можно "стимулировать" покупателей на повторные покупки: купонами на скидку на следующую покупку, программой лояльности с накопительной скидочной системой.
# 3. Среднее количество заказов на пользователя: 2.4. Для увеличения данного показателя так же можно проводить маркетинговые компании (возьми второй продукт, но со скидкой)

# %% [markdown]
# ### Анализ заказов

# %% [markdown]
# #### Количество заказов по месяцам

# %% [markdown]
# Расчитаем количество покупок за каждый месяц:

# %%
month_orders = data.query("month_year != '2018-10-01'").pivot_table(
    index='month_year', 
    values='order_id', 
    aggfunc='count').reset_index()
month_orders.head()
# Out:
#    month_year  order_id
# 0  2018-11-01       474
# 1  2018-12-01       366
# 2  2019-01-01       221
# 3  2019-02-01       425
# 4  2019-03-01       496

# %% [markdown]
# Построим график для визуализации количества покупок за каждый месяц:

# %%
plt.figure(figsize=(10,8))

ax1 = sns.barplot(data=month_orders,
                  x=month_orders['month_year'].astype('datetime64[M]').dt.date, 
                  y=month_orders['order_id'])
ax1.set_xlabel('')
ax1.set_ylabel('')
ax1.figure.autofmt_xdate(rotation=45) 

ax1.set_title('Ежемесячное количество покупок');

# %% [markdown]
# ##### Выводы:
#
# По графику видно, что:
# * наибольшее количество покупок приходится на период с апреля по июнь 2019 года
#
#
# Вероятнее всего, такой спрос в весенне-летний период связан с дачным сезоном, ведь в интернет магазине большой выбор товаров для садоводства, а так же инструментов.
#
#
# * наименьшее количество покупок приходится на январь и август 2019 года
#
# это так же носит сезонный характер, после нового года наступают новогодние каникулы, в которые многие отдыхают, а не занимаются шопингом. Так же как и в августе, большинство пользователей закупаются канцелярией, а так же одеждой и обувью перед началом учебного года.
#
# Возможно, следует провести маркетинговую компанию в эти месяца, для привлечения пользователей и количества покупок и выручки, а так же усилить работу доставки

# %% [markdown]
# #### Прибыль по месяцам

# %% [markdown]
# Построим таблицу, с суммарной прибылью по месяцам

# %%
month_sum = data.pivot_table(index='month_year',
                                 values='price',
                                 aggfunc='sum').reset_index()
month_sum
# Out:
#     month_year     price
# 0   2018-10-01  322573.0
# 1   2018-11-01  238998.0
# 2   2018-12-01  303841.0
# 3   2019-01-01  172051.0
# 4   2019-02-01  250846.0
# 5   2019-03-01  252877.0
# 6   2019-04-01  270123.0
# 7   2019-05-01  210536.0
# 8   2019-06-01  214359.0
# 9   2019-07-01  191593.0
# 10  2019-08-01  168990.0
# 11  2019-09-01  165450.0
# 12  2019-10-01  190461.0

# %%
plt.figure(figsize=(10,8))

ax1 = sns.barplot(data=month_sum,
                  x=month_sum['month_year'].astype('datetime64[M]').dt.date, 
                  y=month_sum['price'])
ax1.set_xlabel('')
ax1.set_ylabel('')
ax1.figure.autofmt_xdate(rotation=45) 

ax1.set_title('Ежемесячная выручка');

# %% [markdown]
# ##### Выводы:
#
# По графику видно, что прибыль:
# * наибольшая в октябре 2018 года, а так же декабре 2018 и апреле 2019 года
# * наименьшая прибыль в сентябре, а так же январе и августе
#
# Возможно, следует проводить  маркетинговую компанию(акции) в месяца с наименьшей прибылью, для привлечения пользователей и  увеличения выручки.

# %% [markdown]
# #### Средний чек по месяцам

# %% [markdown]
# Посмотрим на средний чек по сезонам (средний чек-это отноешние суммы покупок к количеству заказов).
#
# Для этого сформируем таблицу с суммой заказов по месяцам.

# %%
mean_price = data.pivot_table(index='month_year',
                             values='price',
                             aggfunc='sum').reset_index()
mean_price
# Out:
#     month_year     price
# 0   2018-10-01  322573.0
# 1   2018-11-01  238998.0
# 2   2018-12-01  303841.0
# 3   2019-01-01  172051.0
# 4   2019-02-01  250846.0
# 5   2019-03-01  252877.0
# 6   2019-04-01  270123.0
# 7   2019-05-01  210536.0
# 8   2019-06-01  214359.0
# 9   2019-07-01  191593.0
# 10  2019-08-01  168990.0
# 11  2019-09-01  165450.0
# 12  2019-10-01  190461.0

# %% [markdown]
# Далее создадим таблицу, с количеством покупок по месяцам

# %%
count_price = data.pivot_table(index='month_year',
                             values='order_id',
                             aggfunc='count').reset_index()
count_price = count_price.rename(columns={'month_year' : 'month_year2'})
count_price
# Out:
#    month_year2  order_id
# 0   2018-10-01       567
# 1   2018-11-01       474
# 2   2018-12-01       366
# 3   2019-01-01       221
# 4   2019-02-01       425
# 5   2019-03-01       496
# 6   2019-04-01       759
# 7   2019-05-01       851
# 8   2019-06-01       725
# 9   2019-07-01       391
# 10  2019-08-01       219
# 11  2019-09-01       248
# 12  2019-10-01       255

# %% [markdown]
# Объеденим обе таблицы и удалим "задвоившейся" столюец с месяцами, а так же разделим сумму по месяца на количество покупок по месяцам.

# %%
mean_count_price = pd.concat([mean_price, count_price], axis=1)
mean_count_price = mean_count_price[['month_year', 'price', 'order_id']]
mean_count_price['avg_bill'] = mean_count_price['price']/mean_count_price['order_id']
mean_count_price
# Out:
#     month_year     price  order_id    avg_bill
# 0   2018-10-01  322573.0       567  568.911817
# 1   2018-11-01  238998.0       474  504.215190
# 2   2018-12-01  303841.0       366  830.166667
# 3   2019-01-01  172051.0       221  778.511312
# 4   2019-02-01  250846.0       425  590.225882
# 5   2019-03-01  252877.0       496  509.832661
# 6   2019-04-01  270123.0       759  355.893281
# 7   2019-05-01  210536.0       851  247.398355
# 8   2019-06-01  214359.0       725  295.667586
# 9   2019-07-01  191593.0       391  490.007673
# 10  2019-08-01  168990.0       219  771.643836
# 11  2019-09-01  165450.0       248  667.137097
# 12  2019-10-01  190461.0       255  746.905882

# %% [markdown]
# Построим график среднего чека по месяцам

# %%
plt.figure(figsize=(10,8))

ax1 = sns.barplot(data=mean_count_price,
                  x=mean_count_price['month_year'].astype('datetime64[M]').dt.date, 
                  y=mean_count_price['avg_bill'])
ax1.set_xlabel('')
ax1.set_ylabel('')
ax1.figure.autofmt_xdate(rotation=45) 

ax1.set_title('Ежемесячные средний чек');

# %% [markdown]
# ##### Выводы:
#
# По графику видно, что:
# 1. Наибольший средний чек в декабре 2018 года(2018-12-01). Вероятнее всего, это связано с новым годом. Так же большой средний чек (по сравнению с остальными месяцами) в январе 2019 года, в августе 2019 года и октябре 2019 года.
#
# Так же отметим, что средний чек в октябре увеличился с 2018 по 2019 год. Возможно, в 2019 года был расширен ассортимент или проводилась маркетинговая компания, которая хорошая себя показала.
#
# 2. Наименьший средний чек в мае 2019 года, а так же июне 2019 года.Вероятнее всего, многие потенциальные покупатели уезжают в отпуск, на дачу и  реже пользуются интернет-магазином. В данный период можно запустить акцию (маркетинговую компанию), для увеличения среднего чека и привлечения покупателей
#
# 3. Наибольший средний чек по сезонам:
# * зимой-в декабре (вероятнее всего, влияние новго года)
# * весной-в марте
# * летом-в августе
# * осенью-в октябре 2019
#
# 4. Наименьший средний чек по сезонам:
# * зимой-в феврале
# * весной-в мае
# * летом-в июне
# * осенью-в октябре 2018

# %% [markdown]
# ### Количество заказов по часам

# %% [markdown]
# Расчитаем количество покупок по часам:

# %%
hours_orders = data.pivot_table(index='hours', 
                                values='order_id', 
                                aggfunc='count').reset_index()
hours_orders.head()
# Out:
#    hours  order_id
# 0      0        70
# 1      1        44
# 2      2        18
# 3      3        10
# 4      4        28

# %%
plt.figure(figsize=(10,8))

ax1 = sns.barplot(data=hours_orders,
                  x=hours_orders['hours'], 
                  y=hours_orders['order_id'])
ax1.set_xlabel('')
ax1.set_ylabel('')

ax1.set_title('Количество заказов по часам');

# %% [markdown]
# #### Выводы:
#
# По графику видно, что пользователи:
# * чаще всего заказывают в промежутке времени с 8:00 до 22:00.
# * наименьшую активность пользователи проявляют с 02:00 до 04:00

# %% [markdown]
# ### Прибыль по часам

# %% [markdown]
# Посмотрим, как отличается прибыль пользователей по часам

# %%
hours_sum = data.pivot_table(index='hours', 
                                values='price', 
                                aggfunc='sum').reset_index()
hours_sum.head()
# Out:
#    hours    price
# 0      0  34145.0
# 1      1  21702.0
# 2      2  22434.0
# 3      3  12413.0
# 4      4  14116.0

# %%
plt.figure(figsize=(10,8))

ax1 = sns.barplot(data=hours_sum,
                  x=hours_sum['hours'], 
                  y=hours_sum['price'])
ax1.set_xlabel('')
ax1.set_ylabel('')
ax1.set_title('Прибыль по часам');

# %% [markdown]
# ##### Выводы:
#
# По графику видно, что прибыль:
# * больше всего в промежутке времени с 8:00 до 22:00.
# * наименьшая прибыль в промежутке с 03:00 до 04:00.
#
# Таким образом, по графику можно сделать предположение, что прибыль в ночные часы меньше (с 20:00 до 8:00), чем в дневные.
#
# Возможно, следует проводить ночные распродажи, для увеличения прибыль в ночные часы

# %% [markdown]
# #### Анализ прибыли дневное/ночное время

# %% [markdown]
# Рассмотрим прибыль в дневное время,  и в ночное. За ночное время суток примем промежуток времени с 20:00 по 8:00.
#
# Для этого список `night`, где укажем какие часы относятся к ночным:

# %%
night = [20,21,22,23,0,1,2,3,4,5,6,7,8]

# %% [markdown]
# Напишем функция, которая присвоит время суток покупке в зависимости от часа покупки

# %%
def day(hours):
    if hours in night:
        return 'ночь'
    if hours not in night:
        return 'день'
    else:
        return 'неизвестно'

# %% [markdown]
# Проверим функцию:

# %%
display(day(20))
day(10)
# Out:
# 'ночь'
# 'день'

# %% [markdown]
# Функция работает исправно, применим ее к таблице

# %%
data['day'] = data['hours'].apply(day)
data.head()
# Out:
#                             customer_id  order_id  \
# 0  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                              product  quantity  price  \
# 0    комнатное растение в горшке алое вера, d12, h30         1  142.0
# 1  комнатное растение в горшке кофе арабика, d12,...         1  194.0
# 2                        радермахера d-12 см h-20 см         1  112.0
# 3                   хризолидокарпус лутесценс d-9 см         1  179.0
# 4                     циперус зумула d-12 см h-25 см         1  112.0
#
#    month_year  hours      new_product category   day
# 0  2018-10-01      0        комнатное      сад  ночь
# 1  2018-10-01      0        комнатное      сад  ночь
# 2  2018-10-01      0      радермахера      сад  ночь
# 3  2018-10-01      0  хризолидокарпус      сад  ночь
# 4  2018-10-01      0          циперус      сад  ночь

# %% [markdown]
# Время суток присвоено, теперь проверим, есть ли покупки, которые не получили врем ясуток:

# %%
data[data['day']=='неизвестно']
# Out:
# Empty DataFrame
# Columns: [customer_id, order_id, product, quantity, price, month_year, hours, new_product, category, day]
# Index: []

# %%
data['day'].value_counts()#уникальные значения столбца
# Out:
# день    4348
# ночь    1649
# Name: day, dtype: int64

# %% [markdown]
# Все покупки получили время суток. Проверим, отличается ли выручка по времени суток

# %%
day_sum = data.pivot_table(index='day', 
                                values='price', 
                                aggfunc='sum').reset_index()
day_sum.head()
# Out:
#     day      price
# 0  день  2087566.0
# 1  ночь   865132.0

# %%
plt.figure(figsize=(10,8))

ax1 = sns.barplot(data=day_sum,
                  x=day_sum['day'], 
                  y=day_sum['price'], palette='pastel')
ax1.set_xlabel('')
ax1.set_ylabel('')
ax1.set_title('Прибыль по времени суток');

# %% [markdown]
# ##### Выводы:
#
# По графику видно, что:
# * прибыль в дневное время больше (с 8:00 до 20:00), чем в ночное
#
# Далее, проверим: является ли данное различие в прибыли статистически значимым или нет.

# %% [markdown]
# ### Анализ количества заказов день/ночь

# %% [markdown]
# Составим таблицу, где будет количество заказов днем и ночью

# %%
day_orders = data.pivot_table(index='day', 
                                values='order_id', 
                                aggfunc='count').reset_index()
day_orders.head()
# Out:
#     day  order_id
# 0  день      4348
# 1  ночь      1649

# %%
plt.figure(figsize=(10,8))

ax1 = sns.barplot(data=day_orders,
                  x=day_orders['day'], 
                  y=day_orders['order_id'], palette='pastel')
ax1.set_xlabel('')
ax1.set_ylabel('')

ax1.set_title('Количество заказов день/ночь');

# %% [markdown]
# #### Выводы:
#
# По графику видно, что:
# * количество заказов в дневное время больше (с 8:00 до 20:00), чем в ночное время
#
# Далее, проверим: является ли данное различие в количестве заказов статистически значимым или нет.

# %% [markdown]
# ## Формулировка статистических гипотез

# %% [markdown]
# Исходя из проведенного анализа, мы сформурировали следующие предположения:
# * прибыль в ночное время (20:00-8:00) отличается от прибыли в дневное время
# * прибыль в категории гардероб отличается от прибыли в других категориях
#
# Проверим наши гипотезы

# %% [markdown]
# ## Проверка статичстических гипотез

# %% [markdown]
# ### Гипотеза № 1
#
# * Н0: нет статистически значимой разницы между средней прибылью в ночное время и дневное время, то есть в ночное время средняя прибыль такая же, как в дневное
# * Н1: есть статистически значимая разница средней прибыли в ночное время и дневное время, то есть средняя прибыль в дневное время не такая же, как в ночное время

# %%
alpha = .05

results = st.ttest_ind(data.query('day =="день"')['price'], data.query('day =="ночь"')['price'])
print('Значение p-value:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# Значение p-value: 0.08384056882134695
# Не удалось отвергнуть нулевую гипотезу

# %% [markdown]
# #### Выводы
#
# В ходе проверки гипотезы № 1 - не удалось отвергнуть нулевую гипотезу.
#
# Таким образом, нет статистически значимой разницы между средней прибылью в ночное время и дневное время, то есть в ночное время средняя прибыль такая же, как в дневное.

# %% [markdown]
# ### Гипотеза № 2

# %% [markdown]
# * Н0: нет статистически значимой разницы между средним количестом заказов в дневное время и ночное время, то есть количество заказов в дневное и ночное время одинаковое
# * Н1: есть статистически значимая разница между средним количестом заказов в дневное время и ночное время, то есть количество заказов в дневное и ночное время разное

# %%
alpha = .05

results = st.ttest_ind(data.query('day =="день"')['order_id'], data.query('day =="ночь"')['order_id'])
print('Значение p-value:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# Значение p-value: 0.00011355354951749238
# Отвергаем нулевую гипотезу

# %% [markdown]
# #### Выводы
#
# В ходе проверки гипотезы № 2 - отвергаем нулевую гипотезу.
#
# Таким образом, есть значимая разница между средним количестом заказов в дневное время и ночное время, то есть количество заказов в дневное и ночное время разное

# %% [markdown]
# ### Гипотеза № 3
#
# * Н0: нет статистически значимой разницы между средней прибылью в категории гардероб и другими категориями, то есть прибыль в категориях гардероб и других категориях одинаковая
# * Н1: есть статистически значимая разница между прибылью в категории гардероб и другими категориями, то есть прибыль в категории гардероб отличается от прибыли в других категориях

# %%
alpha = .05

results = st.ttest_ind(data.query('category =="гардероб"')['price'], data.query('category !="гардероб"')['price'])
print('Значение p-value:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# Значение p-value: 8.036391577960551e-283
# Отвергаем нулевую гипотезу

# %% [markdown]
# #### Выводы
#
# В ходе проверки гипотезы № 3 - отвергаем нулевую гипотезу.
#
# Таким образом, есть статистически значимая разница между прибылью в категории гардероб и другими категориями, то есть прибыль в категории гардероб отличается от прибыли в других категориях

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе исследования были выполнены следующие задачи:
#
# 1. В столбце date, где указана дата заказа изменен тип данных (с int64 на datetime)
# 2. Данные были проверены на пропуски (пропусков нет)
# 3. Создан доп.столбецы в таблице, где указаны только месяц, и только часы заказа
# 4. Данные были проверкны на дубликаты, дубликаты были удалены
# 5. Была проведена кластеризация, в результате которой установлено число категорий-7 категорий
# 6. Проведена категоризация столбца с наименованиями товаров, каждый товар отнесен в определнную категорию
# 7. Был определен период анализа данных (01.10.2018-01.10.2019 гг)
# 8. Выявление и удаление аномалий
#
#
# 9. Для каждой категории установлен месяц с наибольшим количеством заказов в категории:
# * бытовая химия - в октябре,ноябре и декабре 2018 года
# * ванная комната - в октябре 2018 года
# * гардероб - в октябре,ноябре и декабре 2018 года
# * для дома - в декабре 2018 года, августе, октябре 2018 и 2019 года
# * кухня - в октябре,ноябре и декабре 2018 года
# * сад - в апреле, мае и июне 2019 года
# * текстиль - в октябре,ноябре и декабре 2018 года
#
#
# 10. Для каждой категории установлены месяца с наибольшей прибылью в категории:
# * бытовая химия - в декабре 2018 года и августе 2019 года
# * ванная комната - в октябре 2018 года, феврале и марте 2019 года
# * гардероб - в октябре,ноябре,декабре 2018 года, феврале 2019 года
# * для дома - в октябре 2019 года и апереле 2018 года
# * инстурменты - в октябре, декабре 2018 года, январе,июне и октябре 2019 года
# * кухня - в октябре, декабре 2018 года, феврале 2019 года
# * сад - в апреле, мае и июне 2019 года
# * текстиль - в октябре, декабре 2018 года и январе 2019 года
#
# 11. Была выявлена:
# * наиболее прибыльная категория-гардероб
# * наименее прибыльная категория-бытовая химия
#
# 12. Установлено количество уникальных пользователей (2449 пользователя)
# 13. Выявлено количество повторных покупок-664
# 14. Выявлена доля повторных покупок: 27.1 %. Что бы увеличить данный показатель, можно "стимулировать" покупателей на повторные покупки: купонами на скидку на следующую покупку, программой лояльности с накопительной скидочной системой.
# 15. Определено среднее количество заказов на пользователя: 2.4
# 16. Установлено, что наибольшее количество покупок приходится на период с апреля по июнь 2019 года
# 17. Установлено, что наименьшее количество покупок приходится на январь и август 2019 года
# 18. Определены месяца с наибольшей и наименьшей прибылью:
# * наибольшая в октябре 2018 года, а так же декабре 2018 и апреле 2019 года
# * наименьшая прибыль в сентябре, а так же январе и августе
# 19. Установлено, что:
# * чаще всего заказывают в промежутке времени с 8:00 до 22:00.
# * наименьшую активность пользователи проявляют с 02:00 до 04:00
# 20. Выяснено, что прибыль по часам:
# * больше всего в промежутке времени с 8:00 до 22:00.
# * наименьшая прибыль в промежутке с 03:00 до 04:00.
#
# 21. Проведена проверка гипотез и получены следующие результаты:
#
#
# * Гипотеза № 1-результат:нет статистически значимой разницы между средней прибылью в ночное время и дневное время, то есть в ночное время средняя прибыль такая же, как в дневное
#
#
# * Гипотеза № 2-результат:есть значимая разница между средним количестом заказов в дневное время и ночное время, то есть количество заказов в дневное и ночное время разное
#
# * Гипотеза № 3-результат:есть статистически значимая разница между прибылью в категории гардероб и другими категориями, то есть прибыль в категории гардероб отличается от прибыли в других категориях

# %% [markdown]
# ## Рекомедации

# %% [markdown]
# 1. Рекомендуется пополнять ассортимент соответствующим товаром перед месяцами с наибольшей прибылью в категории:
# * бытовая химия - в декабре 2018 года и августе 2019 года
# * ванная комната - в октябре 2018 года, феврале и марте 2019 года
# * гардероб - в октябре,ноябре,декабре 2018 года, феврале 2019 года
# * для дома - в октябре 2019 года и апереле 2018 года
# * инстурменты - в октябре, декабре 2018 года, январе,июне и октябре 2019 года
# * кухня - в октябре, декабре 2018 года, феврале 2019 года
# * сад - в апреле, мае и июне 2019 года
# * текстиль - в октябре, декабре 2018 года и январе 2019 года
#
# 2. Что бы увеличить долю повторных покупок, можно "стимулировать" покупателей на повторные покупки: купонами на скидку на следующую покупку, программой лояльности с накопительной скидочной системой.
#
#
# 3. Для увеличения среднего количества заказов так же можно проводить маркетинговые компании (возьми второй продукт, но со скидкой)
#
# 4. Рекомендовано пополнить ассортимент перед месяцами с наибольшим количеством заказов (апреля по июнь), а так же усилить службу доставки
#
# 5. Рекомендовано рассмотреть проведение маркетинговую компанию (акций) в месяца с наименьшим количеством покупок, для привлечения пользователей, увеличения количества покупок и выручки (январь и август)
#
# 6. Возможно, следует проводить ночные распродажи, для увеличения прибыль в ночные часы
